# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Clean_Dataset.csv')
data.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
business = pd.read_csv('business.csv')
business
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1      11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2      11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3      11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4      11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 93482  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483  31-03-2022    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485  31-03-2022    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     20:00     Mumbai
# 1                                              non-stop     21:15     Mumbai
# 2      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45     Mumbai
# 3      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# 4      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# ...                                                  ...      ...        ...
# 93482  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
# 93483  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    22:55  Hyderabad
# 93484  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 93485  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    17:00  Hyderabad
# 93486  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
#
#         price
# 0      25,612
# 1      25,612
# 2      42,220
# 3      44,450
# 4      46,690
# ...       ...
# 93482  69,265
# 93483  77,105
# 93484  79,099
# 93485  81,585
# 93486  81,585
#
# [93487 rows x 11 columns]

# %%
economy = pd.read_csv('economy.csv')
economy
# Out:
#               date   airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...            ...       ...     ...       ...      ...      ...        ...
# 206769  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022   Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop arr_time         to  \
# 0                                               non-stop     21:05     Mumbai
# 1                                               non-stop     08:40     Mumbai
# 2                                               non-stop     06:35     Mumbai
# 3                                               non-stop     12:35     Mumbai
# 4                                               non-stop     11:10     Mumbai
# ...                                                   ...      ...        ...
# 206769  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206770  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206771  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206772  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206773  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
#
#         price
# 0       5,953
# 1       5,953
# 2       5,956
# 3       5,955
# 4       5,955
# ...       ...
# 206769  7,697
# 206770  7,709
# 206771  8,640
# 206772  8,640
# 206773  8,640
#
# [206774 rows x 11 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #### merging economy and business class into one column

# %%
business['class'] = "business"
economy['class'] = "economy"

# %%
df =business.append(economy)

# %%
df
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop arr_time         to  \
# 0                                               non-stop     20:00     Mumbai
# 1                                               non-stop     21:15     Mumbai
# 2       1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45     Mumbai
# 3       1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# 4       1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# ...                                                   ...      ...        ...
# 206769  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206770  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206771  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206772  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206773  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
#
#          price     class
# 0       25,612  business
# 1       25,612  business
# 2       42,220  business
# 3       44,450  business
# 4       46,690  business
# ...        ...       ...
# 206769   7,697   economy
# 206770   7,709   economy
# 206771   8,640   economy
# 206772   8,640   economy
# 206773   8,640   economy
#
# [300261 rows x 12 columns]

# %%
df.drop_duplicates(inplace=True) # dropping duplicates if theres any

# %% [markdown]
# # converting stop column into integer

# %%
df['stop']= df['stop'].str.split('-').str[0]

# %%
df['stop'].unique()
# Out:
# array(['non', '1', '2+'], dtype=object)

# %%
df['stop']=df['stop'].map({'non':0, '1':1, '2+':2}).astype(int)

# %%
df
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
#         stop arr_time         to   price     class
# 0          0    20:00     Mumbai  25,612  business
# 1          0    21:15     Mumbai  25,612  business
# 2          1    20:45     Mumbai  42,220  business
# 3          1    23:55     Mumbai  44,450  business
# 4          1    23:55     Mumbai  46,690  business
# ...      ...      ...        ...     ...       ...
# 206769     1    20:55  Hyderabad   7,697   economy
# 206770     1    20:55  Hyderabad   7,709   economy
# 206771     1    09:05  Hyderabad   8,640   economy
# 206772     1    09:05  Hyderabad   8,640   economy
# 206773     1    20:55  Hyderabad   8,640   economy
#
# [300259 rows x 12 columns]

# %% [markdown]
# ## splitting hour taken column into hour and column

# %%
df['hour_taken']=df['time_taken'].str.split(' ').str[0].str.split('h').str[0]

# %%
df['min_taken']=df['time_taken'].str.split(' ').str[1].str.split('m').str[0]

# %%
df['price']= df['price'].str.replace(',','')

# %%
df
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
#         stop arr_time         to  price     class hour_taken min_taken
# 0          0    20:00     Mumbai  25612  business         02        00
# 1          0    21:15     Mumbai  25612  business         02        15
# 2          1    20:45     Mumbai  42220  business         24        45
# 3          1    23:55     Mumbai  44450  business         26        30
# 4          1    23:55     Mumbai  46690  business         06        40
# ...      ...      ...        ...    ...       ...        ...       ...
# 206769     1    20:55  Hyderabad   7697   economy         13        50
# 206770     1    20:55  Hyderabad   7709   economy         13        50
# 206771     1    09:05  Hyderabad   8640   economy         20        35
# 206772     1    09:05  Hyderabad   8640   economy         23        20
# 206773     1    20:55  Hyderabad   8640   economy         24        25
#
# [300259 rows x 14 columns]

# %% [markdown]
# ### merging ch_code and num code to make a proper flight number

# %%
df['flight']=df['ch_code']+ '-'+ df['num_code'].astype(str)

# %%
df.head()
# Out:
#          date    airline ch_code  num_code dep_time   from time_taken  stop  \
# 0  11-02-2022  Air India      AI       868    18:00  Delhi    02h 00m     0
# 1  11-02-2022  Air India      AI       624    19:00  Delhi    02h 15m     0
# 2  11-02-2022  Air India      AI       531    20:00  Delhi    24h 45m     1
# 3  11-02-2022  Air India      AI       839    21:25  Delhi    26h 30m     1
# 4  11-02-2022  Air India      AI       544    17:15  Delhi    06h 40m     1
#
#   arr_time      to  price     class hour_taken min_taken  flight
# 0    20:00  Mumbai  25612  business         02        00  AI-868
# 1    21:15  Mumbai  25612  business         02        15  AI-624
# 2    20:45  Mumbai  42220  business         24        45  AI-531
# 3    23:55  Mumbai  44450  business         26        30  AI-839
# 4    23:55  Mumbai  46690  business         06        40  AI-544

# %% [markdown]
# ### Making category of departure and arrival time for better analysis

# %%
def deptime(tmm):
    tmm = int(tmm.split(":")[0])
    if tmm >= 4 and tmm <= 8:
        day = 'Early Morning'
    elif tmm > 8 and tmm <12:
        day = 'Morning'
    elif tmm >= 12 and tmm < 16:
        day = 'Afternoon'
    elif tmm >= 16 and tmm < 20:
        day = 'Evening'
    elif tmm >= 20 and tmm < 24 :
        day = 'Night'
    else:
        day = 'Late Night'
    return day

# %%
df['departure_time'] = df['dep_time'].apply(deptime)

# %%
df['arrival_time'] = df['arr_time'].apply(deptime)

# %%
df.head()
# Out:
#          date    airline ch_code  num_code dep_time   from time_taken  stop  \
# 0  11-02-2022  Air India      AI       868    18:00  Delhi    02h 00m     0
# 1  11-02-2022  Air India      AI       624    19:00  Delhi    02h 15m     0
# 2  11-02-2022  Air India      AI       531    20:00  Delhi    24h 45m     1
# 3  11-02-2022  Air India      AI       839    21:25  Delhi    26h 30m     1
# 4  11-02-2022  Air India      AI       544    17:15  Delhi    06h 40m     1
#
#   arr_time      to  price     class hour_taken min_taken  flight  \
# 0    20:00  Mumbai  25612  business         02        00  AI-868
# 1    21:15  Mumbai  25612  business         02        15  AI-624
# 2    20:45  Mumbai  42220  business         24        45  AI-531
# 3    23:55  Mumbai  44450  business         26        30  AI-839
# 4    23:55  Mumbai  46690  business         06        40  AI-544
#
#   departure_time arrival_time
# 0        Evening        Night
# 1        Evening        Night
# 2          Night        Night
# 3          Night        Night
# 4        Evening        Night

# %% [markdown]
# ## making a new column days left from the dates

# %%
df['new_date']='10-02-2022'

# %%
df
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
#         stop arr_time         to  price     class hour_taken min_taken  \
# 0          0    20:00     Mumbai  25612  business         02        00
# 1          0    21:15     Mumbai  25612  business         02        15
# 2          1    20:45     Mumbai  42220  business         24        45
# 3          1    23:55     Mumbai  44450  business         26        30
# 4          1    23:55     Mumbai  46690  business         06        40
# ...      ...      ...        ...    ...       ...        ...       ...
# 206769     1    20:55  Hyderabad   7697   economy         13        50
# 206770     1    20:55  Hyderabad   7709   economy         13        50
# 206771     1    09:05  Hyderabad   8640   economy         20        35
# 206772     1    09:05  Hyderabad   8640   economy         23        20
# 206773     1    20:55  Hyderabad   8640   economy         24        25
#
#         flight departure_time arrival_time    new_date
# 0       AI-868        Evening        Night  10-02-2022
# 1       AI-624        Evening        Night  10-02-2022
# 2       AI-531          Night        Night  10-02-2022
# 3       AI-839          Night        Night  10-02-2022
# 4       AI-544        Evening        Night  10-02-2022
# ...        ...            ...          ...         ...
# 206769  UK-832  Early Morning        Night  10-02-2022
# 206770  UK-832  Early Morning        Night  10-02-2022
# 206771  UK-826      Afternoon      Morning  10-02-2022
# 206772  UK-822        Morning      Morning  10-02-2022
# 206773  UK-824          Night        Night  10-02-2022
#
# [300259 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300259 entries, 0 to 206773
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            300259 non-null  object
#  1   airline         300259 non-null  object
#  2   ch_code         300259 non-null  object
#  3   num_code        300259 non-null  int64
#  4   dep_time        300259 non-null  object
#  5   from            300259 non-null  object
#  6   time_taken      300259 non-null  object
#  7   stop            300259 non-null  int32
#  8   arr_time        300259 non-null  object
#  9   to              300259 non-null  object
#  10  price           300259 non-null  object
#  11  class           300259 non-null  object
#  12  hour_taken      300259 non-null  object
#  13  min_taken       300259 non-null  object
#  14  flight          300259 non-null  object
#  15  departure_time  300259 non-null  object
#  16  arrival_time    300259 non-null  object
#  17  new_date        300259 non-null  object
# dtypes: int32(1), int64(1), object(16)
# memory usage: 42.4+ MB

# %%
df['date'] = pd.to_datetime(df['date'],format="%d-%m-%Y")
df['new_date'] = pd.to_datetime(df['new_date'],format="%d-%m-%Y")

# %%
df['days_left']=df['date']-df['new_date']

# %%
df
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      2022-02-11  Air India      AI       868    18:00    Delhi    02h 00m
# 1      2022-02-11  Air India      AI       624    19:00    Delhi    02h 15m
# 2      2022-02-11  Air India      AI       531    20:00    Delhi    24h 45m
# 3      2022-02-11  Air India      AI       839    21:25    Delhi    26h 30m
# 4      2022-02-11  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 206769 2022-03-31    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770 2022-03-31    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771 2022-03-31    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772 2022-03-31    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773 2022-03-31    Vistara      UK       824    20:30  Chennai    24h 25m
#
#         stop arr_time         to  price     class hour_taken min_taken  \
# 0          0    20:00     Mumbai  25612  business         02        00
# 1          0    21:15     Mumbai  25612  business         02        15
# 2          1    20:45     Mumbai  42220  business         24        45
# 3          1    23:55     Mumbai  44450  business         26        30
# 4          1    23:55     Mumbai  46690  business         06        40
# ...      ...      ...        ...    ...       ...        ...       ...
# 206769     1    20:55  Hyderabad   7697   economy         13        50
# 206770     1    20:55  Hyderabad   7709   economy         13        50
# 206771     1    09:05  Hyderabad   8640   economy         20        35
# 206772     1    09:05  Hyderabad   8640   economy         23        20
# 206773     1    20:55  Hyderabad   8640   economy         24        25
#
#         flight departure_time arrival_time   new_date days_left
# 0       AI-868        Evening        Night 2022-02-10    1 days
# 1       AI-624        Evening        Night 2022-02-10    1 days
# 2       AI-531          Night        Night 2022-02-10    1 days
# 3       AI-839          Night        Night 2022-02-10    1 days
# 4       AI-544        Evening        Night 2022-02-10    1 days
# ...        ...            ...          ...        ...       ...
# 206769  UK-832  Early Morning        Night 2022-02-10   49 days
# 206770  UK-832  Early Morning        Night 2022-02-10   49 days
# 206771  UK-826      Afternoon      Morning 2022-02-10   49 days
# 206772  UK-822        Morning      Morning 2022-02-10   49 days
# 206773  UK-824          Night        Night 2022-02-10   49 days
#
# [300259 rows x 19 columns]

# %% [markdown]
# ## Time for remove the unnecessary column . PURGEEEE!!!

# %%
df.drop(['date','new_date','ch_code','num_code','dep_time',
         'time_taken','arr_time'],axis=1,inplace =True)

# %%
df.head(5)
# Out:
#      airline   from  stop      to  price     class hour_taken min_taken  \
# 0  Air India  Delhi     0  Mumbai  25612  business         02        00
# 1  Air India  Delhi     0  Mumbai  25612  business         02        15
# 2  Air India  Delhi     1  Mumbai  42220  business         24        45
# 3  Air India  Delhi     1  Mumbai  44450  business         26        30
# 4  Air India  Delhi     1  Mumbai  46690  business         06        40
#
#    flight departure_time arrival_time days_left
# 0  AI-868        Evening        Night    1 days
# 1  AI-624        Evening        Night    1 days
# 2  AI-531          Night        Night    1 days
# 3  AI-839          Night        Night    1 days
# 4  AI-544        Evening        Night    1 days

# %% [markdown]
# ### Dataset looks good now , but can get better if we convert two difreent time column into just minutes . So, lets do that .

# %%
df['days_left']= df['days_left'].astype(str)

# %%
df['days_left'] = df['days_left'].str.split(' ').str[0]

# %%
df['hour_taken']= df['hour_taken'].astype(float)

# %%
df['hour_taken']=df['hour_taken'].astype(int)

# %%
df[df['min_taken']=='']
# Out:
#          airline       from  stop         to price    class  hour_taken  \
# 96486   GO FIRST  Bangalore     1     Mumbai  5177  economy           1
# 104676  GO FIRST  Bangalore     2    Kolkata  5177  economy           1
# 111315  GO FIRST  Bangalore     2  Hyderabad  4337  economy           1
# 154007  GO FIRST  Hyderabad     1      Delhi  6132  economy           1
#
#        min_taken  flight departure_time   arrival_time days_left
# 96486             G8-146  Early Morning        Morning        16
# 104676            G8-146  Early Morning  Early Morning        16
# 111315            G8-146  Early Morning        Morning        16
# 154007            G8-517          Night          Night        15

# %% [markdown]
# ## heres the trouble making rows , something looks fishy 1 hour flight having 2 stops looks like someone travelling on a moon on Go First . Goodbye 4 rows time to drop them..

# %%
df.drop(df[df['min_taken']==''].index,inplace=True)

# %%
df['min_taken'] = df['min_taken'].astype('int')

# %%
df['duration'] =(df['hour_taken']*60)+df['min_taken']

# %%
df.drop(['min_taken','hour_taken'],axis=1,inplace = True)

# %%
df.reset_index()
# Out:
#          index    airline     from  stop         to  price     class  flight  \
# 0            0  Air India    Delhi     0     Mumbai  25612  business  AI-868
# 1            1  Air India    Delhi     0     Mumbai  25612  business  AI-624
# 2            2  Air India    Delhi     1     Mumbai  42220  business  AI-531
# 3            3  Air India    Delhi     1     Mumbai  44450  business  AI-839
# 4            4  Air India    Delhi     1     Mumbai  46690  business  AI-544
# ...        ...        ...      ...   ...        ...    ...       ...     ...
# 300250  206769    Vistara  Chennai     1  Hyderabad   7697   economy  UK-832
# 300251  206770    Vistara  Chennai     1  Hyderabad   7709   economy  UK-832
# 300252  206771    Vistara  Chennai     1  Hyderabad   8640   economy  UK-826
# 300253  206772    Vistara  Chennai     1  Hyderabad   8640   economy  UK-822
# 300254  206773    Vistara  Chennai     1  Hyderabad   8640   economy  UK-824
#
#        departure_time arrival_time days_left  duration
# 0             Evening        Night         1       120
# 1             Evening        Night         1       135
# 2               Night        Night         1      1485
# 3               Night        Night         1      1590
# 4             Evening        Night         1       400
# ...               ...          ...       ...       ...
# 300250  Early Morning        Night        49       830
# 300251  Early Morning        Night        49       830
# 300252      Afternoon      Morning        49      1235
# 300253        Morning      Morning        49      1400
# 300254          Night        Night        49      1465
#
# [300255 rows x 12 columns]

# %%
df
# Out:
#           airline     from  stop         to  price     class  flight  \
# 0       Air India    Delhi     0     Mumbai  25612  business  AI-868
# 1       Air India    Delhi     0     Mumbai  25612  business  AI-624
# 2       Air India    Delhi     1     Mumbai  42220  business  AI-531
# 3       Air India    Delhi     1     Mumbai  44450  business  AI-839
# 4       Air India    Delhi     1     Mumbai  46690  business  AI-544
# ...           ...      ...   ...        ...    ...       ...     ...
# 206769    Vistara  Chennai     1  Hyderabad   7697   economy  UK-832
# 206770    Vistara  Chennai     1  Hyderabad   7709   economy  UK-832
# 206771    Vistara  Chennai     1  Hyderabad   8640   economy  UK-826
# 206772    Vistara  Chennai     1  Hyderabad   8640   economy  UK-822
# 206773    Vistara  Chennai     1  Hyderabad   8640   economy  UK-824
#
#        departure_time arrival_time days_left  duration
# 0             Evening        Night         1       120
# 1             Evening        Night         1       135
# 2               Night        Night         1      1485
# 3               Night        Night         1      1590
# 4             Evening        Night         1       400
# ...               ...          ...       ...       ...
# 206769  Early Morning        Night        49       830
# 206770  Early Morning        Night        49       830
# 206771      Afternoon      Morning        49      1235
# 206772        Morning      Morning        49      1400
# 206773          Night        Night        49      1465
#
# [300255 rows x 11 columns]

# %%
df['price']=df['price'].astype(int)

# %% [markdown]
# ## merging source and destination city as one

# %%
df["Travelling_Cities"] = df["from"] +'-' + df["to"]

# %%
df['Travelling_Cities'].value_counts()
# Out:
# Delhi-Mumbai           15289
# Mumbai-Delhi           14809
# Delhi-Bangalore        14012
# Bangalore-Delhi        13756
# Bangalore-Mumbai       12939
# Mumbai-Bangalore       12885
# Mumbai-Kolkata         12602
# Delhi-Kolkata          11934
# Kolkata-Mumbai         11467
# Delhi-Chennai          10780
# Kolkata-Delhi          10506
# Mumbai-Hyderabad       10477
# Mumbai-Chennai         10130
# Hyderabad-Mumbai       10073
# Bangalore-Kolkata      10028
# Kolkata-Bangalore       9824
# Chennai-Delhi           9783
# Chennai-Mumbai          9338
# Delhi-Hyderabad         9328
# Bangalore-Hyderabad     8970
# Hyderabad-Delhi         8506
# Hyderabad-Kolkata       7987
# Hyderabad-Bangalore     7898
# Kolkata-Hyderabad       7897
# Chennai-Kolkata         6983
# Kolkata-Chennai         6653
# Chennai-Bangalore       6493
# Bangalore-Chennai       6410
# Hyderabad-Chennai       6395
# Chennai-Hyderabad       6103
# Name: Travelling_Cities, dtype: int64

# %%
df.describe()
# Out:
#                 stop          price       duration
# count  300255.000000  300255.000000  300255.000000
# mean        0.924204   20884.009249     733.071306
# std         0.398182   22696.041149     431.571309
# min         0.000000    1105.000000      50.000000
# 25%         1.000000    4783.000000     405.000000
# 50%         1.000000    7425.000000     675.000000
# 75%         1.000000   42521.000000     970.000000
# max         2.000000  123071.000000    2990.000000

# %% [markdown]
# ## what do we see here ! Mean of price is way greater than median that means data is not normally distributed it is right skewed (positive-skew) lets see that with the help of distribution plot

# %% [markdown]
# # Let the Fun began, Data visualization Time

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title('Flight Price Distribution Plot')
sns.distplot(df.price,color='red')

plt.subplot(1,2,2)
plt.title('Flight Price Spread')
sns.boxplot(y=df.price,color = 'green')

plt.show()

# %%
plt.figure(figsize=(12,6))
sns.catplot('price','Travelling_Cities',hue='class',data = df,kind='bar')
plt.title( 'price comparison with diffrent destination respective to class')
# Out:
# Text(0.5, 1.0, 'price comparison with diffrent destination respective to class')

# %%
plt.figure(figsize=(12,8))
df.groupby(['Travelling_Cities'])['Travelling_Cities'].count().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Travelling_Cities'>

# %% [markdown]
# ### as we can see delhi to mumbai is the most travelled location by flight

# %%
plt.figure(figsize=(30,10))
sns.catplot(x='airline',y='price',hue='class',data=df.sort_values('price',ascending=False),kind='boxen',height = 8, aspect = 3)
plt.show()

# %% [markdown]
# # observation
#
# ### Holy Smokes  Vistara prices are skyrocketing i would need a crowdfunding to travel in a business class
# ### Trujet has the cheapest price (not suprised )
# ### Vistara and Air India provide business class facility for domestic flights and prices are way expensive as compared to economy class dont wonder why

# %%
fig, axes = plt.subplots(1,2, figsize=(12,8))
sns.boxplot(x='from', y='price', data=df, ax=axes[0])
axes[0].set(title='Price based on Source city')

sns.boxplot(x='to', y='price', data=df, ax=axes[1])
axes[1].set(title='Price based on Destination city')
# Out:
# [Text(0.5, 1.0, 'Price based on Destination city')]

# %% [markdown]
# ## theres shouldn't be a doubt there  kolkata being the most costly sorce and destination to travel as its the most farthest city from the above cities..

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='arrival_time',notch= True,y='price',data=df).tick_params(axis='x', rotation=45)

# %% [markdown]
# # Psst !! Here a secret information for the budgeteer if you wanna save some money travel late at night

# %%
df['stop'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df["duration"],df["price"],color='b',marker='+')
plt.title('Duration vs Price')
plt.xlabel('Duration Of Flight')
plt.ylabel('Price Of The Flight')
plt.grid(False)

# %%
plt.figure(figsize=(16,8))
sns.scatterplot('duration','price',hue='class',data=df)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='price'>

# %% [markdown]
# # mostly flights duration is from 1 to 41 hours

# %%
plt.figure(figsize=(16,8))
sns.barplot('days_left','price',hue='class',data=df,color='red')
# Out:
# <AxesSubplot:xlabel='days_left', ylabel='price'>

# %% [markdown]
# # As there's a saying,' Always plan your trip ahead' above graph is a prove showing drop in price when you book your tickets in advance

# %%
pie =df.groupby(['airline'])['airline'].count().sort_values()
keys=['Trujet','StarAir','Spicejet','airasia','go first',' indigo','air india','vistara']
explode = [0.3, 0.1, 0, 0, 0,0,0,0]
palette_color = sns.color_palette('bright')
plt.pie(pie, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%',pctdistance=0.5,radius=1.8,startangle=1,rotatelabels=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x13fd768be20>,
#   <matplotlib.patches.Wedge at 0x13fd7680730>,
#   <matplotlib.patches.Wedge at 0x13fd7680670>,
#   <matplotlib.patches.Wedge at 0x13fd01719a0>,
#   <matplotlib.patches.Wedge at 0x13fd01718b0>,
#   <matplotlib.patches.Wedge at 0x13fd0179e20>,
#   <matplotlib.patches.Wedge at 0x13fd71cc490>,
#   <matplotlib.patches.Wedge at 0x13fd76724c0>],
#  [Text(2.279635465190141, 0.04076942294577457, 'Trujet'),
#   Text(2.07962656376053, 0.039412628706678374, 'StarAir'),
#   Text(1.9671770185567476, 0.2249768380571354, 'Spicejet'),
#   Text(1.8412510419103894, 0.7281446289466855, 'airasia'),
#   Text(1.3971483504792517, 1.402988412907643, 'go first'),
#   Text(0.17733524693662966, 1.9720426491822953, ' indigo'),
#   Text(-1.8510226391216318, 0.7029332752539107, 'air india'),
#   Text(0.49072396095470355, -1.918225741185048, 'vistara')],
#  [Text(1.1998081395737583, 0.02145759102409188, '0%'),
#   Text(0.9998204633464087, 0.01894837918590307, '0%'),
#   Text(0.8941713720712489, 0.10226219911687971, '3%'),
#   Text(0.8369322917774497, 0.3309748313394025, '5%'),
#   Text(0.6350674320360234, 0.6377220058671104, '8%'),
#   Text(0.08060693042574076, 0.8963830223555886, '14%'),
#   Text(-0.8413739268734689, 0.3195151251154139, '27%'),
#   Text(0.2230563458885016, -0.871920791447749, '43%')])

# %% [markdown]
# # Bravo! Trujet and StarAir are just 44% behind from being the most favourable domestic airline of India.. for now Vistara is the most used one followed by Air India and Indigo

# %%
df.head()
# Out:
#      airline   from  stop      to  price     class  flight departure_time  \
# 0  Air India  Delhi     0  Mumbai  25612  business  AI-868        Evening
# 1  Air India  Delhi     0  Mumbai  25612  business  AI-624        Evening
# 2  Air India  Delhi     1  Mumbai  42220  business  AI-531          Night
# 3  Air India  Delhi     1  Mumbai  44450  business  AI-839          Night
# 4  Air India  Delhi     1  Mumbai  46690  business  AI-544        Evening
#
#   arrival_time days_left  duration Travelling_Cities
# 0        Night         1       120      Delhi-Mumbai
# 1        Night         1       135      Delhi-Mumbai
# 2        Night         1      1485      Delhi-Mumbai
# 3        Night         1      1590      Delhi-Mumbai
# 4        Night         1       400      Delhi-Mumbai

# %% [markdown]
# # Dealing with Categorical variables

# %%
df['days_left']=df['days_left'].astype(int)

# %%
df['arrival_time']=df['arrival_time'].map({'Evening':3, 'Night':4, 'Early Morning':0, 'Morning':1, 'Afternoon':2,
       'Late Night':5}).astype(int)

# %%
df['departure_time']=df['departure_time'].map({'Evening':3, 'Night':4, 'Early Morning':0, 'Morning':1, 'Afternoon':2,
       'Late Night':5}).astype(int)

# %%
df['class']=df['class'].map({'business':0, 'economy':1}).astype(int)

# %%
df['airline'].unique()
# Out:
# array(['Air India', 'Vistara', 'SpiceJet', 'AirAsia', 'GO FIRST',
#        'Indigo', 'Trujet', 'StarAir'], dtype=object)

# %%
df['airline']= df['airline'].map({'Air India':0, 'Vistara':1, 'SpiceJet':2, 'AirAsia':3, 'GO FIRST':4,
       'Indigo':5, 'Trujet':6, 'StarAir':7}).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300255 entries, 0 to 206773
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   airline            300255 non-null  int32
#  1   from               300255 non-null  object
#  2   stop               300255 non-null  int32
#  3   to                 300255 non-null  object
#  4   price              300255 non-null  int32
#  5   class              300255 non-null  int32
#  6   flight             300255 non-null  object
#  7   departure_time     300255 non-null  int32
#  8   arrival_time       300255 non-null  int32
#  9   days_left          300255 non-null  int32
#  10  duration           300255 non-null  int32
#  11  Travelling_Cities  300255 non-null  object
# dtypes: int32(8), object(4)
# memory usage: 20.6+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df['flight']=encoder.fit_transform(df['flight'])
df['Travelling_Cities']=encoder.fit_transform(df['Travelling_Cities'])

# %%
df.drop(['from','to'],axis=1,inplace =True)

# %%
df.head()
# Out:
#    airline  stop  price  class  flight  departure_time  arrival_time  \
# 0        0     0  25612      0     877               3             4
# 1        0     0  25612      0     795               3             4
# 2        0     1  42220      0     762               4             4
# 3        0     1  44450      0     871               4             4
# 4        0     1  46690      0     770               3             4
#
#    days_left  duration  Travelling_Cities
# 0          1       120                 14
# 1          1       135                 14
# 2          1      1485                 14
# 3          1      1590                 14
# 4          1       400                 14

# %%
X = df.drop(['price'],axis=1)
y = df['price']

# %% [markdown]
# # Test train Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.24, random_state=32)

# %% [markdown]
# # Model Implimentation

# %%
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error,mean_absolute_percentage_error
from xgboost import XGBRegressor
import math

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasRegressor

# %%
def predict(model):
    model.fit(X_train,y_train)
    training_score = model.score(X_train,y_train)
    y_predict =model.predict(X_test)
    score =r2_score(y_test,y_predict)
    mae = mean_absolute_error(y_test,y_predict)
    mse = mean_squared_error(y_test,y_predict)
    rmse= math.sqrt(mse)
  
    
    print(pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_predict}))
    
    print('Training score: ',training_score)
    print('r2 score is: ',score)
   
    print('MAE: ',mae)
    print('MSE: ',mse)
    print('RMSE: ',math.sqrt(mse))
    return sns.distplot(y_predict,color='r')

# %% [markdown]
# # Linear Regression

# %%
predict(LinearRegression())
# Out:
#         Real Values  Predicted Values
# 187265         3361       3011.933843
# 25128          3754       4624.807130
# 131095         5334        225.549231
# 81729          4249       7405.623076
# 12702         16210      15541.815404
# ...             ...               ...
# 114253         5322       7490.774650
# 23730         79024      56307.385363
# 20324         53152      54310.679232
# 118268         4687       6490.063210
# 134337         5102       2957.277813
#
# [72062 rows x 2 columns]
# Training score:  0.9036102974062656
# r2 score is:  0.9045047760391828
# MAE:  4603.164354368909
# MSE:  49097991.72501656
# RMSE:  7006.995913015546
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Decision Tree Regressor

# %%
predict(DecisionTreeRegressor(max_depth=50))
# Out:
#         Real Values  Predicted Values
# 187265         3361            3361.0
# 25128          3754            5027.0
# 131095         5334            4499.0
# 81729          4249            4348.0
# 12702         16210           16210.0
# ...             ...               ...
# 114253         5322            5322.0
# 23730         79024           74880.0
# 20324         53152           53152.0
# 118268         4687            4687.0
# 134337         5102            5102.0
#
# [72062 rows x 2 columns]
# Training score:  0.9999031033765581
# r2 score is:  0.9831983261707233
# MAE:  913.2917742129463
# MSE:  8638426.179038344
# RMSE:  2939.1199667652804
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Random Forest Regressor

# %%
predict(RandomForestRegressor(max_depth=20))
# Out:
#         Real Values  Predicted Values
# 187265         3361       3217.765544
# 25128          3754       4918.865006
# 131095         5334       4764.356534
# 81729          4249       4399.274307
# 12702         16210      13134.354500
# ...             ...               ...
# 114253         5322       5349.089273
# 23730         79024      82345.440308
# 20324         53152      54784.604900
# 118268         4687       4687.132391
# 134337         5102       5170.991842
#
# [72062 rows x 2 columns]
# Training score:  0.9968610029075194
# r2 score is:  0.9895664286304892
# MAE:  967.4848629095588
# MSE:  5364324.827101342
# RMSE:  2316.1012126203254
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # KNeighborsRegressor

# %%
predict(KNeighborsRegressor())
# Out:
#         Real Values  Predicted Values
# 187265         3361            3619.6
# 25128          3754            4542.0
# 131095         5334            4499.0
# 81729          4249           28995.8
# 12702         16210            9419.0
# ...             ...               ...
# 114253         5322           31452.4
# 23730         79024           37659.8
# 20324         53152           24934.0
# 118268         4687            4687.0
# 134337         5102           23169.6
#
# [72062 rows x 2 columns]
# Training score:  0.5405089863228241
# r2 score is:  0.31861384267731807
# MAE:  13648.05508034748
# MSE:  350328430.3254443
# RMSE:  18717.062545320627
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # ADAboost

# %%
predict(AdaBoostRegressor())
# Out:
#         Real Values  Predicted Values
# 187265         3361       5668.109135
# 25128          3754       5668.109135
# 131095         5334       4404.329929
# 81729          4249       6320.934406
# 12702         16210      10595.703589
# ...             ...               ...
# 114253         5322       6320.934406
# 23730         79024      59700.111857
# 20324         53152      59700.111857
# 118268         4687       5668.109135
# 134337         5102       6091.492340
#
# [72062 rows x 2 columns]
# Training score:  0.9303179913309871
# r2 score is:  0.9300286156041588
# MAE:  3899.3916050841103
# MSE:  35975144.19636909
# RMSE:  5997.928325377779
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Gradient Boost

# %%
predict(GradientBoostingRegressor(n_estimators=50,alpha=0.06,learning_rate=0.9))
# Out:
#         Real Values  Predicted Values
# 187265         3361       2649.805202
# 25128          3754       4767.415141
# 131095         5334       4372.365751
# 81729          4249       7952.931938
# 12702         16210       6054.080549
# ...             ...               ...
# 114253         5322       3114.584056
# 23730         79024      66066.786871
# 20324         53152      55432.074610
# 118268         4687       4237.890073
# 134337         5102       6442.792926
#
# [72062 rows x 2 columns]
# Training score:  0.967135919481818
# r2 score is:  0.9664567333917472
# MAE:  2566.163482930845
# MSE:  17245962.23825565
# RMSE:  4152.825813618439
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Lasso

# %%
predict(Lasso(alpha=0.1,normalize=True))
# Out:
#         Real Values  Predicted Values
# 187265         3361       3168.889352
# 25128          3754       4668.662153
# 131095         5334        219.184514
# 81729          4249       7410.974275
# 12702         16210      15384.452188
# ...             ...               ...
# 114253         5322       7536.598433
# 23730         79024      56128.976044
# 20324         53152      54172.579382
# 118268         4687       6560.112024
# 134337         5102       3331.132708
#
# [72062 rows x 2 columns]
# Training score:  0.9035511128970705
# r2 score is:  0.9044619170309466
# MAE:  4572.725274922526
# MSE:  49120027.29019398
# RMSE:  7008.56813409087
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Catboost

# %%
from catboost import CatBoostRegressor

# %%
predict(CatBoostRegressor(loss_function='RMSE',max_depth=10))
# Out:
# Learning rate set to 0.096559
# 0:	learn: 20651.8980105	total: 189ms	remaining: 3m 8s
# 1:	learn: 18838.9441221	total: 210ms	remaining: 1m 44s
# 2:	learn: 17197.3478003	total: 231ms	remaining: 1m 16s
# 3:	learn: 15745.6903917	total: 248ms	remaining: 1m 1s
# 4:	learn: 14419.8770693	total: 303ms	remaining: 1m
# 5:	learn: 13224.2162062	total: 353ms	remaining: 58.5s
# 6:	learn: 12168.8918040	total: 404ms	remaining: 57.2s
# 7:	learn: 11228.5870889	total: 452ms	remaining: 56s
# 8:	learn: 10398.8181691	total: 495ms	remaining: 54.5s
# 9:	learn: 9658.6744951	total: 534ms	remaining: 52.9s
# 10:	learn: 9028.0043308	total: 547ms	remaining: 49.2s
# 11:	learn: 8432.0898905	total: 581ms	remaining: 47.9s
# 12:	learn: 7927.8318279	total: 615ms	remaining: 46.7s
# 13:	learn: 7474.2509477	total: 648ms	remaining: 45.7s
# 14:	learn: 7073.0120798	total: 682ms	remaining: 44.8s
# 15:	learn: 6726.7693932	total: 717ms	remaining: 44.1s
# 16:	learn: 6436.9894226	total: 752ms	remaining: 43.5s
# 17:	learn: 6170.2656049	total: 785ms	remaining: 42.8s
# 18:	learn: 5950.4791132	total: 820ms	remaining: 42.4s
# 19:	learn: 5744.7342956	total: 857ms	remaining: 42s
# 20:	learn: 5570.2283178	total: 892ms	remaining: 41.6s
# 21:	learn: 5426.9907816	total: 926ms	remaining: 41.2s
# 22:	learn: 5294.9851485	total: 961ms	remaining: 40.8s
# 23:	learn: 5190.5345312	total: 994ms	remaining: 40.4s
# 24:	learn: 5097.3884271	total: 1.03s	remaining: 40.1s
# 25:	learn: 5016.9831398	total: 1.06s	remaining: 39.8s
# 26:	learn: 4933.4144145	total: 1.1s	remaining: 39.5s
# 27:	learn: 4858.6288911	total: 1.13s	remaining: 39.2s
# 28:	learn: 4804.3107118	total: 1.16s	remaining: 38.9s
# 29:	learn: 4750.7507027	total: 1.2s	remaining: 38.7s
# 30:	learn: 4695.7346865	total: 1.23s	remaining: 38.5s
# 31:	learn: 4649.8777924	total: 1.26s	remaining: 38.3s
# 32:	learn: 4613.6042236	total: 1.3s	remaining: 38.1s
# 33:	learn: 4580.3792184	total: 1.33s	remaining: 37.9s
# 34:	learn: 4547.4680243	total: 1.37s	remaining: 37.7s
# 35:	learn: 4525.1074855	total: 1.4s	remaining: 37.5s
# 36:	learn: 4492.7640465	total: 1.43s	remaining: 37.3s
# 37:	learn: 4453.6028797	total: 1.47s	remaining: 37.2s
# 38:	learn: 4421.0506916	total: 1.5s	remaining: 37s
# 39:	learn: 4401.0738819	total: 1.54s	remaining: 36.9s
# 40:	learn: 4383.6106199	total: 1.57s	remaining: 36.8s
# 41:	learn: 4361.4104191	total: 1.61s	remaining: 36.6s
# 42:	learn: 4332.8706899	total: 1.64s	remaining: 36.5s
# 43:	learn: 4316.0460032	total: 1.68s	remaining: 36.4s
# 44:	learn: 4296.4243469	total: 1.71s	remaining: 36.3s
# 45:	learn: 4280.6002493	total: 1.75s	remaining: 36.2s
# 46:	learn: 4258.8832565	total: 1.78s	remaining: 36.2s
# 47:	learn: 4243.7936977	total: 1.82s	remaining: 36.1s
# 48:	learn: 4224.6951486	total: 1.86s	remaining: 36s
# 49:	learn: 4206.3832262	total: 1.89s	remaining: 36s
# 50:	learn: 4195.5040511	total: 1.93s	remaining: 35.9s
# 51:	learn: 4181.6920762	total: 1.97s	remaining: 35.9s
# 52:	learn: 4166.0356267	total: 2.01s	remaining: 35.9s
# 53:	learn: 4155.3046567	total: 2.05s	remaining: 35.9s
# 54:	learn: 4149.6867917	total: 2.08s	remaining: 35.8s
# 55:	learn: 4140.7467467	total: 2.12s	remaining: 35.8s
# 56:	learn: 4125.0056018	total: 2.15s	remaining: 35.6s
# 57:	learn: 4109.9056058	total: 2.19s	remaining: 35.5s
# 58:	learn: 4094.7723438	total: 2.22s	remaining: 35.5s
# 59:	learn: 4088.8557225	total: 2.26s	remaining: 35.4s
# 60:	learn: 4079.4768764	total: 2.29s	remaining: 35.3s
# 61:	learn: 4064.6431019	total: 2.33s	remaining: 35.2s
# 62:	learn: 4052.7507641	total: 2.36s	remaining: 35.2s
# 63:	learn: 4040.4695943	total: 2.4s	remaining: 35.1s
# 64:	learn: 4030.4426493	total: 2.43s	remaining: 35s
# 65:	learn: 4019.9424951	total: 2.47s	remaining: 34.9s
# 66:	learn: 4011.4927643	total: 2.5s	remaining: 34.9s
# 67:	learn: 4006.3308928	total: 2.54s	remaining: 34.8s
# 68:	learn: 3999.5055092	total: 2.58s	remaining: 34.8s
# 69:	learn: 3993.2904367	total: 2.61s	remaining: 34.7s
# 70:	learn: 3986.6326059	total: 2.65s	remaining: 34.6s
# 71:	learn: 3974.0329700	total: 2.68s	remaining: 34.6s
# 72:	learn: 3963.1259689	total: 2.72s	remaining: 34.5s
# 73:	learn: 3950.2491778	total: 2.75s	remaining: 34.5s
# 74:	learn: 3944.3322102	total: 2.79s	remaining: 34.4s
# 75:	learn: 3933.8388695	total: 2.82s	remaining: 34.3s
# 76:	learn: 3920.5680188	total: 2.86s	remaining: 34.3s
# 77:	learn: 3910.7528409	total: 2.9s	remaining: 34.3s
# 78:	learn: 3901.3679644	total: 2.94s	remaining: 34.2s
# 79:	learn: 3892.8904324	total: 2.97s	remaining: 34.2s
# 80:	learn: 3884.8448580	total: 3.01s	remaining: 34.2s
# 81:	learn: 3877.3415256	total: 3.05s	remaining: 34.1s
# 82:	learn: 3865.7938550	total: 3.08s	remaining: 34.1s
# 83:	learn: 3860.3069827	total: 3.12s	remaining: 34s
# 84:	learn: 3855.2771512	total: 3.15s	remaining: 34s
# 85:	learn: 3851.2453241	total: 3.19s	remaining: 33.9s
# 86:	learn: 3845.6941517	total: 3.22s	remaining: 33.8s
# 87:	learn: 3833.6290232	total: 3.26s	remaining: 33.8s
# 88:	learn: 3819.7664460	total: 3.29s	remaining: 33.7s
# 89:	learn: 3814.9674858	total: 3.33s	remaining: 33.6s
# 90:	learn: 3807.5835589	total: 3.36s	remaining: 33.6s
# 91:	learn: 3802.2517380	total: 3.4s	remaining: 33.5s
# 92:	learn: 3797.3005068	total: 3.43s	remaining: 33.5s
# 93:	learn: 3784.6476904	total: 3.46s	remaining: 33.4s
# 94:	learn: 3776.7496059	total: 3.5s	remaining: 33.3s
# 95:	learn: 3772.9722375	total: 3.53s	remaining: 33.2s
# 96:	learn: 3769.5713357	total: 3.56s	remaining: 33.2s
# 97:	learn: 3756.6944864	total: 3.6s	remaining: 33.1s
# 98:	learn: 3749.0862339	total: 3.64s	remaining: 33.1s
# 99:	learn: 3743.7995941	total: 3.67s	remaining: 33s
# 100:	learn: 3738.3632759	total: 3.7s	remaining: 33s
# 101:	learn: 3723.3250436	total: 3.74s	remaining: 32.9s
# 102:	learn: 3717.8391978	total: 3.77s	remaining: 32.9s
# 103:	learn: 3712.3361525	total: 3.81s	remaining: 32.8s
# 104:	learn: 3701.4710351	total: 3.84s	remaining: 32.8s
# 105:	learn: 3691.8381224	total: 3.88s	remaining: 32.7s
# 106:	learn: 3683.7832626	total: 3.91s	remaining: 32.6s
# 107:	learn: 3677.7362699	total: 3.95s	remaining: 32.6s
# 108:	learn: 3671.9427225	total: 3.98s	remaining: 32.6s
# 109:	learn: 3662.6010136	total: 4.02s	remaining: 32.5s
# 110:	learn: 3658.4179547	total: 4.05s	remaining: 32.5s
# 111:	learn: 3654.3475994	total: 4.09s	remaining: 32.4s
# 112:	learn: 3645.1731821	total: 4.13s	remaining: 32.4s
# 113:	learn: 3639.1731170	total: 4.16s	remaining: 32.3s
# 114:	learn: 3632.8305990	total: 4.19s	remaining: 32.3s
# 115:	learn: 3631.0231854	total: 4.23s	remaining: 32.2s
# 116:	learn: 3618.3023680	total: 4.26s	remaining: 32.2s
# 117:	learn: 3614.4945236	total: 4.3s	remaining: 32.1s
# 118:	learn: 3607.0682131	total: 4.33s	remaining: 32.1s
# 119:	learn: 3595.4199472	total: 4.37s	remaining: 32.1s
# 120:	learn: 3589.7691582	total: 4.4s	remaining: 32s
# 121:	learn: 3584.9722015	total: 4.44s	remaining: 32s
# 122:	learn: 3579.0203786	total: 4.47s	remaining: 31.9s
# 123:	learn: 3573.8358028	total: 4.51s	remaining: 31.8s
# 124:	learn: 3567.0839057	total: 4.54s	remaining: 31.8s
# 125:	learn: 3561.7658003	total: 4.58s	remaining: 31.7s
# 126:	learn: 3558.2179579	total: 4.61s	remaining: 31.7s
# 127:	learn: 3552.8443733	total: 4.65s	remaining: 31.7s
# 128:	learn: 3551.0168523	total: 4.68s	remaining: 31.6s
# 129:	learn: 3548.4102001	total: 4.72s	remaining: 31.6s
# 130:	learn: 3540.2369730	total: 4.75s	remaining: 31.5s
# 131:	learn: 3537.5843307	total: 4.79s	remaining: 31.5s
# 132:	learn: 3532.3186567	total: 4.82s	remaining: 31.4s
# 133:	learn: 3529.4800640	total: 4.86s	remaining: 31.4s
# 134:	learn: 3524.5339792	total: 4.89s	remaining: 31.3s
# 135:	learn: 3516.0318644	total: 4.93s	remaining: 31.3s
# 136:	learn: 3510.9164726	total: 4.96s	remaining: 31.3s
# 137:	learn: 3508.2738005	total: 5s	remaining: 31.2s
# 138:	learn: 3506.0983292	total: 5.04s	remaining: 31.2s
# 139:	learn: 3502.6351291	total: 5.07s	remaining: 31.2s
# 140:	learn: 3495.6828613	total: 5.11s	remaining: 31.1s
# 141:	learn: 3490.8177737	total: 5.14s	remaining: 31.1s
# 142:	learn: 3481.5388548	total: 5.17s	remaining: 31s
# 143:	learn: 3472.7438657	total: 5.21s	remaining: 31s
# 144:	learn: 3471.2689730	total: 5.23s	remaining: 30.8s
# 145:	learn: 3467.3199454	total: 5.26s	remaining: 30.8s
# 146:	learn: 3462.1932842	total: 5.3s	remaining: 30.7s
# 147:	learn: 3456.9084076	total: 5.33s	remaining: 30.7s
# 148:	learn: 3453.1385928	total: 5.37s	remaining: 30.7s
# 149:	learn: 3449.4402283	total: 5.4s	remaining: 30.6s
# 150:	learn: 3444.8842286	total: 5.44s	remaining: 30.6s
# 151:	learn: 3441.4592790	total: 5.47s	remaining: 30.5s
# 152:	learn: 3434.8470032	total: 5.51s	remaining: 30.5s
# 153:	learn: 3427.6880820	total: 5.54s	remaining: 30.4s
# 154:	learn: 3424.0493736	total: 5.58s	remaining: 30.4s
# 155:	learn: 3420.3736244	total: 5.61s	remaining: 30.4s
# 156:	learn: 3412.2914316	total: 5.64s	remaining: 30.3s
# 157:	learn: 3405.8987829	total: 5.68s	remaining: 30.3s
# 158:	learn: 3401.2232244	total: 5.71s	remaining: 30.2s
# 159:	learn: 3396.8863530	total: 5.75s	remaining: 30.2s
# 160:	learn: 3391.5309730	total: 5.79s	remaining: 30.1s
# 161:	learn: 3389.7276038	total: 5.82s	remaining: 30.1s
# 162:	learn: 3384.3553477	total: 5.85s	remaining: 30.1s
# 163:	learn: 3381.2706082	total: 5.89s	remaining: 30s
# 164:	learn: 3376.8305443	total: 5.92s	remaining: 30s
# 165:	learn: 3373.0355975	total: 5.96s	remaining: 29.9s
# 166:	learn: 3368.5706051	total: 5.99s	remaining: 29.9s
# 167:	learn: 3362.5981033	total: 6.03s	remaining: 29.8s
# 168:	learn: 3361.1435147	total: 6.06s	remaining: 29.8s
# 169:	learn: 3358.4148714	total: 6.09s	remaining: 29.8s
# 170:	learn: 3355.9359783	total: 6.13s	remaining: 29.7s
# 171:	learn: 3352.3405977	total: 6.16s	remaining: 29.7s
# 172:	learn: 3349.2206064	total: 6.2s	remaining: 29.6s
# 173:	learn: 3343.0079580	total: 6.23s	remaining: 29.6s
# 174:	learn: 3340.3492344	total: 6.27s	remaining: 29.6s
# 175:	learn: 3338.4158388	total: 6.31s	remaining: 29.5s
# 176:	learn: 3335.7203789	total: 6.34s	remaining: 29.5s
# 177:	learn: 3332.4722372	total: 6.38s	remaining: 29.4s
# 178:	learn: 3329.2371438	total: 6.41s	remaining: 29.4s
# 179:	learn: 3323.6958856	total: 6.44s	remaining: 29.4s
# 180:	learn: 3318.9613125	total: 6.48s	remaining: 29.3s
# 181:	learn: 3315.5952262	total: 6.51s	remaining: 29.3s
# 182:	learn: 3312.7920183	total: 6.55s	remaining: 29.2s
# 183:	learn: 3311.8037271	total: 6.56s	remaining: 29.1s
# 184:	learn: 3307.0802460	total: 6.6s	remaining: 29.1s
# 185:	learn: 3302.6838435	total: 6.63s	remaining: 29s
# 186:	learn: 3297.7550316	total: 6.67s	remaining: 29s
# 187:	learn: 3296.2085916	total: 6.7s	remaining: 28.9s
# 188:	learn: 3290.2034998	total: 6.74s	remaining: 28.9s
# 189:	learn: 3284.8990896	total: 6.77s	remaining: 28.9s
# 190:	learn: 3282.5253736	total: 6.81s	remaining: 28.8s
# 191:	learn: 3278.9567931	total: 6.85s	remaining: 28.8s
# 192:	learn: 3274.4279993	total: 6.88s	remaining: 28.8s
# 193:	learn: 3270.6693495	total: 6.92s	remaining: 28.7s
# 194:	learn: 3268.0246885	total: 6.95s	remaining: 28.7s
# 195:	learn: 3264.4693584	total: 6.99s	remaining: 28.7s
# 196:	learn: 3260.9394599	total: 7.02s	remaining: 28.6s
# 197:	learn: 3257.9865243	total: 7.06s	remaining: 28.6s
# 198:	learn: 3255.3174731	total: 7.09s	remaining: 28.5s
# 199:	learn: 3252.0460273	total: 7.12s	remaining: 28.5s
# 200:	learn: 3248.4203163	total: 7.16s	remaining: 28.5s
# 201:	learn: 3245.2338830	total: 7.19s	remaining: 28.4s
# 202:	learn: 3242.1508499	total: 7.23s	remaining: 28.4s
# 203:	learn: 3239.4147787	total: 7.26s	remaining: 28.3s
# 204:	learn: 3235.5942463	total: 7.3s	remaining: 28.3s
# 205:	learn: 3232.9090048	total: 7.33s	remaining: 28.3s
# 206:	learn: 3231.5267443	total: 7.37s	remaining: 28.2s
# 207:	learn: 3227.9095305	total: 7.4s	remaining: 28.2s
# 208:	learn: 3224.7375808	total: 7.43s	remaining: 28.1s
# 209:	learn: 3223.1257158	total: 7.47s	remaining: 28.1s
# 210:	learn: 3219.1753980	total: 7.5s	remaining: 28.1s
# 211:	learn: 3214.0070927	total: 7.54s	remaining: 28s
# 212:	learn: 3212.7416388	total: 7.57s	remaining: 28s
# 213:	learn: 3209.0952883	total: 7.61s	remaining: 27.9s
# 214:	learn: 3207.2899990	total: 7.64s	remaining: 27.9s
# 215:	learn: 3205.5435393	total: 7.67s	remaining: 27.9s
# 216:	learn: 3201.1965827	total: 7.71s	remaining: 27.8s
# 217:	learn: 3196.2564046	total: 7.74s	remaining: 27.8s
# 218:	learn: 3194.5619949	total: 7.78s	remaining: 27.7s
# 219:	learn: 3191.4177965	total: 7.81s	remaining: 27.7s
# 220:	learn: 3188.3601408	total: 7.85s	remaining: 27.7s
# 221:	learn: 3185.9476831	total: 7.88s	remaining: 27.6s
# 222:	learn: 3183.3969785	total: 7.92s	remaining: 27.6s
# 223:	learn: 3181.9297626	total: 7.95s	remaining: 27.5s
# 224:	learn: 3179.4782119	total: 7.99s	remaining: 27.5s
# 225:	learn: 3176.8253070	total: 8.02s	remaining: 27.5s
# 226:	learn: 3174.8167211	total: 8.06s	remaining: 27.4s
# 227:	learn: 3171.2582635	total: 8.09s	remaining: 27.4s
# 228:	learn: 3168.3145457	total: 8.12s	remaining: 27.4s
# 229:	learn: 3166.5648728	total: 8.16s	remaining: 27.3s
# 230:	learn: 3162.4997930	total: 8.19s	remaining: 27.3s
# 231:	learn: 3159.5383853	total: 8.23s	remaining: 27.2s
# 232:	learn: 3157.6503490	total: 8.26s	remaining: 27.2s
# 233:	learn: 3155.6729657	total: 8.3s	remaining: 27.2s
# 234:	learn: 3154.2816771	total: 8.33s	remaining: 27.1s
# 235:	learn: 3150.9686082	total: 8.37s	remaining: 27.1s
# 236:	learn: 3149.1417750	total: 8.4s	remaining: 27s
# 237:	learn: 3146.8509087	total: 8.44s	remaining: 27s
# 238:	learn: 3138.6593721	total: 8.47s	remaining: 27s
# 239:	learn: 3137.0550766	total: 8.51s	remaining: 26.9s
# 240:	learn: 3135.5463056	total: 8.54s	remaining: 26.9s
# 241:	learn: 3129.7329139	total: 8.57s	remaining: 26.9s
# 242:	learn: 3127.8429388	total: 8.61s	remaining: 26.8s
# 243:	learn: 3124.1025839	total: 8.64s	remaining: 26.8s
# 244:	learn: 3121.7290229	total: 8.68s	remaining: 26.7s
# 245:	learn: 3116.9357376	total: 8.71s	remaining: 26.7s
# 246:	learn: 3113.7989840	total: 8.74s	remaining: 26.7s
# 247:	learn: 3112.0753430	total: 8.78s	remaining: 26.6s
# 248:	learn: 3107.5050001	total: 8.81s	remaining: 26.6s
# 249:	learn: 3107.1571299	total: 8.84s	remaining: 26.5s
# 250:	learn: 3105.7698928	total: 8.88s	remaining: 26.5s
# 251:	learn: 3103.3853252	total: 8.91s	remaining: 26.4s
# 252:	learn: 3100.6809844	total: 8.95s	remaining: 26.4s
# 253:	learn: 3098.6418843	total: 8.98s	remaining: 26.4s
# 254:	learn: 3095.1406439	total: 9.01s	remaining: 26.3s
# 255:	learn: 3092.9311169	total: 9.05s	remaining: 26.3s
# 256:	learn: 3088.8770413	total: 9.08s	remaining: 26.3s
# 257:	learn: 3086.5031731	total: 9.12s	remaining: 26.2s
# 258:	learn: 3084.1617692	total: 9.15s	remaining: 26.2s
# 259:	learn: 3081.9658858	total: 9.19s	remaining: 26.1s
# 260:	learn: 3078.5511075	total: 9.22s	remaining: 26.1s
# 261:	learn: 3076.4975327	total: 9.26s	remaining: 26.1s
# 262:	learn: 3073.2533570	total: 9.29s	remaining: 26s
# 263:	learn: 3072.2586733	total: 9.32s	remaining: 26s
# 264:	learn: 3069.5441101	total: 9.36s	remaining: 26s
# 265:	learn: 3065.5501919	total: 9.39s	remaining: 25.9s
# 266:	learn: 3058.0732892	total: 9.43s	remaining: 25.9s
# 267:	learn: 3054.5720834	total: 9.46s	remaining: 25.8s
# 268:	learn: 3052.7765585	total: 9.49s	remaining: 25.8s
# 269:	learn: 3050.0348923	total: 9.53s	remaining: 25.8s
# 270:	learn: 3047.1844982	total: 9.56s	remaining: 25.7s
# 271:	learn: 3044.0578798	total: 9.6s	remaining: 25.7s
# 272:	learn: 3040.6969104	total: 9.63s	remaining: 25.6s
# 273:	learn: 3038.5036270	total: 9.66s	remaining: 25.6s
# 274:	learn: 3036.2149387	total: 9.7s	remaining: 25.6s
# 275:	learn: 3034.1279346	total: 9.73s	remaining: 25.5s
# 276:	learn: 3032.5481507	total: 9.77s	remaining: 25.5s
# 277:	learn: 3031.2470089	total: 9.8s	remaining: 25.5s
# 278:	learn: 3028.7599230	total: 9.84s	remaining: 25.4s
# 279:	learn: 3026.3834146	total: 9.87s	remaining: 25.4s
# 280:	learn: 3024.9963944	total: 9.91s	remaining: 25.4s
# 281:	learn: 3023.5441747	total: 9.94s	remaining: 25.3s
# 282:	learn: 3020.3817804	total: 9.98s	remaining: 25.3s
# 283:	learn: 3016.9833278	total: 10s	remaining: 25.2s
# 284:	learn: 3014.6620674	total: 10s	remaining: 25.2s
# 285:	learn: 3012.2351781	total: 10.1s	remaining: 25.2s
# 286:	learn: 3009.2653926	total: 10.1s	remaining: 25.1s
# 287:	learn: 3008.5076697	total: 10.2s	remaining: 25.1s
# 288:	learn: 3005.4262510	total: 10.2s	remaining: 25.1s
# 289:	learn: 3002.4313791	total: 10.2s	remaining: 25s
# 290:	learn: 3000.3216480	total: 10.3s	remaining: 25s
# 291:	learn: 2999.2361433	total: 10.3s	remaining: 25s
# 292:	learn: 2995.7610613	total: 10.3s	remaining: 24.9s
# 293:	learn: 2994.0402490	total: 10.4s	remaining: 24.9s
# 294:	learn: 2992.5395631	total: 10.4s	remaining: 24.9s
# 295:	learn: 2991.0925461	total: 10.4s	remaining: 24.8s
# 296:	learn: 2989.2838031	total: 10.5s	remaining: 24.8s
# 297:	learn: 2985.6539099	total: 10.5s	remaining: 24.7s
# 298:	learn: 2983.2446004	total: 10.5s	remaining: 24.7s
# 299:	learn: 2981.0003811	total: 10.6s	remaining: 24.7s
# 300:	learn: 2978.8691522	total: 10.6s	remaining: 24.6s
# 301:	learn: 2977.7141693	total: 10.6s	remaining: 24.6s
# 302:	learn: 2974.6832883	total: 10.7s	remaining: 24.6s
# 303:	learn: 2973.1655843	total: 10.7s	remaining: 24.5s
# 304:	learn: 2971.4168016	total: 10.8s	remaining: 24.5s
# 305:	learn: 2969.6798078	total: 10.8s	remaining: 24.5s
# 306:	learn: 2968.7500980	total: 10.8s	remaining: 24.4s
# 307:	learn: 2966.4352102	total: 10.9s	remaining: 24.4s
# 308:	learn: 2964.8730964	total: 10.9s	remaining: 24.4s
# 309:	learn: 2964.1574062	total: 10.9s	remaining: 24.3s
# 310:	learn: 2962.4823809	total: 11s	remaining: 24.3s
# 311:	learn: 2961.0261904	total: 11s	remaining: 24.3s
# 312:	learn: 2958.9120896	total: 11s	remaining: 24.2s
# 313:	learn: 2957.8661551	total: 11.1s	remaining: 24.2s
# 314:	learn: 2957.3883910	total: 11.1s	remaining: 24.1s
# 315:	learn: 2954.5611163	total: 11.1s	remaining: 24.1s
# 316:	learn: 2952.9165531	total: 11.2s	remaining: 24.1s
# 317:	learn: 2950.8116434	total: 11.2s	remaining: 24s
# 318:	learn: 2947.9320353	total: 11.2s	remaining: 24s
# 319:	learn: 2946.0197346	total: 11.3s	remaining: 24s
# 320:	learn: 2944.1133010	total: 11.3s	remaining: 23.9s
# 321:	learn: 2941.8459509	total: 11.3s	remaining: 23.9s
# 322:	learn: 2940.3070955	total: 11.4s	remaining: 23.9s
# 323:	learn: 2938.3378468	total: 11.4s	remaining: 23.8s
# 324:	learn: 2937.5676291	total: 11.4s	remaining: 23.8s
# 325:	learn: 2935.7781785	total: 11.5s	remaining: 23.7s
# 326:	learn: 2933.6460913	total: 11.5s	remaining: 23.7s
# 327:	learn: 2932.3589183	total: 11.6s	remaining: 23.7s
# 328:	learn: 2930.8148491	total: 11.6s	remaining: 23.6s
# 329:	learn: 2929.5927767	total: 11.6s	remaining: 23.6s
# 330:	learn: 2928.3292049	total: 11.7s	remaining: 23.6s
# 331:	learn: 2926.6679173	total: 11.7s	remaining: 23.5s
# 332:	learn: 2924.9206706	total: 11.7s	remaining: 23.5s
# 333:	learn: 2923.5103007	total: 11.8s	remaining: 23.4s
# 334:	learn: 2921.8625210	total: 11.8s	remaining: 23.4s
# 335:	learn: 2921.1677453	total: 11.8s	remaining: 23.4s
# 336:	learn: 2920.1216065	total: 11.9s	remaining: 23.3s
# 337:	learn: 2917.6111281	total: 11.9s	remaining: 23.3s
# 338:	learn: 2916.6643416	total: 11.9s	remaining: 23.3s
# 339:	learn: 2914.9276976	total: 12s	remaining: 23.2s
# 340:	learn: 2913.6162290	total: 12s	remaining: 23.2s
# 341:	learn: 2911.8254435	total: 12s	remaining: 23.2s
# 342:	learn: 2910.2254660	total: 12.1s	remaining: 23.1s
# 343:	learn: 2907.4563664	total: 12.1s	remaining: 23.1s
# 344:	learn: 2906.4113104	total: 12.1s	remaining: 23s
# 345:	learn: 2903.7345687	total: 12.2s	remaining: 23s
# 346:	learn: 2902.6465841	total: 12.2s	remaining: 23s
# 347:	learn: 2901.9993236	total: 12.2s	remaining: 22.9s
# 348:	learn: 2899.7741668	total: 12.3s	remaining: 22.9s
# 349:	learn: 2897.8271455	total: 12.3s	remaining: 22.9s
# 350:	learn: 2895.3850729	total: 12.3s	remaining: 22.8s
# 351:	learn: 2893.1353696	total: 12.4s	remaining: 22.8s
# 352:	learn: 2892.3615835	total: 12.4s	remaining: 22.8s
# 353:	learn: 2891.1506808	total: 12.5s	remaining: 22.7s
# 354:	learn: 2888.6420059	total: 12.5s	remaining: 22.7s
# 355:	learn: 2887.7393114	total: 12.5s	remaining: 22.7s
# 356:	learn: 2886.0150149	total: 12.6s	remaining: 22.6s
# 357:	learn: 2884.0167292	total: 12.6s	remaining: 22.6s
# 358:	learn: 2881.2918323	total: 12.6s	remaining: 22.6s
# 359:	learn: 2879.3462570	total: 12.7s	remaining: 22.5s
# 360:	learn: 2877.7435140	total: 12.7s	remaining: 22.5s
# 361:	learn: 2875.4675816	total: 12.7s	remaining: 22.4s
# 362:	learn: 2874.5299712	total: 12.8s	remaining: 22.4s
# 363:	learn: 2873.0209659	total: 12.8s	remaining: 22.4s
# 364:	learn: 2871.4675889	total: 12.8s	remaining: 22.3s
# 365:	learn: 2869.7630919	total: 12.9s	remaining: 22.3s
# 366:	learn: 2868.2942037	total: 12.9s	remaining: 22.3s
# 367:	learn: 2866.2849738	total: 12.9s	remaining: 22.2s
# 368:	learn: 2864.2543729	total: 13s	remaining: 22.2s
# 369:	learn: 2863.0171429	total: 13s	remaining: 22.1s
# 370:	learn: 2861.7966947	total: 13s	remaining: 22.1s
# 371:	learn: 2860.3480192	total: 13.1s	remaining: 22.1s
# 372:	learn: 2858.8005499	total: 13.1s	remaining: 22s
# 373:	learn: 2857.1876738	total: 13.1s	remaining: 22s
# 374:	learn: 2855.9758189	total: 13.2s	remaining: 22s
# 375:	learn: 2854.0307954	total: 13.2s	remaining: 21.9s
# 376:	learn: 2851.8356610	total: 13.2s	remaining: 21.9s
# 377:	learn: 2849.7410632	total: 13.3s	remaining: 21.9s
# 378:	learn: 2845.9337170	total: 13.3s	remaining: 21.8s
# 379:	learn: 2844.3701928	total: 13.3s	remaining: 21.8s
# 380:	learn: 2842.9117612	total: 13.4s	remaining: 21.7s
# 381:	learn: 2842.0051863	total: 13.4s	remaining: 21.7s
# 382:	learn: 2840.5734076	total: 13.5s	remaining: 21.7s
# 383:	learn: 2838.6535604	total: 13.5s	remaining: 21.6s
# 384:	learn: 2834.9072931	total: 13.5s	remaining: 21.6s
# 385:	learn: 2833.4628654	total: 13.6s	remaining: 21.6s
# 386:	learn: 2831.3327098	total: 13.6s	remaining: 21.5s
# 387:	learn: 2829.3910630	total: 13.6s	remaining: 21.5s
# 388:	learn: 2826.7856236	total: 13.7s	remaining: 21.5s
# 389:	learn: 2825.1705734	total: 13.7s	remaining: 21.4s
# 390:	learn: 2823.3324293	total: 13.7s	remaining: 21.4s
# 391:	learn: 2822.2530027	total: 13.8s	remaining: 21.3s
# 392:	learn: 2820.8412041	total: 13.8s	remaining: 21.3s
# 393:	learn: 2818.9736066	total: 13.8s	remaining: 21.3s
# 394:	learn: 2817.2511003	total: 13.9s	remaining: 21.2s
# 395:	learn: 2816.3049560	total: 13.9s	remaining: 21.2s
# 396:	learn: 2814.7027564	total: 13.9s	remaining: 21.2s
# 397:	learn: 2812.7538865	total: 14s	remaining: 21.1s
# 398:	learn: 2811.1602287	total: 14s	remaining: 21.1s
# 399:	learn: 2809.7193621	total: 14s	remaining: 21.1s
# 400:	learn: 2807.9675982	total: 14.1s	remaining: 21s
# 401:	learn: 2806.4612438	total: 14.1s	remaining: 21s
# 402:	learn: 2805.6980798	total: 14.1s	remaining: 21s
# 403:	learn: 2804.1167400	total: 14.2s	remaining: 20.9s
# 404:	learn: 2802.6814887	total: 14.2s	remaining: 20.9s
# 405:	learn: 2801.5935577	total: 14.2s	remaining: 20.8s
# 406:	learn: 2797.7753886	total: 14.3s	remaining: 20.8s
# 407:	learn: 2797.1226786	total: 14.3s	remaining: 20.8s
# 408:	learn: 2796.3828912	total: 14.4s	remaining: 20.7s
# 409:	learn: 2794.1951303	total: 14.4s	remaining: 20.7s
# 410:	learn: 2792.5865837	total: 14.4s	remaining: 20.7s
# 411:	learn: 2790.7866403	total: 14.5s	remaining: 20.6s
# 412:	learn: 2789.8314708	total: 14.5s	remaining: 20.6s
# 413:	learn: 2788.0496495	total: 14.5s	remaining: 20.6s
# 414:	learn: 2785.8381487	total: 14.6s	remaining: 20.5s
# 415:	learn: 2784.7215869	total: 14.6s	remaining: 20.5s
# 416:	learn: 2783.7387356	total: 14.6s	remaining: 20.4s
# 417:	learn: 2780.8602621	total: 14.7s	remaining: 20.4s
# 418:	learn: 2779.2595239	total: 14.7s	remaining: 20.4s
# 419:	learn: 2777.7278316	total: 14.7s	remaining: 20.3s
# 420:	learn: 2776.8146897	total: 14.8s	remaining: 20.3s
# 421:	learn: 2774.9008910	total: 14.8s	remaining: 20.3s
# 422:	learn: 2773.3473949	total: 14.8s	remaining: 20.2s
# 423:	learn: 2771.8001714	total: 14.9s	remaining: 20.2s
# 424:	learn: 2770.0865790	total: 14.9s	remaining: 20.2s
# 425:	learn: 2768.6900278	total: 14.9s	remaining: 20.1s
# 426:	learn: 2767.2060178	total: 15s	remaining: 20.1s
# 427:	learn: 2765.9150136	total: 15s	remaining: 20.1s
# 428:	learn: 2764.8451457	total: 15s	remaining: 20s
# 429:	learn: 2764.1374529	total: 15.1s	remaining: 20s
# 430:	learn: 2762.4198251	total: 15.1s	remaining: 19.9s
# 431:	learn: 2761.7164506	total: 15.1s	remaining: 19.9s
# 432:	learn: 2760.5466615	total: 15.2s	remaining: 19.9s
# 433:	learn: 2759.4811492	total: 15.2s	remaining: 19.8s
# 434:	learn: 2758.3076059	total: 15.2s	remaining: 19.8s
# 435:	learn: 2756.2293995	total: 15.3s	remaining: 19.8s
# 436:	learn: 2754.9222471	total: 15.3s	remaining: 19.7s
# 437:	learn: 2753.9290511	total: 15.3s	remaining: 19.7s
# 438:	learn: 2753.2543107	total: 15.4s	remaining: 19.7s
# 439:	learn: 2751.8452746	total: 15.4s	remaining: 19.6s
# 440:	learn: 2750.2041871	total: 15.5s	remaining: 19.6s
# 441:	learn: 2748.2132894	total: 15.5s	remaining: 19.6s
# 442:	learn: 2747.6634282	total: 15.5s	remaining: 19.5s
# 443:	learn: 2746.5930240	total: 15.6s	remaining: 19.5s
# 444:	learn: 2745.9203850	total: 15.6s	remaining: 19.5s
# 445:	learn: 2744.4655560	total: 15.6s	remaining: 19.4s
# 446:	learn: 2743.7955782	total: 15.7s	remaining: 19.4s
# 447:	learn: 2742.8040661	total: 15.7s	remaining: 19.3s
# 448:	learn: 2741.2429790	total: 15.7s	remaining: 19.3s
# 449:	learn: 2739.5701021	total: 15.8s	remaining: 19.3s
# 450:	learn: 2735.3838180	total: 15.8s	remaining: 19.2s
# 451:	learn: 2734.3163335	total: 15.8s	remaining: 19.2s
# 452:	learn: 2732.7886616	total: 15.9s	remaining: 19.2s
# 453:	learn: 2731.1348624	total: 15.9s	remaining: 19.1s
# 454:	learn: 2730.1903543	total: 15.9s	remaining: 19.1s
# 455:	learn: 2729.1135203	total: 16s	remaining: 19.1s
# 456:	learn: 2727.4549398	total: 16s	remaining: 19s
# 457:	learn: 2725.2986431	total: 16s	remaining: 19s
# 458:	learn: 2723.4834363	total: 16.1s	remaining: 19s
# 459:	learn: 2721.1333086	total: 16.1s	remaining: 18.9s
# 460:	learn: 2720.1558220	total: 16.2s	remaining: 18.9s
# 461:	learn: 2718.5274630	total: 16.2s	remaining: 18.9s
# 462:	learn: 2717.2730607	total: 16.2s	remaining: 18.8s
# 463:	learn: 2715.1643804	total: 16.3s	remaining: 18.8s
# 464:	learn: 2714.3662307	total: 16.3s	remaining: 18.7s
# 465:	learn: 2712.5914894	total: 16.3s	remaining: 18.7s
# 466:	learn: 2711.0772882	total: 16.4s	remaining: 18.7s
# 467:	learn: 2710.0468157	total: 16.4s	remaining: 18.6s
# 468:	learn: 2708.7436717	total: 16.4s	remaining: 18.6s
# 469:	learn: 2708.0169739	total: 16.5s	remaining: 18.6s
# 470:	learn: 2706.2319425	total: 16.5s	remaining: 18.5s
# 471:	learn: 2705.1054317	total: 16.5s	remaining: 18.5s
# 472:	learn: 2704.0893607	total: 16.6s	remaining: 18.5s
# 473:	learn: 2703.1938951	total: 16.6s	remaining: 18.4s
# 474:	learn: 2702.3106587	total: 16.6s	remaining: 18.4s
# 475:	learn: 2701.0895250	total: 16.7s	remaining: 18.3s
# 476:	learn: 2699.4377844	total: 16.7s	remaining: 18.3s
# 477:	learn: 2698.8194857	total: 16.7s	remaining: 18.3s
# 478:	learn: 2697.3320211	total: 16.8s	remaining: 18.2s
# 479:	learn: 2695.8081227	total: 16.8s	remaining: 18.2s
# 480:	learn: 2694.7259878	total: 16.8s	remaining: 18.2s
# 481:	learn: 2693.3353303	total: 16.9s	remaining: 18.1s
# 482:	learn: 2692.7380746	total: 16.9s	remaining: 18.1s
# 483:	learn: 2691.9144702	total: 16.9s	remaining: 18.1s
# 484:	learn: 2690.7741482	total: 17s	remaining: 18s
# 485:	learn: 2689.5562114	total: 17s	remaining: 18s
# 486:	learn: 2688.0522201	total: 17.1s	remaining: 18s
# 487:	learn: 2686.4801775	total: 17.1s	remaining: 17.9s
# 488:	learn: 2685.8056834	total: 17.1s	remaining: 17.9s
# 489:	learn: 2684.8041550	total: 17.2s	remaining: 17.9s
# 490:	learn: 2682.7505270	total: 17.2s	remaining: 17.8s
# 491:	learn: 2681.3088200	total: 17.2s	remaining: 17.8s
# 492:	learn: 2680.2346683	total: 17.3s	remaining: 17.7s
# 493:	learn: 2677.9538256	total: 17.3s	remaining: 17.7s
# 494:	learn: 2676.4503219	total: 17.3s	remaining: 17.7s
# 495:	learn: 2674.9184345	total: 17.4s	remaining: 17.6s
# 496:	learn: 2673.9005060	total: 17.4s	remaining: 17.6s
# 497:	learn: 2672.6416944	total: 17.4s	remaining: 17.6s
# 498:	learn: 2670.8937110	total: 17.5s	remaining: 17.5s
# 499:	learn: 2669.4529463	total: 17.5s	remaining: 17.5s
# 500:	learn: 2669.0344150	total: 17.5s	remaining: 17.5s
# 501:	learn: 2667.9709039	total: 17.6s	remaining: 17.4s
# 502:	learn: 2666.5829175	total: 17.6s	remaining: 17.4s
# 503:	learn: 2665.9693352	total: 17.6s	remaining: 17.4s
# 504:	learn: 2664.8795078	total: 17.7s	remaining: 17.3s
# 505:	learn: 2661.5720623	total: 17.7s	remaining: 17.3s
# 506:	learn: 2659.6519934	total: 17.7s	remaining: 17.3s
# 507:	learn: 2657.7560016	total: 17.8s	remaining: 17.2s
# 508:	learn: 2657.2628115	total: 17.8s	remaining: 17.2s
# 509:	learn: 2656.2147580	total: 17.9s	remaining: 17.2s
# 510:	learn: 2654.8411335	total: 17.9s	remaining: 17.1s
# 511:	learn: 2653.7870632	total: 17.9s	remaining: 17.1s
# 512:	learn: 2651.6379498	total: 18s	remaining: 17.1s
# 513:	learn: 2651.1843589	total: 18s	remaining: 17s
# 514:	learn: 2650.4146907	total: 18s	remaining: 17s
# 515:	learn: 2649.4188087	total: 18.1s	remaining: 16.9s
# 516:	learn: 2647.5291504	total: 18.1s	remaining: 16.9s
# 517:	learn: 2645.3644325	total: 18.1s	remaining: 16.9s
# 518:	learn: 2644.7782434	total: 18.2s	remaining: 16.8s
# 519:	learn: 2643.7649578	total: 18.2s	remaining: 16.8s
# 520:	learn: 2643.0455534	total: 18.2s	remaining: 16.8s
# 521:	learn: 2641.6850419	total: 18.3s	remaining: 16.7s
# 522:	learn: 2640.5790839	total: 18.3s	remaining: 16.7s
# 523:	learn: 2639.4934622	total: 18.3s	remaining: 16.7s
# 524:	learn: 2638.3824296	total: 18.4s	remaining: 16.6s
# 525:	learn: 2637.6641961	total: 18.4s	remaining: 16.6s
# 526:	learn: 2636.1104327	total: 18.4s	remaining: 16.6s
# 527:	learn: 2634.9120717	total: 18.5s	remaining: 16.5s
# 528:	learn: 2632.6709627	total: 18.5s	remaining: 16.5s
# 529:	learn: 2631.7148497	total: 18.6s	remaining: 16.5s
# 530:	learn: 2631.3309920	total: 18.6s	remaining: 16.4s
# 531:	learn: 2629.0783540	total: 18.6s	remaining: 16.4s
# 532:	learn: 2627.9417098	total: 18.7s	remaining: 16.3s
# 533:	learn: 2627.1240766	total: 18.7s	remaining: 16.3s
# 534:	learn: 2624.9487119	total: 18.7s	remaining: 16.3s
# 535:	learn: 2624.3973470	total: 18.8s	remaining: 16.2s
# 536:	learn: 2623.7454457	total: 18.8s	remaining: 16.2s
# 537:	learn: 2621.4388479	total: 18.8s	remaining: 16.2s
# 538:	learn: 2620.6024516	total: 18.9s	remaining: 16.1s
# 539:	learn: 2619.3263429	total: 18.9s	remaining: 16.1s
# 540:	learn: 2618.0753257	total: 18.9s	remaining: 16.1s
# 541:	learn: 2616.6606534	total: 19s	remaining: 16s
# 542:	learn: 2615.5970544	total: 19s	remaining: 16s
# 543:	learn: 2614.2582643	total: 19s	remaining: 16s
# 544:	learn: 2613.5477618	total: 19.1s	remaining: 15.9s
# 545:	learn: 2612.8028019	total: 19.1s	remaining: 15.9s
# 546:	learn: 2611.7233871	total: 19.1s	remaining: 15.9s
# 547:	learn: 2610.7899042	total: 19.2s	remaining: 15.8s
# 548:	learn: 2609.9911497	total: 19.2s	remaining: 15.8s
# 549:	learn: 2609.1303142	total: 19.2s	remaining: 15.7s
# 550:	learn: 2608.1439975	total: 19.3s	remaining: 15.7s
# 551:	learn: 2605.9840963	total: 19.3s	remaining: 15.7s
# 552:	learn: 2604.8875313	total: 19.4s	remaining: 15.6s
# 553:	learn: 2603.6911462	total: 19.4s	remaining: 15.6s
# 554:	learn: 2602.9808215	total: 19.4s	remaining: 15.6s
# 555:	learn: 2601.7167045	total: 19.5s	remaining: 15.5s
# 556:	learn: 2601.0434586	total: 19.5s	remaining: 15.5s
# 557:	learn: 2599.5939987	total: 19.5s	remaining: 15.5s
# 558:	learn: 2598.8264996	total: 19.6s	remaining: 15.4s
# 559:	learn: 2597.5341287	total: 19.6s	remaining: 15.4s
# 560:	learn: 2595.9803561	total: 19.6s	remaining: 15.4s
# 561:	learn: 2595.0166694	total: 19.7s	remaining: 15.3s
# 562:	learn: 2593.7184027	total: 19.7s	remaining: 15.3s
# 563:	learn: 2592.8418009	total: 19.8s	remaining: 15.3s
# 564:	learn: 2591.5357725	total: 19.8s	remaining: 15.2s
# 565:	learn: 2590.9163164	total: 19.8s	remaining: 15.2s
# 566:	learn: 2590.5520646	total: 19.9s	remaining: 15.2s
# 567:	learn: 2588.8797084	total: 19.9s	remaining: 15.1s
# 568:	learn: 2588.2171360	total: 19.9s	remaining: 15.1s
# 569:	learn: 2587.1012765	total: 20s	remaining: 15.1s
# 570:	learn: 2585.1972296	total: 20s	remaining: 15s
# 571:	learn: 2584.2017168	total: 20s	remaining: 15s
# 572:	learn: 2583.7327617	total: 20.1s	remaining: 15s
# 573:	learn: 2582.6170469	total: 20.1s	remaining: 14.9s
# 574:	learn: 2581.8468012	total: 20.2s	remaining: 14.9s
# 575:	learn: 2581.0646318	total: 20.2s	remaining: 14.9s
# 576:	learn: 2579.7180995	total: 20.2s	remaining: 14.8s
# 577:	learn: 2578.7813578	total: 20.3s	remaining: 14.8s
# 578:	learn: 2577.8866958	total: 20.3s	remaining: 14.8s
# 579:	learn: 2576.9547363	total: 20.3s	remaining: 14.7s
# 580:	learn: 2576.0213816	total: 20.4s	remaining: 14.7s
# 581:	learn: 2574.7891472	total: 20.4s	remaining: 14.7s
# 582:	learn: 2573.2728066	total: 20.4s	remaining: 14.6s
# 583:	learn: 2572.3358305	total: 20.5s	remaining: 14.6s
# 584:	learn: 2571.3153063	total: 20.5s	remaining: 14.6s
# 585:	learn: 2570.5250133	total: 20.6s	remaining: 14.5s
# 586:	learn: 2569.7989062	total: 20.6s	remaining: 14.5s
# 587:	learn: 2568.5707223	total: 20.6s	remaining: 14.5s
# 588:	learn: 2567.3958900	total: 20.7s	remaining: 14.4s
# 589:	learn: 2566.6036307	total: 20.7s	remaining: 14.4s
# 590:	learn: 2566.1110133	total: 20.7s	remaining: 14.4s
# 591:	learn: 2564.6524359	total: 20.8s	remaining: 14.3s
# 592:	learn: 2563.6930229	total: 20.8s	remaining: 14.3s
# 593:	learn: 2562.2397817	total: 20.9s	remaining: 14.3s
# 594:	learn: 2561.3414136	total: 20.9s	remaining: 14.2s
# 595:	learn: 2560.3263395	total: 20.9s	remaining: 14.2s
# 596:	learn: 2559.1144478	total: 21s	remaining: 14.2s
# 597:	learn: 2558.6588966	total: 21s	remaining: 14.1s
# 598:	learn: 2557.8857791	total: 21.1s	remaining: 14.1s
# 599:	learn: 2556.8112022	total: 21.1s	remaining: 14.1s
# 600:	learn: 2555.5782361	total: 21.1s	remaining: 14s
# 601:	learn: 2554.6337378	total: 21.2s	remaining: 14s
# 602:	learn: 2553.8460335	total: 21.2s	remaining: 14s
# 603:	learn: 2552.7277253	total: 21.2s	remaining: 13.9s
# 604:	learn: 2552.2029955	total: 21.3s	remaining: 13.9s
# 605:	learn: 2551.5815185	total: 21.3s	remaining: 13.8s
# 606:	learn: 2551.0335643	total: 21.3s	remaining: 13.8s
# 607:	learn: 2550.3695981	total: 21.4s	remaining: 13.8s
# 608:	learn: 2549.3377586	total: 21.4s	remaining: 13.7s
# 609:	learn: 2548.8986561	total: 21.4s	remaining: 13.7s
# 610:	learn: 2548.1162221	total: 21.5s	remaining: 13.7s
# 611:	learn: 2546.8838290	total: 21.5s	remaining: 13.6s
# 612:	learn: 2546.1125827	total: 21.5s	remaining: 13.6s
# 613:	learn: 2545.4131685	total: 21.6s	remaining: 13.6s
# 614:	learn: 2544.5319412	total: 21.6s	remaining: 13.5s
# 615:	learn: 2543.6487786	total: 21.7s	remaining: 13.5s
# 616:	learn: 2542.8705236	total: 21.7s	remaining: 13.5s
# 617:	learn: 2542.2577408	total: 21.7s	remaining: 13.4s
# 618:	learn: 2541.5356706	total: 21.8s	remaining: 13.4s
# 619:	learn: 2540.6615638	total: 21.8s	remaining: 13.4s
# 620:	learn: 2539.2773972	total: 21.8s	remaining: 13.3s
# 621:	learn: 2538.3426318	total: 21.9s	remaining: 13.3s
# 622:	learn: 2537.7725224	total: 21.9s	remaining: 13.3s
# 623:	learn: 2537.1841682	total: 21.9s	remaining: 13.2s
# 624:	learn: 2536.4127551	total: 22s	remaining: 13.2s
# 625:	learn: 2535.1735511	total: 22s	remaining: 13.2s
# 626:	learn: 2534.5827644	total: 22.1s	remaining: 13.1s
# 627:	learn: 2533.5002002	total: 22.1s	remaining: 13.1s
# 628:	learn: 2531.6430322	total: 22.1s	remaining: 13.1s
# 629:	learn: 2530.9496140	total: 22.2s	remaining: 13s
# 630:	learn: 2530.4523145	total: 22.2s	remaining: 13s
# 631:	learn: 2529.3050708	total: 22.2s	remaining: 12.9s
# 632:	learn: 2528.1974110	total: 22.3s	remaining: 12.9s
# 633:	learn: 2526.9840802	total: 22.3s	remaining: 12.9s
# 634:	learn: 2525.9985009	total: 22.3s	remaining: 12.8s
# 635:	learn: 2525.3222536	total: 22.4s	remaining: 12.8s
# 636:	learn: 2524.4827312	total: 22.4s	remaining: 12.8s
# 637:	learn: 2522.7244172	total: 22.4s	remaining: 12.7s
# 638:	learn: 2521.7175083	total: 22.5s	remaining: 12.7s
# 639:	learn: 2520.6558715	total: 22.5s	remaining: 12.7s
# 640:	learn: 2519.5320259	total: 22.6s	remaining: 12.6s
# 641:	learn: 2518.8007241	total: 22.6s	remaining: 12.6s
# 642:	learn: 2518.2635225	total: 22.6s	remaining: 12.6s
# 643:	learn: 2517.2859492	total: 22.7s	remaining: 12.5s
# 644:	learn: 2516.8092366	total: 22.7s	remaining: 12.5s
# 645:	learn: 2515.1997016	total: 22.7s	remaining: 12.5s
# 646:	learn: 2514.4034803	total: 22.8s	remaining: 12.4s
# 647:	learn: 2513.4570849	total: 22.8s	remaining: 12.4s
# 648:	learn: 2512.5114036	total: 22.8s	remaining: 12.3s
# 649:	learn: 2511.8207475	total: 22.9s	remaining: 12.3s
# 650:	learn: 2510.8378420	total: 22.9s	remaining: 12.3s
# 651:	learn: 2510.1913781	total: 22.9s	remaining: 12.2s
# 652:	learn: 2509.5952678	total: 23s	remaining: 12.2s
# 653:	learn: 2508.8590067	total: 23s	remaining: 12.2s
# 654:	learn: 2507.6639328	total: 23s	remaining: 12.1s
# 655:	learn: 2506.5868047	total: 23.1s	remaining: 12.1s
# 656:	learn: 2506.2018549	total: 23.1s	remaining: 12.1s
# 657:	learn: 2505.4447579	total: 23.2s	remaining: 12s
# 658:	learn: 2504.6069962	total: 23.2s	remaining: 12s
# 659:	learn: 2503.5556388	total: 23.2s	remaining: 12s
# 660:	learn: 2502.6277427	total: 23.3s	remaining: 11.9s
# 661:	learn: 2502.0556633	total: 23.3s	remaining: 11.9s
# 662:	learn: 2501.6788024	total: 23.3s	remaining: 11.9s
# 663:	learn: 2500.3546493	total: 23.4s	remaining: 11.8s
# 664:	learn: 2499.6454086	total: 23.4s	remaining: 11.8s
# 665:	learn: 2498.8076264	total: 23.4s	remaining: 11.8s
# 666:	learn: 2497.8405617	total: 23.5s	remaining: 11.7s
# 667:	learn: 2496.9747230	total: 23.5s	remaining: 11.7s
# 668:	learn: 2495.2775941	total: 23.5s	remaining: 11.6s
# 669:	learn: 2494.7189262	total: 23.6s	remaining: 11.6s
# 670:	learn: 2493.6789633	total: 23.6s	remaining: 11.6s
# 671:	learn: 2492.9834858	total: 23.6s	remaining: 11.5s
# 672:	learn: 2491.8144525	total: 23.7s	remaining: 11.5s
# 673:	learn: 2490.8022526	total: 23.7s	remaining: 11.5s
# 674:	learn: 2489.6762736	total: 23.8s	remaining: 11.4s
# 675:	learn: 2488.9529646	total: 23.8s	remaining: 11.4s
# 676:	learn: 2488.0895777	total: 23.8s	remaining: 11.4s
# 677:	learn: 2487.6030601	total: 23.9s	remaining: 11.3s
# 678:	learn: 2486.4626493	total: 23.9s	remaining: 11.3s
# 679:	learn: 2486.1262821	total: 23.9s	remaining: 11.3s
# 680:	learn: 2485.5417044	total: 24s	remaining: 11.2s
# 681:	learn: 2484.2801678	total: 24s	remaining: 11.2s
# 682:	learn: 2483.2205517	total: 24s	remaining: 11.2s
# 683:	learn: 2482.6771366	total: 24.1s	remaining: 11.1s
# 684:	learn: 2481.8095161	total: 24.1s	remaining: 11.1s
# 685:	learn: 2481.2837774	total: 24.2s	remaining: 11.1s
# 686:	learn: 2480.3472280	total: 24.2s	remaining: 11s
# 687:	learn: 2479.6879818	total: 24.2s	remaining: 11s
# 688:	learn: 2478.9364300	total: 24.3s	remaining: 10.9s
# 689:	learn: 2478.2182015	total: 24.3s	remaining: 10.9s
# 690:	learn: 2477.8859544	total: 24.3s	remaining: 10.9s
# 691:	learn: 2476.8150688	total: 24.4s	remaining: 10.8s
# 692:	learn: 2474.9791495	total: 24.4s	remaining: 10.8s
# 693:	learn: 2474.2464174	total: 24.4s	remaining: 10.8s
# 694:	learn: 2472.5718508	total: 24.5s	remaining: 10.7s
# 695:	learn: 2471.4077855	total: 24.5s	remaining: 10.7s
# 696:	learn: 2470.9660851	total: 24.5s	remaining: 10.7s
# 697:	learn: 2470.2627603	total: 24.6s	remaining: 10.6s
# 698:	learn: 2469.8721431	total: 24.6s	remaining: 10.6s
# 699:	learn: 2469.1869672	total: 24.7s	remaining: 10.6s
# 700:	learn: 2468.0082198	total: 24.7s	remaining: 10.5s
# 701:	learn: 2467.1295529	total: 24.7s	remaining: 10.5s
# 702:	learn: 2466.0785973	total: 24.8s	remaining: 10.5s
# 703:	learn: 2465.0481059	total: 24.8s	remaining: 10.4s
# 704:	learn: 2464.3934691	total: 24.8s	remaining: 10.4s
# 705:	learn: 2463.3700487	total: 24.9s	remaining: 10.4s
# 706:	learn: 2462.7066155	total: 24.9s	remaining: 10.3s
# 707:	learn: 2462.1055795	total: 25s	remaining: 10.3s
# 708:	learn: 2461.1062559	total: 25s	remaining: 10.3s
# 709:	learn: 2460.3211167	total: 25s	remaining: 10.2s
# 710:	learn: 2459.8238018	total: 25.1s	remaining: 10.2s
# 711:	learn: 2459.0354126	total: 25.1s	remaining: 10.2s
# 712:	learn: 2457.7294598	total: 25.1s	remaining: 10.1s
# 713:	learn: 2457.3174108	total: 25.2s	remaining: 10.1s
# 714:	learn: 2456.2305732	total: 25.2s	remaining: 10s
# 715:	learn: 2455.7273623	total: 25.2s	remaining: 10s
# 716:	learn: 2454.3783331	total: 25.3s	remaining: 9.97s
# 717:	learn: 2453.9890030	total: 25.3s	remaining: 9.94s
# 718:	learn: 2453.1735863	total: 25.3s	remaining: 9.9s
# 719:	learn: 2451.5216330	total: 25.4s	remaining: 9.87s
# 720:	learn: 2450.5486562	total: 25.4s	remaining: 9.83s
# 721:	learn: 2449.7111166	total: 25.4s	remaining: 9.8s
# 722:	learn: 2449.0771264	total: 25.5s	remaining: 9.76s
# 723:	learn: 2448.5098109	total: 25.5s	remaining: 9.73s
# 724:	learn: 2447.9692445	total: 25.6s	remaining: 9.69s
# 725:	learn: 2447.4009238	total: 25.6s	remaining: 9.65s
# 726:	learn: 2446.4656417	total: 25.6s	remaining: 9.62s
# 727:	learn: 2445.6085166	total: 25.7s	remaining: 9.59s
# 728:	learn: 2444.3688914	total: 25.7s	remaining: 9.55s
# 729:	learn: 2443.6195400	total: 25.7s	remaining: 9.51s
# 730:	learn: 2442.6649247	total: 25.8s	remaining: 9.48s
# 731:	learn: 2441.9377237	total: 25.8s	remaining: 9.44s
# 732:	learn: 2441.4354032	total: 25.8s	remaining: 9.41s
# 733:	learn: 2440.7957199	total: 25.9s	remaining: 9.37s
# 734:	learn: 2439.7342650	total: 25.9s	remaining: 9.34s
# 735:	learn: 2438.4702996	total: 25.9s	remaining: 9.3s
# 736:	learn: 2437.5281399	total: 26s	remaining: 9.27s
# 737:	learn: 2437.0973493	total: 26s	remaining: 9.23s
# 738:	learn: 2435.9140264	total: 26s	remaining: 9.2s
# 739:	learn: 2435.2341699	total: 26.1s	remaining: 9.16s
# 740:	learn: 2434.5720877	total: 26.1s	remaining: 9.13s
# 741:	learn: 2433.4904889	total: 26.1s	remaining: 9.09s
# 742:	learn: 2433.0560377	total: 26.2s	remaining: 9.06s
# 743:	learn: 2432.1205870	total: 26.2s	remaining: 9.02s
# 744:	learn: 2431.5312569	total: 26.3s	remaining: 8.99s
# 745:	learn: 2430.9829612	total: 26.3s	remaining: 8.95s
# 746:	learn: 2430.5775243	total: 26.3s	remaining: 8.92s
# 747:	learn: 2430.2620974	total: 26.4s	remaining: 8.88s
# 748:	learn: 2429.7013978	total: 26.4s	remaining: 8.85s
# 749:	learn: 2428.8412507	total: 26.4s	remaining: 8.81s
# 750:	learn: 2427.7437551	total: 26.5s	remaining: 8.78s
# 751:	learn: 2426.4047713	total: 26.5s	remaining: 8.75s
# 752:	learn: 2425.6114150	total: 26.6s	remaining: 8.71s
# 753:	learn: 2424.4022425	total: 26.6s	remaining: 8.68s
# 754:	learn: 2423.5973063	total: 26.6s	remaining: 8.65s
# 755:	learn: 2423.1524291	total: 26.7s	remaining: 8.61s
# 756:	learn: 2422.0845901	total: 26.7s	remaining: 8.58s
# 757:	learn: 2421.6951387	total: 26.8s	remaining: 8.54s
# 758:	learn: 2421.1553821	total: 26.8s	remaining: 8.51s
# 759:	learn: 2420.2062045	total: 26.8s	remaining: 8.47s
# 760:	learn: 2419.7657857	total: 26.9s	remaining: 8.44s
# 761:	learn: 2419.0554894	total: 26.9s	remaining: 8.4s
# 762:	learn: 2418.5288735	total: 26.9s	remaining: 8.37s
# 763:	learn: 2417.4800569	total: 27s	remaining: 8.33s
# 764:	learn: 2416.7749874	total: 27s	remaining: 8.3s
# 765:	learn: 2415.9526423	total: 27s	remaining: 8.26s
# 766:	learn: 2415.5492333	total: 27.1s	remaining: 8.22s
# 767:	learn: 2414.7132047	total: 27.1s	remaining: 8.19s
# 768:	learn: 2414.3948314	total: 27.1s	remaining: 8.15s
# 769:	learn: 2413.6055306	total: 27.2s	remaining: 8.12s
# 770:	learn: 2413.1334131	total: 27.2s	remaining: 8.08s
# 771:	learn: 2412.2448619	total: 27.3s	remaining: 8.05s
# 772:	learn: 2411.5651824	total: 27.3s	remaining: 8.02s
# 773:	learn: 2410.8948391	total: 27.3s	remaining: 7.98s
# 774:	learn: 2409.9676399	total: 27.4s	remaining: 7.95s
# 775:	learn: 2409.2964931	total: 27.4s	remaining: 7.91s
# 776:	learn: 2408.4666623	total: 27.4s	remaining: 7.88s
# 777:	learn: 2407.9096711	total: 27.5s	remaining: 7.84s
# 778:	learn: 2407.3674039	total: 27.5s	remaining: 7.81s
# 779:	learn: 2406.5840516	total: 27.6s	remaining: 7.77s
# 780:	learn: 2405.7715374	total: 27.6s	remaining: 7.74s
# 781:	learn: 2404.1440251	total: 27.6s	remaining: 7.7s
# 782:	learn: 2403.6788651	total: 27.7s	remaining: 7.67s
# 783:	learn: 2402.8077515	total: 27.7s	remaining: 7.63s
# 784:	learn: 2402.1643685	total: 27.7s	remaining: 7.59s
# 785:	learn: 2401.3351938	total: 27.8s	remaining: 7.56s
# 786:	learn: 2400.2082796	total: 27.8s	remaining: 7.53s
# 787:	learn: 2399.6111157	total: 27.8s	remaining: 7.49s
# 788:	learn: 2399.1916764	total: 27.9s	remaining: 7.46s
# 789:	learn: 2398.5175263	total: 27.9s	remaining: 7.42s
# 790:	learn: 2397.6799469	total: 28s	remaining: 7.39s
# 791:	learn: 2396.6164665	total: 28s	remaining: 7.35s
# 792:	learn: 2395.3981724	total: 28s	remaining: 7.32s
# 793:	learn: 2394.6916008	total: 28.1s	remaining: 7.28s
# 794:	learn: 2394.0888132	total: 28.1s	remaining: 7.25s
# 795:	learn: 2393.6173278	total: 28.1s	remaining: 7.21s
# 796:	learn: 2392.9329041	total: 28.2s	remaining: 7.17s
# 797:	learn: 2391.9040253	total: 28.2s	remaining: 7.14s
# 798:	learn: 2391.3596535	total: 28.2s	remaining: 7.11s
# 799:	learn: 2390.6135032	total: 28.3s	remaining: 7.07s
# 800:	learn: 2389.6805623	total: 28.3s	remaining: 7.03s
# 801:	learn: 2389.1826263	total: 28.4s	remaining: 7s
# 802:	learn: 2388.2744790	total: 28.4s	remaining: 6.96s
# 803:	learn: 2387.6963017	total: 28.4s	remaining: 6.93s
# 804:	learn: 2387.3024855	total: 28.5s	remaining: 6.89s
# 805:	learn: 2385.9349427	total: 28.5s	remaining: 6.86s
# 806:	learn: 2385.6680930	total: 28.5s	remaining: 6.82s
# 807:	learn: 2385.2223644	total: 28.6s	remaining: 6.79s
# 808:	learn: 2384.6216112	total: 28.6s	remaining: 6.75s
# 809:	learn: 2384.0649144	total: 28.6s	remaining: 6.72s
# 810:	learn: 2382.8116614	total: 28.7s	remaining: 6.68s
# 811:	learn: 2382.1730842	total: 28.7s	remaining: 6.65s
# 812:	learn: 2381.3466090	total: 28.7s	remaining: 6.61s
# 813:	learn: 2380.9999054	total: 28.8s	remaining: 6.58s
# 814:	learn: 2380.0624833	total: 28.8s	remaining: 6.54s
# 815:	learn: 2378.6974205	total: 28.9s	remaining: 6.51s
# 816:	learn: 2378.3330966	total: 28.9s	remaining: 6.47s
# 817:	learn: 2377.6675979	total: 28.9s	remaining: 6.44s
# 818:	learn: 2376.9901382	total: 29s	remaining: 6.4s
# 819:	learn: 2376.1222330	total: 29s	remaining: 6.37s
# 820:	learn: 2375.5272692	total: 29s	remaining: 6.33s
# 821:	learn: 2374.8537546	total: 29.1s	remaining: 6.3s
# 822:	learn: 2374.4125745	total: 29.1s	remaining: 6.26s
# 823:	learn: 2373.7609977	total: 29.2s	remaining: 6.23s
# 824:	learn: 2373.2091015	total: 29.2s	remaining: 6.19s
# 825:	learn: 2372.0652364	total: 29.2s	remaining: 6.16s
# 826:	learn: 2371.5484831	total: 29.3s	remaining: 6.12s
# 827:	learn: 2371.0587889	total: 29.3s	remaining: 6.09s
# 828:	learn: 2370.7542454	total: 29.3s	remaining: 6.05s
# 829:	learn: 2370.3295355	total: 29.4s	remaining: 6.01s
# 830:	learn: 2369.4978128	total: 29.4s	remaining: 5.98s
# 831:	learn: 2368.9388267	total: 29.4s	remaining: 5.95s
# 832:	learn: 2368.6220364	total: 29.5s	remaining: 5.91s
# 833:	learn: 2368.3160861	total: 29.5s	remaining: 5.88s
# 834:	learn: 2367.9204324	total: 29.6s	remaining: 5.84s
# 835:	learn: 2367.5939292	total: 29.6s	remaining: 5.8s
# 836:	learn: 2367.0089283	total: 29.6s	remaining: 5.77s
# 837:	learn: 2366.1165334	total: 29.7s	remaining: 5.73s
# 838:	learn: 2365.3160246	total: 29.7s	remaining: 5.7s
# 839:	learn: 2364.4578373	total: 29.7s	remaining: 5.66s
# 840:	learn: 2363.7762757	total: 29.8s	remaining: 5.63s
# 841:	learn: 2363.1476314	total: 29.8s	remaining: 5.59s
# 842:	learn: 2362.2587081	total: 29.8s	remaining: 5.56s
# 843:	learn: 2361.3829911	total: 29.9s	remaining: 5.52s
# 844:	learn: 2360.2973498	total: 29.9s	remaining: 5.49s
# 845:	learn: 2359.7403068	total: 30s	remaining: 5.45s
# 846:	learn: 2359.3419837	total: 30s	remaining: 5.42s
# 847:	learn: 2358.7526468	total: 30s	remaining: 5.38s
# 848:	learn: 2358.4077606	total: 30.1s	remaining: 5.35s
# 849:	learn: 2357.8332390	total: 30.1s	remaining: 5.31s
# 850:	learn: 2357.4520060	total: 30.2s	remaining: 5.28s
# 851:	learn: 2357.0519349	total: 30.2s	remaining: 5.24s
# 852:	learn: 2356.4927791	total: 30.2s	remaining: 5.21s
# 853:	learn: 2355.6465190	total: 30.3s	remaining: 5.17s
# 854:	learn: 2354.9271941	total: 30.3s	remaining: 5.14s
# 855:	learn: 2354.2080890	total: 30.3s	remaining: 5.1s
# 856:	learn: 2353.4039663	total: 30.4s	remaining: 5.07s
# 857:	learn: 2352.6890682	total: 30.4s	remaining: 5.03s
# 858:	learn: 2351.7550636	total: 30.5s	remaining: 5s
# 859:	learn: 2351.4460506	total: 30.5s	remaining: 4.96s
# 860:	learn: 2350.9076760	total: 30.5s	remaining: 4.93s
# 861:	learn: 2350.3189580	total: 30.6s	remaining: 4.89s
# 862:	learn: 2349.5889103	total: 30.6s	remaining: 4.86s
# 863:	learn: 2348.8539460	total: 30.6s	remaining: 4.82s
# 864:	learn: 2348.2776613	total: 30.7s	remaining: 4.79s
# 865:	learn: 2347.8783888	total: 30.7s	remaining: 4.75s
# 866:	learn: 2347.2308476	total: 30.8s	remaining: 4.72s
# 867:	learn: 2346.7036364	total: 30.8s	remaining: 4.68s
# 868:	learn: 2346.1087550	total: 30.8s	remaining: 4.65s
# 869:	learn: 2345.3281946	total: 30.9s	remaining: 4.61s
# 870:	learn: 2344.7691189	total: 30.9s	remaining: 4.58s
# 871:	learn: 2344.2676910	total: 30.9s	remaining: 4.54s
# 872:	learn: 2343.6747681	total: 31s	remaining: 4.51s
# 873:	learn: 2342.2853718	total: 31s	remaining: 4.47s
# 874:	learn: 2341.4118848	total: 31.1s	remaining: 4.43s
# 875:	learn: 2340.9515122	total: 31.1s	remaining: 4.4s
# 876:	learn: 2340.2772324	total: 31.1s	remaining: 4.36s
# 877:	learn: 2339.3076847	total: 31.2s	remaining: 4.33s
# 878:	learn: 2338.2212075	total: 31.2s	remaining: 4.29s
# 879:	learn: 2337.7496817	total: 31.2s	remaining: 4.26s
# 880:	learn: 2337.3605663	total: 31.3s	remaining: 4.22s
# 881:	learn: 2336.8181843	total: 31.3s	remaining: 4.19s
# 882:	learn: 2335.6705551	total: 31.3s	remaining: 4.15s
# 883:	learn: 2335.1153792	total: 31.4s	remaining: 4.12s
# 884:	learn: 2334.4566741	total: 31.4s	remaining: 4.08s
# 885:	learn: 2333.4244505	total: 31.4s	remaining: 4.05s
# 886:	learn: 2332.8464725	total: 31.5s	remaining: 4.01s
# 887:	learn: 2332.2142810	total: 31.5s	remaining: 3.98s
# 888:	learn: 2331.4079406	total: 31.6s	remaining: 3.94s
# 889:	learn: 2331.0557238	total: 31.6s	remaining: 3.91s
# 890:	learn: 2330.5691370	total: 31.6s	remaining: 3.87s
# 891:	learn: 2329.9244661	total: 31.7s	remaining: 3.84s
# 892:	learn: 2329.1645018	total: 31.7s	remaining: 3.8s
# 893:	learn: 2328.7966205	total: 31.8s	remaining: 3.77s
# 894:	learn: 2328.4734893	total: 31.8s	remaining: 3.73s
# 895:	learn: 2327.8241092	total: 31.8s	remaining: 3.69s
# 896:	learn: 2327.3605674	total: 31.9s	remaining: 3.66s
# 897:	learn: 2326.8005417	total: 31.9s	remaining: 3.62s
# 898:	learn: 2326.3274238	total: 31.9s	remaining: 3.59s
# 899:	learn: 2325.2610364	total: 32s	remaining: 3.55s
# 900:	learn: 2324.8020055	total: 32s	remaining: 3.52s
# 901:	learn: 2324.4464929	total: 32.1s	remaining: 3.48s
# 902:	learn: 2323.9601079	total: 32.1s	remaining: 3.45s
# 903:	learn: 2322.9259898	total: 32.1s	remaining: 3.41s
# 904:	learn: 2322.2009947	total: 32.2s	remaining: 3.38s
# 905:	learn: 2321.5543538	total: 32.2s	remaining: 3.34s
# 906:	learn: 2320.8785800	total: 32.3s	remaining: 3.31s
# 907:	learn: 2320.0905859	total: 32.3s	remaining: 3.27s
# 908:	learn: 2319.4045621	total: 32.3s	remaining: 3.24s
# 909:	learn: 2318.7756267	total: 32.4s	remaining: 3.2s
# 910:	learn: 2318.5305443	total: 32.4s	remaining: 3.17s
# 911:	learn: 2318.1635199	total: 32.4s	remaining: 3.13s
# 912:	learn: 2317.4703214	total: 32.5s	remaining: 3.1s
# 913:	learn: 2316.5861397	total: 32.5s	remaining: 3.06s
# 914:	learn: 2316.0171237	total: 32.6s	remaining: 3.02s
# 915:	learn: 2315.3213009	total: 32.6s	remaining: 2.99s
# 916:	learn: 2314.7001693	total: 32.6s	remaining: 2.95s
# 917:	learn: 2314.2473621	total: 32.7s	remaining: 2.92s
# 918:	learn: 2313.7775665	total: 32.7s	remaining: 2.88s
# 919:	learn: 2313.4423612	total: 32.8s	remaining: 2.85s
# 920:	learn: 2312.9608713	total: 32.8s	remaining: 2.81s
# 921:	learn: 2312.3384311	total: 32.8s	remaining: 2.78s
# 922:	learn: 2311.7714740	total: 32.9s	remaining: 2.74s
# 923:	learn: 2310.5798989	total: 32.9s	remaining: 2.71s
# 924:	learn: 2310.1253310	total: 33s	remaining: 2.67s
# 925:	learn: 2309.6304359	total: 33s	remaining: 2.64s
# 926:	learn: 2309.1401034	total: 33s	remaining: 2.6s
# 927:	learn: 2308.5081143	total: 33.1s	remaining: 2.56s
# 928:	learn: 2307.7806991	total: 33.1s	remaining: 2.53s
# 929:	learn: 2307.3308187	total: 33.1s	remaining: 2.49s
# 930:	learn: 2306.7719870	total: 33.2s	remaining: 2.46s
# 931:	learn: 2306.4900285	total: 33.2s	remaining: 2.42s
# 932:	learn: 2305.5247615	total: 33.3s	remaining: 2.39s
# 933:	learn: 2304.7437461	total: 33.3s	remaining: 2.35s
# 934:	learn: 2304.5032703	total: 33.3s	remaining: 2.32s
# 935:	learn: 2304.1397570	total: 33.4s	remaining: 2.28s
# 936:	learn: 2303.2364026	total: 33.4s	remaining: 2.25s
# 937:	learn: 2302.2307821	total: 33.5s	remaining: 2.21s
# 938:	learn: 2301.6648734	total: 33.5s	remaining: 2.18s
# 939:	learn: 2301.2923997	total: 33.5s	remaining: 2.14s
# 940:	learn: 2300.4396883	total: 33.6s	remaining: 2.1s
# 941:	learn: 2299.3929621	total: 33.6s	remaining: 2.07s
# 942:	learn: 2298.5631927	total: 33.7s	remaining: 2.04s
# 943:	learn: 2298.1187400	total: 33.7s	remaining: 2s
# 944:	learn: 2297.8292443	total: 33.7s	remaining: 1.96s
# 945:	learn: 2297.2694536	total: 33.8s	remaining: 1.93s
# 946:	learn: 2296.4073300	total: 33.8s	remaining: 1.89s
# 947:	learn: 2295.9490738	total: 33.9s	remaining: 1.86s
# 948:	learn: 2295.1281954	total: 33.9s	remaining: 1.82s
# 949:	learn: 2294.3003007	total: 33.9s	remaining: 1.79s
# 950:	learn: 2293.8413923	total: 34s	remaining: 1.75s
# 951:	learn: 2293.2089487	total: 34s	remaining: 1.72s
# 952:	learn: 2292.7718154	total: 34.1s	remaining: 1.68s
# 953:	learn: 2292.3041644	total: 34.1s	remaining: 1.64s
# 954:	learn: 2291.5694208	total: 34.1s	remaining: 1.61s
# 955:	learn: 2291.1315274	total: 34.2s	remaining: 1.57s
# 956:	learn: 2290.3162201	total: 34.2s	remaining: 1.54s
# 957:	learn: 2290.1546796	total: 34.2s	remaining: 1.5s
# 958:	learn: 2289.8421804	total: 34.3s	remaining: 1.47s
# 959:	learn: 2289.1910472	total: 34.3s	remaining: 1.43s
# 960:	learn: 2288.8791439	total: 34.3s	remaining: 1.39s
# 961:	learn: 2288.5964037	total: 34.4s	remaining: 1.36s
# 962:	learn: 2288.1586769	total: 34.4s	remaining: 1.32s
# 963:	learn: 2287.5632052	total: 34.5s	remaining: 1.29s
# 964:	learn: 2287.1170045	total: 34.5s	remaining: 1.25s
# 965:	learn: 2286.8057343	total: 34.5s	remaining: 1.22s
# 966:	learn: 2286.1059240	total: 34.6s	remaining: 1.18s
# 967:	learn: 2285.4140063	total: 34.6s	remaining: 1.14s
# 968:	learn: 2284.4732369	total: 34.6s	remaining: 1.11s
# 969:	learn: 2283.7287031	total: 34.7s	remaining: 1.07s
# 970:	learn: 2283.3553909	total: 34.7s	remaining: 1.04s
# 971:	learn: 2282.8040878	total: 34.8s	remaining: 1s
# 972:	learn: 2281.8500354	total: 34.8s	remaining: 965ms
# 973:	learn: 2281.5930442	total: 34.8s	remaining: 930ms
# 974:	learn: 2281.1178591	total: 34.9s	remaining: 894ms
# 975:	learn: 2279.9600901	total: 34.9s	remaining: 859ms
# 976:	learn: 2279.6452806	total: 35s	remaining: 823ms
# 977:	learn: 2279.2165708	total: 35s	remaining: 787ms
# 978:	learn: 2279.0240459	total: 35s	remaining: 751ms
# 979:	learn: 2278.3666292	total: 35s	remaining: 715ms
# 980:	learn: 2277.8939536	total: 35.1s	remaining: 679ms
# 981:	learn: 2277.4279435	total: 35.1s	remaining: 644ms
# 982:	learn: 2277.0076026	total: 35.2s	remaining: 608ms
# 983:	learn: 2276.6768730	total: 35.2s	remaining: 572ms
# 984:	learn: 2276.3063383	total: 35.2s	remaining: 537ms
# 985:	learn: 2275.6269101	total: 35.3s	remaining: 501ms
# 986:	learn: 2275.0503862	total: 35.3s	remaining: 465ms
# 987:	learn: 2274.3671771	total: 35.3s	remaining: 429ms
# 988:	learn: 2273.8387407	total: 35.4s	remaining: 394ms
# 989:	learn: 2273.0330248	total: 35.4s	remaining: 358ms
# 990:	learn: 2272.6279203	total: 35.5s	remaining: 322ms
# 991:	learn: 2271.9414419	total: 35.5s	remaining: 286ms
# 992:	learn: 2271.6948637	total: 35.5s	remaining: 250ms
# 993:	learn: 2271.3634924	total: 35.6s	remaining: 215ms
# 994:	learn: 2270.6462528	total: 35.6s	remaining: 179ms
# 995:	learn: 2270.3074193	total: 35.6s	remaining: 143ms
# 996:	learn: 2269.6232784	total: 35.7s	remaining: 107ms
# 997:	learn: 2268.9746138	total: 35.7s	remaining: 71.6ms
# 998:	learn: 2268.6895710	total: 35.8s	remaining: 35.8ms
# 999:	learn: 2268.2058345	total: 35.8s	remaining: 0us
#         Real Values  Predicted Values
# 187265         3361       3012.165696
# 25128          3754       5065.982798
# 131095         5334       5328.642423
# 81729          4249       4730.150751
# 12702         16210       8252.976113
# ...             ...               ...
# 114253         5322       5222.556350
# 23730         79024      77362.170823
# 20324         53152      55906.250375
# 118268         4687       4480.818514
# 134337         5102       5099.184330
#
# [72062 rows x 2 columns]
# Training score:  0.9900181988087235
# r2 score is:  0.9882162935243041
# MAE:  1318.4181830717632
# MSE:  6058484.383167988
# RMSE:  2461.3988671420134
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # XGBoostRegressor

# %%
predict(XGBRegressor(objective = 'reg:squarederror', learning_rate = 0.3, max_depth = 5, n_estimators = 50))
# Out:
#         Real Values  Predicted Values
# 187265         3361       2972.976807
# 25128          3754       4686.604980
# 131095         5334       5104.322754
# 81729          4249       5056.418457
# 12702         16210       6742.519043
# ...             ...               ...
# 114253         5322       4773.471680
# 23730         79024      69848.203125
# 20324         53152      54309.843750
# 118268         4687       3713.932617
# 134337         5102       5442.494141
#
# [72062 rows x 2 columns]
# Training score:  0.9738639371973632
# r2 score is:  0.9731434752057679
# MAE:  2139.9058923393372
# MSE:  13808035.39086882
# RMSE:  3715.9164940656055
# <AxesSubplot:ylabel='Density'>

# %%
def seqmodel(arr):  # [8,16,32,16,8,4,1]
    model = Sequential()
    for i in range(len(arr)):
        if i!=0 and i!=len(arr)-1:
            if i==1:
                model.add(Dense(arr[i], input_dim = arr[0], activation='relu'))
            else:
                model.add(Dense(arr[i], activation='relu'))
    model.add(Dense(arr[-1]))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
    return model

# %%
# Def a function for model evaluation
def eval_model(model,xtrain,ytrain,xtest,ytest):
    history= model.fit(xtrain,ytrain, epochs=100, batch_size=100, verbose=0)
    
    plt.plot(history.history['mean_squared_error'])
    plt.plot(history.history['loss'])
    plt.xlabel('Epochs')
    plt.ylabel('MSE')
    plt.legend(['mean_squared_error', 'loss'])
    
    y_pred = model.predict(xtest)
    print('R2: ',r2_score(y_test,y_pred))
    print('MSE: ',mean_squared_error(y_test,y_pred))
    print('RMSE: ',(mean_squared_error(y_test,y_pred))**0.5)
    print('MAPE: ',mean_absolute_percentage_error(y_test,y_pred))

# %%
eval_model(seqmodel([9,18,36,18,9,1]), X_train,y_train,X_test,y_test)
# Out:
# R2:  0.9439718280976581
# MSE:  28806369.641666047
# RMSE:  5367.156569512953
# MAPE:  0.2103856843743612
