# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Clean_Dataset.csv')
data.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
data['source_city'].unique()
# Out:
# array(['Delhi', 'Mumbai', 'Bangalore', 'Kolkata', 'Hyderabad', 'Chennai'],
#       dtype=object)

# %%
business = pd.read_csv('business.csv')
business
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1      11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2      11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3      11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4      11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 93482  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483  31-03-2022    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485  31-03-2022    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     20:00     Mumbai
# 1                                              non-stop     21:15     Mumbai
# 2      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45     Mumbai
# 3      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# 4      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# ...                                                  ...      ...        ...
# 93482  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
# 93483  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    22:55  Hyderabad
# 93484  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 93485  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    17:00  Hyderabad
# 93486  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
#
#         price
# 0      25,612
# 1      25,612
# 2      42,220
# 3      44,450
# 4      46,690
# ...       ...
# 93482  69,265
# 93483  77,105
# 93484  79,099
# 93485  81,585
# 93486  81,585
#
# [93487 rows x 11 columns]

# %%
economy = pd.read_csv('economy.csv')
economy
# Out:
#               date   airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...            ...       ...     ...       ...      ...      ...        ...
# 206769  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022   Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop arr_time         to  \
# 0                                               non-stop     21:05     Mumbai
# 1                                               non-stop     08:40     Mumbai
# 2                                               non-stop     06:35     Mumbai
# 3                                               non-stop     12:35     Mumbai
# 4                                               non-stop     11:10     Mumbai
# ...                                                   ...      ...        ...
# 206769  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206770  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206771  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206772  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206773  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
#
#         price
# 0       5,953
# 1       5,953
# 2       5,956
# 3       5,955
# 4       5,955
# ...       ...
# 206769  7,697
# 206770  7,709
# 206771  8,640
# 206772  8,640
# 206773  8,640
#
# [206774 rows x 11 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #### merging economy and business class into one column

# %%
business['class'] = "business"
economy['class'] = "economy"

# %%
df =business.append(economy)

# %%
df
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop arr_time         to  \
# 0                                               non-stop     20:00     Mumbai
# 1                                               non-stop     21:15     Mumbai
# 2       1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45     Mumbai
# 3       1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# 4       1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# ...                                                   ...      ...        ...
# 206769  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206770  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206771  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206772  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206773  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
#
#          price     class
# 0       25,612  business
# 1       25,612  business
# 2       42,220  business
# 3       44,450  business
# 4       46,690  business
# ...        ...       ...
# 206769   7,697   economy
# 206770   7,709   economy
# 206771   8,640   economy
# 206772   8,640   economy
# 206773   8,640   economy
#
# [300261 rows x 12 columns]

# %%
df.drop_duplicates(inplace=True) # dropping duplicates if theres any

# %% [markdown]
# # converting stop column into integer

# %%
df['stop']= df['stop'].str.split('-').str[0]

# %%
df['stop'].unique()
# Out:
# array(['non', '1', '2+'], dtype=object)

# %%
df['stop']=df['stop'].map({'non':0, '1':1, '2+':2}).astype(int)

# %%
df
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
#         stop arr_time         to   price     class
# 0          0    20:00     Mumbai  25,612  business
# 1          0    21:15     Mumbai  25,612  business
# 2          1    20:45     Mumbai  42,220  business
# 3          1    23:55     Mumbai  44,450  business
# 4          1    23:55     Mumbai  46,690  business
# ...      ...      ...        ...     ...       ...
# 206769     1    20:55  Hyderabad   7,697   economy
# 206770     1    20:55  Hyderabad   7,709   economy
# 206771     1    09:05  Hyderabad   8,640   economy
# 206772     1    09:05  Hyderabad   8,640   economy
# 206773     1    20:55  Hyderabad   8,640   economy
#
# [300259 rows x 12 columns]

# %% [markdown]
# ## splitting hour taken column into hour and column

# %%
df['hour_taken']=df['time_taken'].str.split(' ').str[0].str.split('h').str[0]

# %%
df['min_taken']=df['time_taken'].str.split(' ').str[1].str.split('m').str[0]

# %%
df['price']= df['price'].str.replace(',','')

# %%
df
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
#         stop arr_time         to  price     class hour_taken min_taken
# 0          0    20:00     Mumbai  25612  business         02        00
# 1          0    21:15     Mumbai  25612  business         02        15
# 2          1    20:45     Mumbai  42220  business         24        45
# 3          1    23:55     Mumbai  44450  business         26        30
# 4          1    23:55     Mumbai  46690  business         06        40
# ...      ...      ...        ...    ...       ...        ...       ...
# 206769     1    20:55  Hyderabad   7697   economy         13        50
# 206770     1    20:55  Hyderabad   7709   economy         13        50
# 206771     1    09:05  Hyderabad   8640   economy         20        35
# 206772     1    09:05  Hyderabad   8640   economy         23        20
# 206773     1    20:55  Hyderabad   8640   economy         24        25
#
# [300259 rows x 14 columns]

# %% [markdown]
# ### merging ch_code and num code to make a proper flight number

# %%
df['flight']=df['ch_code']+ '-'+ df['num_code'].astype(str)

# %%
df.head()
# Out:
#          date    airline ch_code  num_code dep_time   from time_taken  stop  \
# 0  11-02-2022  Air India      AI       868    18:00  Delhi    02h 00m     0
# 1  11-02-2022  Air India      AI       624    19:00  Delhi    02h 15m     0
# 2  11-02-2022  Air India      AI       531    20:00  Delhi    24h 45m     1
# 3  11-02-2022  Air India      AI       839    21:25  Delhi    26h 30m     1
# 4  11-02-2022  Air India      AI       544    17:15  Delhi    06h 40m     1
#
#   arr_time      to  price     class hour_taken min_taken  flight
# 0    20:00  Mumbai  25612  business         02        00  AI-868
# 1    21:15  Mumbai  25612  business         02        15  AI-624
# 2    20:45  Mumbai  42220  business         24        45  AI-531
# 3    23:55  Mumbai  44450  business         26        30  AI-839
# 4    23:55  Mumbai  46690  business         06        40  AI-544

# %% [markdown]
# ### Making category of departure and arrival time for better analysis

# %%
def deptime(tmm):
    tmm = int(tmm.split(":")[0])
    if tmm >= 4 and tmm <= 8:
        day = 'Early_Morning'
    elif tmm > 8 and tmm <12:
        day = 'Morning'
    elif tmm >= 12 and tmm < 16:
        day = 'Afternoon'
    elif tmm >= 16 and tmm < 20:
        day = 'Evening'
    elif tmm >= 20 and tmm < 24 :
        day = 'Night'
    else:
        day = 'Late_Night'
    return day

# %%
df['departure_time'] = df['dep_time'].apply(deptime)

# %%
df['arrival_time'] = df['arr_time'].apply(deptime)

# %%
df.head()
# Out:
#          date    airline ch_code  num_code dep_time   from time_taken  stop  \
# 0  11-02-2022  Air India      AI       868    18:00  Delhi    02h 00m     0
# 1  11-02-2022  Air India      AI       624    19:00  Delhi    02h 15m     0
# 2  11-02-2022  Air India      AI       531    20:00  Delhi    24h 45m     1
# 3  11-02-2022  Air India      AI       839    21:25  Delhi    26h 30m     1
# 4  11-02-2022  Air India      AI       544    17:15  Delhi    06h 40m     1
#
#   arr_time      to  price     class hour_taken min_taken  flight  \
# 0    20:00  Mumbai  25612  business         02        00  AI-868
# 1    21:15  Mumbai  25612  business         02        15  AI-624
# 2    20:45  Mumbai  42220  business         24        45  AI-531
# 3    23:55  Mumbai  44450  business         26        30  AI-839
# 4    23:55  Mumbai  46690  business         06        40  AI-544
#
#   departure_time arrival_time
# 0        Evening        Night
# 1        Evening        Night
# 2          Night        Night
# 3          Night        Night
# 4        Evening        Night

# %% [markdown]
# ## making a new column days left from the dates

# %%
df['new_date']='10-02-2022'

# %%
df
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
#         stop arr_time         to  price     class hour_taken min_taken  \
# 0          0    20:00     Mumbai  25612  business         02        00
# 1          0    21:15     Mumbai  25612  business         02        15
# 2          1    20:45     Mumbai  42220  business         24        45
# 3          1    23:55     Mumbai  44450  business         26        30
# 4          1    23:55     Mumbai  46690  business         06        40
# ...      ...      ...        ...    ...       ...        ...       ...
# 206769     1    20:55  Hyderabad   7697   economy         13        50
# 206770     1    20:55  Hyderabad   7709   economy         13        50
# 206771     1    09:05  Hyderabad   8640   economy         20        35
# 206772     1    09:05  Hyderabad   8640   economy         23        20
# 206773     1    20:55  Hyderabad   8640   economy         24        25
#
#         flight departure_time arrival_time    new_date
# 0       AI-868        Evening        Night  10-02-2022
# 1       AI-624        Evening        Night  10-02-2022
# 2       AI-531          Night        Night  10-02-2022
# 3       AI-839          Night        Night  10-02-2022
# 4       AI-544        Evening        Night  10-02-2022
# ...        ...            ...          ...         ...
# 206769  UK-832  Early_Morning        Night  10-02-2022
# 206770  UK-832  Early_Morning        Night  10-02-2022
# 206771  UK-826      Afternoon      Morning  10-02-2022
# 206772  UK-822        Morning      Morning  10-02-2022
# 206773  UK-824          Night        Night  10-02-2022
#
# [300259 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300259 entries, 0 to 206773
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            300259 non-null  object
#  1   airline         300259 non-null  object
#  2   ch_code         300259 non-null  object
#  3   num_code        300259 non-null  int64
#  4   dep_time        300259 non-null  object
#  5   from            300259 non-null  object
#  6   time_taken      300259 non-null  object
#  7   stop            300259 non-null  int32
#  8   arr_time        300259 non-null  object
#  9   to              300259 non-null  object
#  10  price           300259 non-null  object
#  11  class           300259 non-null  object
#  12  hour_taken      300259 non-null  object
#  13  min_taken       300259 non-null  object
#  14  flight          300259 non-null  object
#  15  departure_time  300259 non-null  object
#  16  arrival_time    300259 non-null  object
#  17  new_date        300259 non-null  object
# dtypes: int32(1), int64(1), object(16)
# memory usage: 42.4+ MB

# %%
df['date'] = pd.to_datetime(df['date'],format="%d-%m-%Y")
df['new_date'] = pd.to_datetime(df['new_date'],format="%d-%m-%Y")

# %%
df['days_left']=df['date']-df['new_date']

# %%
df
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      2022-02-11  Air India      AI       868    18:00    Delhi    02h 00m
# 1      2022-02-11  Air India      AI       624    19:00    Delhi    02h 15m
# 2      2022-02-11  Air India      AI       531    20:00    Delhi    24h 45m
# 3      2022-02-11  Air India      AI       839    21:25    Delhi    26h 30m
# 4      2022-02-11  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 206769 2022-03-31    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770 2022-03-31    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771 2022-03-31    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772 2022-03-31    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773 2022-03-31    Vistara      UK       824    20:30  Chennai    24h 25m
#
#         stop arr_time         to  price     class hour_taken min_taken  \
# 0          0    20:00     Mumbai  25612  business         02        00
# 1          0    21:15     Mumbai  25612  business         02        15
# 2          1    20:45     Mumbai  42220  business         24        45
# 3          1    23:55     Mumbai  44450  business         26        30
# 4          1    23:55     Mumbai  46690  business         06        40
# ...      ...      ...        ...    ...       ...        ...       ...
# 206769     1    20:55  Hyderabad   7697   economy         13        50
# 206770     1    20:55  Hyderabad   7709   economy         13        50
# 206771     1    09:05  Hyderabad   8640   economy         20        35
# 206772     1    09:05  Hyderabad   8640   economy         23        20
# 206773     1    20:55  Hyderabad   8640   economy         24        25
#
#         flight departure_time arrival_time   new_date days_left
# 0       AI-868        Evening        Night 2022-02-10    1 days
# 1       AI-624        Evening        Night 2022-02-10    1 days
# 2       AI-531          Night        Night 2022-02-10    1 days
# 3       AI-839          Night        Night 2022-02-10    1 days
# 4       AI-544        Evening        Night 2022-02-10    1 days
# ...        ...            ...          ...        ...       ...
# 206769  UK-832  Early_Morning        Night 2022-02-10   49 days
# 206770  UK-832  Early_Morning        Night 2022-02-10   49 days
# 206771  UK-826      Afternoon      Morning 2022-02-10   49 days
# 206772  UK-822        Morning      Morning 2022-02-10   49 days
# 206773  UK-824          Night        Night 2022-02-10   49 days
#
# [300259 rows x 19 columns]

# %% [markdown]
# ## Time for remove the unnecessary column . PURGEEEE!!!

# %%
df.drop(['date','new_date','ch_code','num_code','dep_time',
         'time_taken','arr_time'],axis=1,inplace =True)

# %%
df.head(5)
# Out:
#      airline   from  stop      to  price     class hour_taken min_taken  \
# 0  Air India  Delhi     0  Mumbai  25612  business         02        00
# 1  Air India  Delhi     0  Mumbai  25612  business         02        15
# 2  Air India  Delhi     1  Mumbai  42220  business         24        45
# 3  Air India  Delhi     1  Mumbai  44450  business         26        30
# 4  Air India  Delhi     1  Mumbai  46690  business         06        40
#
#    flight departure_time arrival_time days_left
# 0  AI-868        Evening        Night    1 days
# 1  AI-624        Evening        Night    1 days
# 2  AI-531          Night        Night    1 days
# 3  AI-839          Night        Night    1 days
# 4  AI-544        Evening        Night    1 days

# %% [markdown]
# ### Dataset looks good now , but can get better if we convert two difreent time column into just minutes . So, lets do that .

# %%
df['days_left']= df['days_left'].astype(str)

# %%
df['days_left'] = df['days_left'].str.split(' ').str[0]

# %%
df['hour_taken']= df['hour_taken'].astype(float)

# %%
df['hour_taken']=df['hour_taken'].astype(int)

# %%
df[df['min_taken']=='']
# Out:
#          airline       from  stop         to price    class  hour_taken  \
# 96486   GO FIRST  Bangalore     1     Mumbai  5177  economy           1
# 104676  GO FIRST  Bangalore     2    Kolkata  5177  economy           1
# 111315  GO FIRST  Bangalore     2  Hyderabad  4337  economy           1
# 154007  GO FIRST  Hyderabad     1      Delhi  6132  economy           1
#
#        min_taken  flight departure_time   arrival_time days_left
# 96486             G8-146  Early_Morning        Morning        16
# 104676            G8-146  Early_Morning  Early_Morning        16
# 111315            G8-146  Early_Morning        Morning        16
# 154007            G8-517          Night          Night        15

# %% [markdown]
# ## heres the trouble making rows , something looks fishy 1 hour flight having 2 stops looks like someone travelling on a moon on Go First . Goodbye 4 rows time to drop them..

# %%
df.drop(df[df['min_taken']==''].index,inplace=True)

# %%
df['min_taken'] = df['min_taken'].astype('int')

# %%
df['duration'] =(df['hour_taken']*60)+df['min_taken']

# %%
df.drop(['min_taken','hour_taken'],axis=1,inplace = True)

# %%
df.reset_index()
# Out:
#          index    airline     from  stop         to  price     class  flight  \
# 0            0  Air India    Delhi     0     Mumbai  25612  business  AI-868
# 1            1  Air India    Delhi     0     Mumbai  25612  business  AI-624
# 2            2  Air India    Delhi     1     Mumbai  42220  business  AI-531
# 3            3  Air India    Delhi     1     Mumbai  44450  business  AI-839
# 4            4  Air India    Delhi     1     Mumbai  46690  business  AI-544
# ...        ...        ...      ...   ...        ...    ...       ...     ...
# 300250  206769    Vistara  Chennai     1  Hyderabad   7697   economy  UK-832
# 300251  206770    Vistara  Chennai     1  Hyderabad   7709   economy  UK-832
# 300252  206771    Vistara  Chennai     1  Hyderabad   8640   economy  UK-826
# 300253  206772    Vistara  Chennai     1  Hyderabad   8640   economy  UK-822
# 300254  206773    Vistara  Chennai     1  Hyderabad   8640   economy  UK-824
#
#        departure_time arrival_time days_left  duration
# 0             Evening        Night         1       120
# 1             Evening        Night         1       135
# 2               Night        Night         1      1485
# 3               Night        Night         1      1590
# 4             Evening        Night         1       400
# ...               ...          ...       ...       ...
# 300250  Early_Morning        Night        49       830
# 300251  Early_Morning        Night        49       830
# 300252      Afternoon      Morning        49      1235
# 300253        Morning      Morning        49      1400
# 300254          Night        Night        49      1465
#
# [300255 rows x 12 columns]

# %%
df
# Out:
#           airline     from  stop         to  price     class  flight  \
# 0       Air India    Delhi     0     Mumbai  25612  business  AI-868
# 1       Air India    Delhi     0     Mumbai  25612  business  AI-624
# 2       Air India    Delhi     1     Mumbai  42220  business  AI-531
# 3       Air India    Delhi     1     Mumbai  44450  business  AI-839
# 4       Air India    Delhi     1     Mumbai  46690  business  AI-544
# ...           ...      ...   ...        ...    ...       ...     ...
# 206769    Vistara  Chennai     1  Hyderabad   7697   economy  UK-832
# 206770    Vistara  Chennai     1  Hyderabad   7709   economy  UK-832
# 206771    Vistara  Chennai     1  Hyderabad   8640   economy  UK-826
# 206772    Vistara  Chennai     1  Hyderabad   8640   economy  UK-822
# 206773    Vistara  Chennai     1  Hyderabad   8640   economy  UK-824
#
#        departure_time arrival_time days_left  duration
# 0             Evening        Night         1       120
# 1             Evening        Night         1       135
# 2               Night        Night         1      1485
# 3               Night        Night         1      1590
# 4             Evening        Night         1       400
# ...               ...          ...       ...       ...
# 206769  Early_Morning        Night        49       830
# 206770  Early_Morning        Night        49       830
# 206771      Afternoon      Morning        49      1235
# 206772        Morning      Morning        49      1400
# 206773          Night        Night        49      1465
#
# [300255 rows x 11 columns]

# %%
df['price']=df['price'].astype(int)

# %% [markdown]
# ## merging source and destination city as one

# %%
df["Travelling_Cities"] = df["from"] +'-' + df["to"]

# %%
df['Travelling_Cities'].value_counts()
# Out:
# Delhi-Mumbai           15289
# Mumbai-Delhi           14809
# Delhi-Bangalore        14012
# Bangalore-Delhi        13756
# Bangalore-Mumbai       12939
# Mumbai-Bangalore       12885
# Mumbai-Kolkata         12602
# Delhi-Kolkata          11934
# Kolkata-Mumbai         11467
# Delhi-Chennai          10780
# Kolkata-Delhi          10506
# Mumbai-Hyderabad       10477
# Mumbai-Chennai         10130
# Hyderabad-Mumbai       10073
# Bangalore-Kolkata      10028
# Kolkata-Bangalore       9824
# Chennai-Delhi           9783
# Chennai-Mumbai          9338
# Delhi-Hyderabad         9328
# Bangalore-Hyderabad     8970
# Hyderabad-Delhi         8506
# Hyderabad-Kolkata       7987
# Hyderabad-Bangalore     7898
# Kolkata-Hyderabad       7897
# Chennai-Kolkata         6983
# Kolkata-Chennai         6653
# Chennai-Bangalore       6493
# Bangalore-Chennai       6410
# Hyderabad-Chennai       6395
# Chennai-Hyderabad       6103
# Name: Travelling_Cities, dtype: int64

# %%
df.describe()
# Out:
#                 stop          price       duration
# count  300255.000000  300255.000000  300255.000000
# mean        0.924204   20884.009249     733.071306
# std         0.398182   22696.041149     431.571309
# min         0.000000    1105.000000      50.000000
# 25%         1.000000    4783.000000     405.000000
# 50%         1.000000    7425.000000     675.000000
# 75%         1.000000   42521.000000     970.000000
# max         2.000000  123071.000000    2990.000000

# %% [markdown]
# ## what do we see here ! Mean of price is way greater than median that means data is not normally distributed it is right skewed (positive-skew) lets see that with the help of distribution plot

# %% [markdown]
# # Time for some fun, Data visualization Time

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.title('Flight Price Distribution Plot')
sns.distplot(df.price,color='red')

plt.subplot(1,2,2)
plt.title('Flight Price Spread')
sns.boxplot(y=df.price,color = 'green')

plt.show()

# %%
plt.figure(figsize=(12,6))
sns.catplot('price','Travelling_Cities',hue='class',data = df,kind='bar')
plt.title( 'price comparison with diffrent destination respective to class')
# Out:
# Text(0.5, 1.0, 'price comparison with diffrent destination respective to class')

# %%
plt.figure(figsize=(12,8))
df.groupby(['Travelling_Cities'])['Travelling_Cities'].count().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Travelling_Cities'>

# %% [markdown]
# ### as we can see delhi to mumbai is the most travelled location by flight

# %%
plt.figure(figsize=(30,10))
sns.catplot(x='airline',y='price',hue='class',data=df.sort_values('price',ascending=False),kind='boxen',height = 8, aspect = 3)
plt.show()

# %% [markdown]
# # observation
#
# ### Holy Smokes  Vistara prices are skyrocketing i would need a crowdfunding to travel in a business class
# ### Trujet has the cheapest price (not suprised )
# ### Vistara and Air India provide business class facility for domestic flights and prices are way expensive as compared to economy class dont wonder why

# %%
fig, axes = plt.subplots(1,2, figsize=(12,8))
sns.boxplot(x='from', y='price', data=df, ax=axes[0])
axes[0].set(title='Price based on Source city')

sns.boxplot(x='to', y='price', data=df, ax=axes[1])
axes[1].set(title='Price based on Destination city')
# Out:
# [Text(0.5, 1.0, 'Price based on Destination city')]

# %% [markdown]
# ## theres shouldn't be a doubt there  kolkata being the most costly sorce and destination to travel as its the most farthest city from the above cities..

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='arrival_time',notch= True,y='price',data=df).tick_params(axis='x', rotation=45)

# %% [markdown]
# # Psst !! Here a secret information for the budgeteer if you wanna save some money travel late at night

# %%
df['stop'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df["duration"],df["price"],color='b',marker='+')
plt.title('Duration vs Price')
plt.xlabel('Duration Of Flight')
plt.ylabel('Price Of The Flight')
plt.grid(False)

# %%
plt.figure(figsize=(16,8))
sns.scatterplot('duration','price',hue='class',data=df)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='price'>

# %% [markdown]
# # mostly flights duration is from 1 to 41 hours

# %%
plt.figure(figsize=(16,8))
sns.barplot('days_left','price',hue='class',data=df,color='red')
# Out:
# <AxesSubplot:xlabel='days_left', ylabel='price'>

# %% [markdown]
# # As there's a saying,' Always plan your trip ahead' above graph is a prove showing drop in price when you book your tickets in advance

# %%
pie =df.groupby(['airline'])['airline'].count().sort_values()
keys=['Trujet','StarAir','Spicejet','airasia','go first',' indigo','air india','vistara']
explode = [0.3, 0.1, 0, 0, 0,0,0,0]
palette_color = sns.color_palette('bright')
plt.pie(pie, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%',pctdistance=0.5,radius=1.8,startangle=1,rotatelabels=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1aa9943cf10>,
#   <matplotlib.patches.Wedge at 0x1aa9943c280>,
#   <matplotlib.patches.Wedge at 0x1aa9feaaa30>,
#   <matplotlib.patches.Wedge at 0x1aa9944ebe0>,
#   <matplotlib.patches.Wedge at 0x1aa9944e820>,
#   <matplotlib.patches.Wedge at 0x1aa9942e550>,
#   <matplotlib.patches.Wedge at 0x1aa9942e1f0>,
#   <matplotlib.patches.Wedge at 0x1aa9fe933d0>],
#  [Text(2.279635465190141, 0.04076942294577457, 'Trujet'),
#   Text(2.07962656376053, 0.039412628706678374, 'StarAir'),
#   Text(1.9671770185567476, 0.2249768380571354, 'Spicejet'),
#   Text(1.8412510419103894, 0.7281446289466855, 'airasia'),
#   Text(1.3971483504792517, 1.402988412907643, 'go first'),
#   Text(0.17733524693662966, 1.9720426491822953, ' indigo'),
#   Text(-1.8510226391216318, 0.7029332752539107, 'air india'),
#   Text(0.49072396095470355, -1.918225741185048, 'vistara')],
#  [Text(1.1998081395737583, 0.02145759102409188, '0%'),
#   Text(0.9998204633464087, 0.01894837918590307, '0%'),
#   Text(0.8941713720712489, 0.10226219911687971, '3%'),
#   Text(0.8369322917774497, 0.3309748313394025, '5%'),
#   Text(0.6350674320360234, 0.6377220058671104, '8%'),
#   Text(0.08060693042574076, 0.8963830223555886, '14%'),
#   Text(-0.8413739268734689, 0.3195151251154139, '27%'),
#   Text(0.2230563458885016, -0.871920791447749, '43%')])

# %% [markdown]
# ## People ignored Starjet and Trujet just like Indians ignore traffic rules , Vistrara is the most used airline followed by AirIndia and Indigo

# %%
df.head()
# Out:
#      airline   from  stop      to  price     class  flight departure_time  \
# 0  Air India  Delhi     0  Mumbai  25612  business  AI-868        Evening
# 1  Air India  Delhi     0  Mumbai  25612  business  AI-624        Evening
# 2  Air India  Delhi     1  Mumbai  42220  business  AI-531          Night
# 3  Air India  Delhi     1  Mumbai  44450  business  AI-839          Night
# 4  Air India  Delhi     1  Mumbai  46690  business  AI-544        Evening
#
#   arrival_time days_left  duration Travelling_Cities
# 0        Night         1       120      Delhi-Mumbai
# 1        Night         1       135      Delhi-Mumbai
# 2        Night         1      1485      Delhi-Mumbai
# 3        Night         1      1590      Delhi-Mumbai
# 4        Night         1       400      Delhi-Mumbai

# %% [markdown]
# ## Dealing with Categorical variables

# %%
df['days_left']=df['days_left'].astype(int)

# %%
df['arrival_time']=df['arrival_time'].map({'Evening':3, 'Night':4, 'Early_Morning':0, 'Morning':1, 'Afternoon':2,
       'Late_Night':5}).astype(int)

# %%
df['departure_time']=df['departure_time'].map({'Evening':3, 'Night':4, 'Early_Morning':0, 'Morning':1, 'Afternoon':2,
       'Late_Night':5}).astype(int)

# %%
df['class']=df['class'].map({'business':0, 'economy':1}).astype(int)

# %%
df['airline'].unique()
# Out:
# array(['Air India', 'Vistara', 'SpiceJet', 'AirAsia', 'GO FIRST',
#        'Indigo', 'Trujet', 'StarAir'], dtype=object)

# %%
df['airline']= df['airline'].map({'Air India':0, 'Vistara':1, 'SpiceJet':2, 'AirAsia':3, 'GO FIRST':4,
       'Indigo':5, 'Trujet':6, 'StarAir':7}).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300255 entries, 0 to 206773
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   airline            300255 non-null  int32
#  1   from               300255 non-null  object
#  2   stop               300255 non-null  int32
#  3   to                 300255 non-null  object
#  4   price              300255 non-null  int32
#  5   class              300255 non-null  int32
#  6   flight             300255 non-null  object
#  7   departure_time     300255 non-null  int32
#  8   arrival_time       300255 non-null  int32
#  9   days_left          300255 non-null  int32
#  10  duration           300255 non-null  int32
#  11  Travelling_Cities  300255 non-null  object
# dtypes: int32(8), object(4)
# memory usage: 20.6+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
#df['flight']=encoder.fit_transform(df['flight'])
df['Travelling_Cities']=encoder.fit_transform(df['Travelling_Cities'])

# %%
df.drop(['from','to','flight'],axis=1,inplace =True)

# %%
df.rename({'class':'classs'}, axis=1,inplace=True)

# %%
df
# Out:
#         airline  stop  price  classs  departure_time  arrival_time  days_left  \
# 0             0     0  25612       0               3             4          1
# 1             0     0  25612       0               3             4          1
# 2             0     1  42220       0               4             4          1
# 3             0     1  44450       0               4             4          1
# 4             0     1  46690       0               3             4          1
# ...         ...   ...    ...     ...             ...           ...        ...
# 206769        1     1   7697       1               0             4         49
# 206770        1     1   7709       1               0             4         49
# 206771        1     1   8640       1               2             1         49
# 206772        1     1   8640       1               1             1         49
# 206773        1     1   8640       1               4             4         49
#
#         duration  Travelling_Cities
# 0            120                 14
# 1            135                 14
# 2           1485                 14
# 3           1590                 14
# 4            400                 14
# ...          ...                ...
# 206769       830                  7
# 206770       830                  7
# 206771      1235                  7
# 206772      1400                  7
# 206773      1465                  7
#
# [300255 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['airline', 'stop', 'price', 'classs', 'departure_time', 'arrival_time',
#        'days_left', 'duration', 'Travelling_Cities'],
#       dtype='object')

# %%
plt.figure(figsize = (20, 10))
sns.heatmap(df.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
X = df.drop(['price'],axis=1)
y = df['price']

# %% [markdown]
# # Test train Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.24, random_state=32)

# %% [markdown]
# # Model Implimentation

# %%
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error,mean_absolute_percentage_error
from xgboost import XGBRegressor
import math

# %%
def predict(model):
    model.fit(X_train,y_train)
    training_score = model.score(X_train,y_train)
    y_predict =model.predict(X_test)
    score =r2_score(y_test,y_predict)
    mae = mean_absolute_error(y_test,y_predict)
    mse = mean_squared_error(y_test,y_predict)
    rmse= math.sqrt(mse)
    error = y_test-y_predict
  
    
    print(pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_predict}))
    
    print('Training score: ',training_score)
    print('r2 score is: ',score)
   
    print('MAE: ',mae)
    print('MSE: ',mse)
    print('RMSE: ',math.sqrt(mse))
    return sns.distplot(error,color='r')

# %% [markdown]
# # Linear Regression

# %%
predict(LinearRegression())
# Out:
#         Real Values  Predicted Values
# 187265         3361       4090.622499
# 25128          3754       6422.728101
# 131095         5334       1423.737067
# 81729          4249       6069.375489
# 12702         16210      14902.153272
# ...             ...               ...
# 114253         5322       6273.489326
# 23730         79024      55311.602375
# 20324         53152      53439.025867
# 118268         4687       5627.837330
# 134337         5102       4334.302335
#
# [72062 rows x 2 columns]
# Training score:  0.9004631462877295
# r2 score is:  0.9013926378035927
# MAE:  4630.324803592543
# MSE:  50698068.99590504
# RMSE:  7120.257649545067
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# # Decision Tree Regressor

# %%
predict(DecisionTreeRegressor(max_depth=50))
# Out:
#         Real Values  Predicted Values
# 187265         3361            2051.0
# 25128          3754            2482.0
# 131095         5334            4499.0
# 81729          4249            4249.0
# 12702         16210           16210.0
# ...             ...               ...
# 114253         5322            5322.0
# 23730         79024           84512.0
# 20324         53152           53152.0
# 118268         4687            4687.0
# 134337         5102            5102.0
#
# [72062 rows x 2 columns]
# Training score:  0.9993896522174023
# r2 score is:  0.9758947481479644
# MAE:  1191.0427317217582
# MSE:  12393493.6939495
# RMSE:  3520.439417736016
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# # Random Forest Regressor

# %%
predict(RandomForestRegressor(n_estimators=20,max_depth=20))
# Out:
#         Real Values  Predicted Values
# 187265         3361       3081.836427
# 25128          3754       4423.674305
# 131095         5334       4806.722893
# 81729          4249       4361.281183
# 12702         16210      10884.633262
# ...             ...               ...
# 114253         5322       5463.560817
# 23730         79024      76016.980833
# 20324         53152      53609.166234
# 118268         4687       4687.000000
# 134337         5102       5233.653795
#
# [72062 rows x 2 columns]
# Training score:  0.99376396531774
# r2 score is:  0.9845014954304018
# MAE:  1262.2540354587004
# MSE:  7968413.681300872
# RMSE:  2822.8378772612627
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# # KNeighborsRegressor

# %%
predict(KNeighborsRegressor())
# Out:
#         Real Values  Predicted Values
# 187265         3361            3160.6
# 25128          3754            5194.8
# 131095         5334            5083.0
# 81729          4249           29726.8
# 12702         16210            7401.8
# ...             ...               ...
# 114253         5322           36515.0
# 23730         79024           48457.0
# 20324         53152           24934.0
# 118268         4687            4571.8
# 134337         5102           23169.6
#
# [72062 rows x 2 columns]
# Training score:  0.5649246422357481
# r2 score is:  0.33635337384792485
# MAE:  13727.645011240322
# MSE:  341207813.4139902
# RMSE:  18471.811319250482
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# # ADAboost

# %%
predict(AdaBoostRegressor())
# Out:
#         Real Values  Predicted Values
# 187265         3361       5794.021836
# 25128          3754       5520.320093
# 131095         5334       4597.454545
# 81729          4249       6270.427405
# 12702         16210      10416.465187
# ...             ...               ...
# 114253         5322       6474.426562
# 23730         79024      59896.891721
# 20324         53152      59504.535167
# 118268         4687       5794.021836
# 134337         5102       6270.427405
#
# [72062 rows x 2 columns]
# Training score:  0.9278608957980318
# r2 score is:  0.9277000328924538
# MAE:  3971.549183576831
# MSE:  37172363.59612899
# RMSE:  6096.9142683925775
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# # Gradient Boost

# %%
predict(GradientBoostingRegressor(n_estimators=50,alpha=0.06,learning_rate=0.9))
# Out:
#         Real Values  Predicted Values
# 187265         3361       2434.363925
# 25128          3754       6469.887036
# 131095         5334       4851.349019
# 81729          4249       5296.506855
# 12702         16210       3983.233328
# ...             ...               ...
# 114253         5322       1016.155259
# 23730         79024      63081.539940
# 20324         53152      53610.419031
# 118268         4687       5358.444269
# 134337         5102       4394.494277
#
# [72062 rows x 2 columns]
# Training score:  0.9572993108798263
# r2 score is:  0.9564355845768996
# MAE:  2891.9645537521146
# MSE:  22398243.79935683
# RMSE:  4732.678290287311
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# # Lasso

# %%
predict(Lasso(alpha=0.1,normalize=True))
# Out:
#         Real Values  Predicted Values
# 187265         3361       4184.599947
# 25128          3754       6362.314058
# 131095         5334       1348.308011
# 81729          4249       6151.955630
# 12702         16210      14780.822857
# ...             ...               ...
# 114253         5322       6389.619217
# 23730         79024      55190.631184
# 20324         53152      53351.235775
# 118268         4687       5746.932073
# 134337         5102       4628.923602
#
# [72062 rows x 2 columns]
# Training score:  0.9004143215516014
# r2 score is:  0.9013604626877985
# MAE:  4607.055269787375
# MSE:  50714611.535976626
# RMSE:  7121.419207993349
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# # Catboost

# %%
from catboost import CatBoostRegressor

# %%
predict(CatBoostRegressor(loss_function='RMSE',max_depth=8))
# Out:
# Learning rate set to 0.096559
# 0:	learn: 20661.8130982	total: 186ms	remaining: 3m 6s
# 1:	learn: 18827.6539544	total: 215ms	remaining: 1m 47s
# 2:	learn: 17198.8813050	total: 245ms	remaining: 1m 21s
# 3:	learn: 15723.7132280	total: 274ms	remaining: 1m 8s
# 4:	learn: 14426.2213138	total: 290ms	remaining: 57.8s
# 5:	learn: 13252.0327983	total: 319ms	remaining: 52.9s
# 6:	learn: 12207.9938950	total: 349ms	remaining: 49.5s
# 7:	learn: 11270.8781274	total: 381ms	remaining: 47.2s
# 8:	learn: 10447.8324036	total: 411ms	remaining: 45.2s
# 9:	learn: 9721.5377989	total: 443ms	remaining: 43.8s
# 10:	learn: 9090.0220239	total: 472ms	remaining: 42.5s
# 11:	learn: 8528.7950858	total: 502ms	remaining: 41.3s
# 12:	learn: 8031.4627115	total: 530ms	remaining: 40.2s
# 13:	learn: 7601.7992483	total: 560ms	remaining: 39.5s
# 14:	learn: 7233.4592670	total: 587ms	remaining: 38.6s
# 15:	learn: 6913.2053782	total: 618ms	remaining: 38s
# 16:	learn: 6632.8372614	total: 649ms	remaining: 37.5s
# 17:	learn: 6381.2591318	total: 679ms	remaining: 37.1s
# 18:	learn: 6172.6425470	total: 706ms	remaining: 36.4s
# 19:	learn: 5980.3259015	total: 734ms	remaining: 35.9s
# 20:	learn: 5835.3132410	total: 764ms	remaining: 35.6s
# 21:	learn: 5703.9162753	total: 793ms	remaining: 35.3s
# 22:	learn: 5579.5789901	total: 822ms	remaining: 34.9s
# 23:	learn: 5477.7361180	total: 851ms	remaining: 34.6s
# 24:	learn: 5394.0832113	total: 880ms	remaining: 34.3s
# 25:	learn: 5313.9996380	total: 911ms	remaining: 34.1s
# 26:	learn: 5254.8374712	total: 940ms	remaining: 33.9s
# 27:	learn: 5197.0083961	total: 971ms	remaining: 33.7s
# 28:	learn: 5138.6274816	total: 1s	remaining: 33.6s
# 29:	learn: 5090.4965629	total: 1.03s	remaining: 33.4s
# 30:	learn: 5057.3355429	total: 1.06s	remaining: 33.3s
# 31:	learn: 5020.7666614	total: 1.09s	remaining: 33.1s
# 32:	learn: 4987.6623299	total: 1.13s	remaining: 33s
# 33:	learn: 4959.2436175	total: 1.15s	remaining: 32.8s
# 34:	learn: 4938.9237065	total: 1.18s	remaining: 32.7s
# 35:	learn: 4917.1931256	total: 1.21s	remaining: 32.5s
# 36:	learn: 4894.7528520	total: 1.24s	remaining: 32.3s
# 37:	learn: 4870.9497984	total: 1.27s	remaining: 32.1s
# 38:	learn: 4854.1095175	total: 1.3s	remaining: 32.1s
# 39:	learn: 4834.9847480	total: 1.33s	remaining: 32s
# 40:	learn: 4821.6141330	total: 1.36s	remaining: 31.8s
# 41:	learn: 4808.4202036	total: 1.39s	remaining: 31.7s
# 42:	learn: 4791.3482364	total: 1.42s	remaining: 31.5s
# 43:	learn: 4784.5459232	total: 1.45s	remaining: 31.5s
# 44:	learn: 4777.8135364	total: 1.48s	remaining: 31.4s
# 45:	learn: 4763.0879120	total: 1.51s	remaining: 31.3s
# 46:	learn: 4757.2499528	total: 1.54s	remaining: 31.2s
# 47:	learn: 4748.3497755	total: 1.57s	remaining: 31.1s
# 48:	learn: 4739.4253441	total: 1.6s	remaining: 31.1s
# 49:	learn: 4732.7447538	total: 1.63s	remaining: 31s
# 50:	learn: 4725.6793567	total: 1.66s	remaining: 30.9s
# 51:	learn: 4719.0088605	total: 1.69s	remaining: 30.7s
# 52:	learn: 4708.6985862	total: 1.72s	remaining: 30.7s
# 53:	learn: 4701.7190193	total: 1.75s	remaining: 30.6s
# 54:	learn: 4692.0457994	total: 1.78s	remaining: 30.5s
# 55:	learn: 4683.0667087	total: 1.81s	remaining: 30.5s
# 56:	learn: 4679.4862574	total: 1.84s	remaining: 30.4s
# 57:	learn: 4669.5447807	total: 1.87s	remaining: 30.3s
# 58:	learn: 4663.7544402	total: 1.9s	remaining: 30.2s
# 59:	learn: 4651.7925983	total: 1.93s	remaining: 30.2s
# 60:	learn: 4643.5794398	total: 1.96s	remaining: 30.1s
# 61:	learn: 4638.3870583	total: 1.99s	remaining: 30.1s
# 62:	learn: 4628.9595016	total: 2.02s	remaining: 30s
# 63:	learn: 4621.3304976	total: 2.05s	remaining: 29.9s
# 64:	learn: 4614.9336564	total: 2.08s	remaining: 29.9s
# 65:	learn: 4607.5029462	total: 2.11s	remaining: 29.9s
# 66:	learn: 4599.7271498	total: 2.14s	remaining: 29.9s
# 67:	learn: 4595.4840593	total: 2.18s	remaining: 29.9s
# 68:	learn: 4593.4488880	total: 2.21s	remaining: 29.9s
# 69:	learn: 4587.9871160	total: 2.24s	remaining: 29.8s
# 70:	learn: 4582.5026213	total: 2.27s	remaining: 29.7s
# 71:	learn: 4579.2939686	total: 2.3s	remaining: 29.7s
# 72:	learn: 4574.5444629	total: 2.33s	remaining: 29.6s
# 73:	learn: 4569.0901086	total: 2.36s	remaining: 29.6s
# 74:	learn: 4561.1067948	total: 2.39s	remaining: 29.5s
# 75:	learn: 4553.7178384	total: 2.42s	remaining: 29.5s
# 76:	learn: 4547.2285621	total: 2.46s	remaining: 29.5s
# 77:	learn: 4543.9412501	total: 2.49s	remaining: 29.4s
# 78:	learn: 4539.3568094	total: 2.51s	remaining: 29.3s
# 79:	learn: 4534.8923140	total: 2.54s	remaining: 29.3s
# 80:	learn: 4523.5813249	total: 2.58s	remaining: 29.2s
# 81:	learn: 4520.5879754	total: 2.61s	remaining: 29.2s
# 82:	learn: 4512.0543263	total: 2.64s	remaining: 29.2s
# 83:	learn: 4505.1576577	total: 2.67s	remaining: 29.1s
# 84:	learn: 4499.2391537	total: 2.7s	remaining: 29.1s
# 85:	learn: 4496.6370440	total: 2.73s	remaining: 29s
# 86:	learn: 4490.5140950	total: 2.76s	remaining: 29s
# 87:	learn: 4485.2669907	total: 2.79s	remaining: 28.9s
# 88:	learn: 4479.2227382	total: 2.83s	remaining: 28.9s
# 89:	learn: 4474.2739133	total: 2.86s	remaining: 28.9s
# 90:	learn: 4468.6041545	total: 2.89s	remaining: 28.9s
# 91:	learn: 4465.6142535	total: 2.92s	remaining: 28.8s
# 92:	learn: 4457.5989455	total: 2.95s	remaining: 28.8s
# 93:	learn: 4454.0072020	total: 2.98s	remaining: 28.7s
# 94:	learn: 4451.1848350	total: 3.01s	remaining: 28.7s
# 95:	learn: 4447.7951993	total: 3.04s	remaining: 28.6s
# 96:	learn: 4439.2323219	total: 3.07s	remaining: 28.6s
# 97:	learn: 4431.8344839	total: 3.1s	remaining: 28.6s
# 98:	learn: 4426.8905758	total: 3.13s	remaining: 28.5s
# 99:	learn: 4421.6159428	total: 3.16s	remaining: 28.5s
# 100:	learn: 4415.2666319	total: 3.19s	remaining: 28.4s
# 101:	learn: 4409.8862290	total: 3.22s	remaining: 28.3s
# 102:	learn: 4400.6847137	total: 3.25s	remaining: 28.3s
# 103:	learn: 4396.8067248	total: 3.28s	remaining: 28.3s
# 104:	learn: 4391.4193210	total: 3.31s	remaining: 28.3s
# 105:	learn: 4389.7980003	total: 3.34s	remaining: 28.2s
# 106:	learn: 4385.1997294	total: 3.37s	remaining: 28.1s
# 107:	learn: 4380.0535973	total: 3.4s	remaining: 28.1s
# 108:	learn: 4376.9676563	total: 3.43s	remaining: 28s
# 109:	learn: 4369.7763969	total: 3.46s	remaining: 28s
# 110:	learn: 4363.1948997	total: 3.5s	remaining: 28s
# 111:	learn: 4359.3655544	total: 3.54s	remaining: 28s
# 112:	learn: 4354.6940251	total: 3.57s	remaining: 28s
# 113:	learn: 4350.2143275	total: 3.6s	remaining: 28s
# 114:	learn: 4346.0497783	total: 3.63s	remaining: 27.9s
# 115:	learn: 4344.1123294	total: 3.66s	remaining: 27.9s
# 116:	learn: 4340.5269996	total: 3.69s	remaining: 27.9s
# 117:	learn: 4334.7213538	total: 3.73s	remaining: 27.9s
# 118:	learn: 4328.4625115	total: 3.76s	remaining: 27.8s
# 119:	learn: 4321.0302504	total: 3.79s	remaining: 27.8s
# 120:	learn: 4314.1547253	total: 3.82s	remaining: 27.8s
# 121:	learn: 4307.4850275	total: 3.86s	remaining: 27.8s
# 122:	learn: 4300.4131308	total: 3.89s	remaining: 27.7s
# 123:	learn: 4295.7256623	total: 3.92s	remaining: 27.7s
# 124:	learn: 4289.5717330	total: 3.95s	remaining: 27.7s
# 125:	learn: 4285.3404858	total: 3.98s	remaining: 27.6s
# 126:	learn: 4282.8478546	total: 4.01s	remaining: 27.6s
# 127:	learn: 4281.1352894	total: 4.05s	remaining: 27.6s
# 128:	learn: 4276.9555156	total: 4.08s	remaining: 27.6s
# 129:	learn: 4273.1236805	total: 4.11s	remaining: 27.5s
# 130:	learn: 4269.3214787	total: 4.15s	remaining: 27.5s
# 131:	learn: 4263.7207347	total: 4.18s	remaining: 27.5s
# 132:	learn: 4260.0357359	total: 4.21s	remaining: 27.4s
# 133:	learn: 4257.9111402	total: 4.24s	remaining: 27.4s
# 134:	learn: 4253.6018575	total: 4.27s	remaining: 27.4s
# 135:	learn: 4247.9091747	total: 4.3s	remaining: 27.3s
# 136:	learn: 4245.9080731	total: 4.33s	remaining: 27.3s
# 137:	learn: 4240.7856680	total: 4.36s	remaining: 27.3s
# 138:	learn: 4238.6838253	total: 4.39s	remaining: 27.2s
# 139:	learn: 4235.0083803	total: 4.42s	remaining: 27.2s
# 140:	learn: 4231.2547701	total: 4.46s	remaining: 27.2s
# 141:	learn: 4227.6309617	total: 4.49s	remaining: 27.1s
# 142:	learn: 4224.4974733	total: 4.53s	remaining: 27.1s
# 143:	learn: 4219.4699098	total: 4.56s	remaining: 27.1s
# 144:	learn: 4215.3923536	total: 4.59s	remaining: 27.1s
# 145:	learn: 4210.9742504	total: 4.63s	remaining: 27.1s
# 146:	learn: 4207.6737204	total: 4.65s	remaining: 27s
# 147:	learn: 4206.4968260	total: 4.68s	remaining: 27s
# 148:	learn: 4204.9169138	total: 4.71s	remaining: 26.9s
# 149:	learn: 4203.1634323	total: 4.75s	remaining: 26.9s
# 150:	learn: 4197.3345700	total: 4.78s	remaining: 26.9s
# 151:	learn: 4195.8179039	total: 4.81s	remaining: 26.8s
# 152:	learn: 4190.2310535	total: 4.84s	remaining: 26.8s
# 153:	learn: 4185.5663671	total: 4.87s	remaining: 26.8s
# 154:	learn: 4182.1850112	total: 4.9s	remaining: 26.7s
# 155:	learn: 4180.3048895	total: 4.93s	remaining: 26.7s
# 156:	learn: 4176.0483249	total: 4.96s	remaining: 26.7s
# 157:	learn: 4171.8337473	total: 5s	remaining: 26.6s
# 158:	learn: 4167.7180630	total: 5.04s	remaining: 26.6s
# 159:	learn: 4166.5441211	total: 5.07s	remaining: 26.6s
# 160:	learn: 4162.6294071	total: 5.1s	remaining: 26.6s
# 161:	learn: 4159.6098932	total: 5.13s	remaining: 26.5s
# 162:	learn: 4157.1914189	total: 5.16s	remaining: 26.5s
# 163:	learn: 4155.9143758	total: 5.19s	remaining: 26.5s
# 164:	learn: 4154.6584626	total: 5.22s	remaining: 26.4s
# 165:	learn: 4149.8190720	total: 5.25s	remaining: 26.4s
# 166:	learn: 4144.1526634	total: 5.28s	remaining: 26.4s
# 167:	learn: 4141.8104736	total: 5.32s	remaining: 26.3s
# 168:	learn: 4137.1051200	total: 5.35s	remaining: 26.3s
# 169:	learn: 4135.6335581	total: 5.38s	remaining: 26.3s
# 170:	learn: 4131.1787985	total: 5.41s	remaining: 26.2s
# 171:	learn: 4129.1685986	total: 5.44s	remaining: 26.2s
# 172:	learn: 4124.7732057	total: 5.47s	remaining: 26.2s
# 173:	learn: 4122.2146665	total: 5.5s	remaining: 26.1s
# 174:	learn: 4119.8846729	total: 5.54s	remaining: 26.1s
# 175:	learn: 4117.6473888	total: 5.57s	remaining: 26.1s
# 176:	learn: 4115.2113507	total: 5.6s	remaining: 26s
# 177:	learn: 4111.4258075	total: 5.63s	remaining: 26s
# 178:	learn: 4110.1226097	total: 5.66s	remaining: 26s
# 179:	learn: 4107.3361688	total: 5.69s	remaining: 25.9s
# 180:	learn: 4106.0994930	total: 5.72s	remaining: 25.9s
# 181:	learn: 4104.4591584	total: 5.75s	remaining: 25.9s
# 182:	learn: 4100.1745337	total: 5.79s	remaining: 25.8s
# 183:	learn: 4095.4722812	total: 5.82s	remaining: 25.8s
# 184:	learn: 4093.8790470	total: 5.86s	remaining: 25.8s
# 185:	learn: 4092.0518993	total: 5.89s	remaining: 25.8s
# 186:	learn: 4085.7437732	total: 5.93s	remaining: 25.8s
# 187:	learn: 4082.7651269	total: 5.96s	remaining: 25.7s
# 188:	learn: 4080.7057813	total: 5.99s	remaining: 25.7s
# 189:	learn: 4078.8104699	total: 6.03s	remaining: 25.7s
# 190:	learn: 4076.3751172	total: 6.06s	remaining: 25.7s
# 191:	learn: 4073.2859223	total: 6.09s	remaining: 25.6s
# 192:	learn: 4072.4277661	total: 6.13s	remaining: 25.6s
# 193:	learn: 4069.2710503	total: 6.16s	remaining: 25.6s
# 194:	learn: 4064.5777562	total: 6.2s	remaining: 25.6s
# 195:	learn: 4061.1250235	total: 6.23s	remaining: 25.6s
# 196:	learn: 4059.4322870	total: 6.26s	remaining: 25.5s
# 197:	learn: 4057.1405683	total: 6.3s	remaining: 25.5s
# 198:	learn: 4053.9534075	total: 6.34s	remaining: 25.5s
# 199:	learn: 4052.2955431	total: 6.37s	remaining: 25.5s
# 200:	learn: 4049.4470222	total: 6.41s	remaining: 25.5s
# 201:	learn: 4048.5073288	total: 6.44s	remaining: 25.4s
# 202:	learn: 4047.1568744	total: 6.47s	remaining: 25.4s
# 203:	learn: 4046.0474131	total: 6.5s	remaining: 25.4s
# 204:	learn: 4044.5412915	total: 6.53s	remaining: 25.3s
# 205:	learn: 4043.1181857	total: 6.56s	remaining: 25.3s
# 206:	learn: 4040.2759606	total: 6.59s	remaining: 25.3s
# 207:	learn: 4039.4358017	total: 6.63s	remaining: 25.2s
# 208:	learn: 4036.8815855	total: 6.66s	remaining: 25.2s
# 209:	learn: 4028.7946848	total: 6.69s	remaining: 25.2s
# 210:	learn: 4027.0559341	total: 6.73s	remaining: 25.2s
# 211:	learn: 4026.2804547	total: 6.76s	remaining: 25.1s
# 212:	learn: 4023.9633631	total: 6.8s	remaining: 25.1s
# 213:	learn: 4021.0332228	total: 6.83s	remaining: 25.1s
# 214:	learn: 4017.4822115	total: 6.86s	remaining: 25.1s
# 215:	learn: 4014.8566511	total: 6.89s	remaining: 25s
# 216:	learn: 4012.2505795	total: 6.92s	remaining: 25s
# 217:	learn: 4010.6394629	total: 6.96s	remaining: 24.9s
# 218:	learn: 4007.1212973	total: 6.99s	remaining: 24.9s
# 219:	learn: 4003.5648136	total: 7.02s	remaining: 24.9s
# 220:	learn: 4002.4628133	total: 7.06s	remaining: 24.9s
# 221:	learn: 3999.7760218	total: 7.09s	remaining: 24.9s
# 222:	learn: 3998.7970006	total: 7.12s	remaining: 24.8s
# 223:	learn: 3995.4341371	total: 7.16s	remaining: 24.8s
# 224:	learn: 3990.7366769	total: 7.19s	remaining: 24.8s
# 225:	learn: 3988.5525199	total: 7.22s	remaining: 24.7s
# 226:	learn: 3986.8698299	total: 7.26s	remaining: 24.7s
# 227:	learn: 3985.0110314	total: 7.29s	remaining: 24.7s
# 228:	learn: 3983.4278199	total: 7.33s	remaining: 24.7s
# 229:	learn: 3979.9454558	total: 7.36s	remaining: 24.6s
# 230:	learn: 3977.6974993	total: 7.4s	remaining: 24.6s
# 231:	learn: 3976.4165058	total: 7.43s	remaining: 24.6s
# 232:	learn: 3974.5734805	total: 7.46s	remaining: 24.6s
# 233:	learn: 3971.2206009	total: 7.5s	remaining: 24.5s
# 234:	learn: 3968.9895583	total: 7.53s	remaining: 24.5s
# 235:	learn: 3967.5237055	total: 7.56s	remaining: 24.5s
# 236:	learn: 3964.1059179	total: 7.6s	remaining: 24.5s
# 237:	learn: 3961.0295889	total: 7.63s	remaining: 24.4s
# 238:	learn: 3958.2773544	total: 7.67s	remaining: 24.4s
# 239:	learn: 3955.3696511	total: 7.7s	remaining: 24.4s
# 240:	learn: 3953.5511639	total: 7.73s	remaining: 24.3s
# 241:	learn: 3949.6527509	total: 7.76s	remaining: 24.3s
# 242:	learn: 3947.9158313	total: 7.79s	remaining: 24.3s
# 243:	learn: 3945.5223731	total: 7.82s	remaining: 24.2s
# 244:	learn: 3942.6478304	total: 7.86s	remaining: 24.2s
# 245:	learn: 3940.4872668	total: 7.89s	remaining: 24.2s
# 246:	learn: 3939.0559065	total: 7.92s	remaining: 24.2s
# 247:	learn: 3934.4668295	total: 7.96s	remaining: 24.1s
# 248:	learn: 3933.0254948	total: 7.99s	remaining: 24.1s
# 249:	learn: 3930.7246615	total: 8.02s	remaining: 24.1s
# 250:	learn: 3928.3050171	total: 8.05s	remaining: 24s
# 251:	learn: 3925.4557617	total: 8.08s	remaining: 24s
# 252:	learn: 3924.1013715	total: 8.11s	remaining: 23.9s
# 253:	learn: 3921.3021480	total: 8.14s	remaining: 23.9s
# 254:	learn: 3920.3783954	total: 8.18s	remaining: 23.9s
# 255:	learn: 3917.3808064	total: 8.21s	remaining: 23.9s
# 256:	learn: 3915.9828484	total: 8.24s	remaining: 23.8s
# 257:	learn: 3913.7145799	total: 8.27s	remaining: 23.8s
# 258:	learn: 3909.6468817	total: 8.31s	remaining: 23.8s
# 259:	learn: 3907.8398677	total: 8.34s	remaining: 23.7s
# 260:	learn: 3905.7024241	total: 8.37s	remaining: 23.7s
# 261:	learn: 3903.1670307	total: 8.41s	remaining: 23.7s
# 262:	learn: 3902.0432410	total: 8.44s	remaining: 23.6s
# 263:	learn: 3900.1002068	total: 8.47s	remaining: 23.6s
# 264:	learn: 3899.2960080	total: 8.51s	remaining: 23.6s
# 265:	learn: 3897.1980320	total: 8.54s	remaining: 23.6s
# 266:	learn: 3896.1287894	total: 8.57s	remaining: 23.5s
# 267:	learn: 3894.4980034	total: 8.61s	remaining: 23.5s
# 268:	learn: 3892.8500008	total: 8.64s	remaining: 23.5s
# 269:	learn: 3891.9757543	total: 8.67s	remaining: 23.4s
# 270:	learn: 3889.7475056	total: 8.7s	remaining: 23.4s
# 271:	learn: 3887.7542063	total: 8.73s	remaining: 23.4s
# 272:	learn: 3885.7066482	total: 8.77s	remaining: 23.3s
# 273:	learn: 3883.4945565	total: 8.8s	remaining: 23.3s
# 274:	learn: 3882.5212860	total: 8.83s	remaining: 23.3s
# 275:	learn: 3881.7192407	total: 8.86s	remaining: 23.2s
# 276:	learn: 3879.6210525	total: 8.89s	remaining: 23.2s
# 277:	learn: 3878.6226730	total: 8.93s	remaining: 23.2s
# 278:	learn: 3876.0237045	total: 8.96s	remaining: 23.2s
# 279:	learn: 3875.4985023	total: 8.99s	remaining: 23.1s
# 280:	learn: 3874.9958864	total: 9.02s	remaining: 23.1s
# 281:	learn: 3872.9539071	total: 9.05s	remaining: 23.1s
# 282:	learn: 3871.9940271	total: 9.09s	remaining: 23s
# 283:	learn: 3871.6964232	total: 9.12s	remaining: 23s
# 284:	learn: 3868.0532048	total: 9.15s	remaining: 23s
# 285:	learn: 3867.5878189	total: 9.18s	remaining: 22.9s
# 286:	learn: 3866.2904920	total: 9.21s	remaining: 22.9s
# 287:	learn: 3865.4471268	total: 9.24s	remaining: 22.9s
# 288:	learn: 3864.5874990	total: 9.28s	remaining: 22.8s
# 289:	learn: 3862.3135247	total: 9.31s	remaining: 22.8s
# 290:	learn: 3860.3543400	total: 9.35s	remaining: 22.8s
# 291:	learn: 3858.1106663	total: 9.38s	remaining: 22.7s
# 292:	learn: 3855.9512619	total: 9.41s	remaining: 22.7s
# 293:	learn: 3855.0222392	total: 9.44s	remaining: 22.7s
# 294:	learn: 3853.1413913	total: 9.47s	remaining: 22.6s
# 295:	learn: 3851.2743608	total: 9.5s	remaining: 22.6s
# 296:	learn: 3850.0044930	total: 9.53s	remaining: 22.6s
# 297:	learn: 3848.8711826	total: 9.56s	remaining: 22.5s
# 298:	learn: 3847.8338751	total: 9.59s	remaining: 22.5s
# 299:	learn: 3846.8426453	total: 9.62s	remaining: 22.5s
# 300:	learn: 3845.0196155	total: 9.65s	remaining: 22.4s
# 301:	learn: 3838.2169543	total: 9.69s	remaining: 22.4s
# 302:	learn: 3836.1009349	total: 9.72s	remaining: 22.4s
# 303:	learn: 3835.2616747	total: 9.75s	remaining: 22.3s
# 304:	learn: 3833.9386112	total: 9.78s	remaining: 22.3s
# 305:	learn: 3832.4927376	total: 9.81s	remaining: 22.3s
# 306:	learn: 3831.4837094	total: 9.84s	remaining: 22.2s
# 307:	learn: 3830.2099822	total: 9.87s	remaining: 22.2s
# 308:	learn: 3829.4162874	total: 9.9s	remaining: 22.2s
# 309:	learn: 3826.3374412	total: 9.94s	remaining: 22.1s
# 310:	learn: 3825.2998605	total: 9.97s	remaining: 22.1s
# 311:	learn: 3822.8660374	total: 10s	remaining: 22.1s
# 312:	learn: 3821.4083490	total: 10s	remaining: 22s
# 313:	learn: 3819.2151905	total: 10.1s	remaining: 22s
# 314:	learn: 3816.1619504	total: 10.1s	remaining: 22s
# 315:	learn: 3812.9656826	total: 10.1s	remaining: 21.9s
# 316:	learn: 3809.4330701	total: 10.2s	remaining: 21.9s
# 317:	learn: 3808.0543570	total: 10.2s	remaining: 21.9s
# 318:	learn: 3804.6075329	total: 10.2s	remaining: 21.8s
# 319:	learn: 3802.7472279	total: 10.3s	remaining: 21.8s
# 320:	learn: 3802.0556729	total: 10.3s	remaining: 21.8s
# 321:	learn: 3799.4861309	total: 10.3s	remaining: 21.7s
# 322:	learn: 3796.4230367	total: 10.3s	remaining: 21.7s
# 323:	learn: 3794.9031965	total: 10.4s	remaining: 21.7s
# 324:	learn: 3791.2409251	total: 10.4s	remaining: 21.6s
# 325:	learn: 3788.7100309	total: 10.4s	remaining: 21.6s
# 326:	learn: 3786.2408294	total: 10.5s	remaining: 21.6s
# 327:	learn: 3781.7636854	total: 10.5s	remaining: 21.5s
# 328:	learn: 3780.4621377	total: 10.5s	remaining: 21.5s
# 329:	learn: 3778.6090082	total: 10.6s	remaining: 21.5s
# 330:	learn: 3777.5652882	total: 10.6s	remaining: 21.4s
# 331:	learn: 3776.6020883	total: 10.6s	remaining: 21.4s
# 332:	learn: 3773.2491693	total: 10.7s	remaining: 21.4s
# 333:	learn: 3769.8282255	total: 10.7s	remaining: 21.3s
# 334:	learn: 3767.8337890	total: 10.7s	remaining: 21.3s
# 335:	learn: 3766.1445665	total: 10.8s	remaining: 21.3s
# 336:	learn: 3765.2322113	total: 10.8s	remaining: 21.2s
# 337:	learn: 3763.1580733	total: 10.8s	remaining: 21.2s
# 338:	learn: 3762.4396655	total: 10.9s	remaining: 21.2s
# 339:	learn: 3759.9973514	total: 10.9s	remaining: 21.1s
# 340:	learn: 3758.3022620	total: 10.9s	remaining: 21.1s
# 341:	learn: 3756.3413949	total: 10.9s	remaining: 21.1s
# 342:	learn: 3754.9287037	total: 11s	remaining: 21s
# 343:	learn: 3752.8879569	total: 11s	remaining: 21s
# 344:	learn: 3750.8609564	total: 11s	remaining: 21s
# 345:	learn: 3748.9264589	total: 11.1s	remaining: 20.9s
# 346:	learn: 3747.2893756	total: 11.1s	remaining: 20.9s
# 347:	learn: 3746.1930619	total: 11.1s	remaining: 20.9s
# 348:	learn: 3745.1068097	total: 11.2s	remaining: 20.8s
# 349:	learn: 3744.0741402	total: 11.2s	remaining: 20.8s
# 350:	learn: 3741.3283143	total: 11.2s	remaining: 20.8s
# 351:	learn: 3738.5513509	total: 11.3s	remaining: 20.7s
# 352:	learn: 3737.5916611	total: 11.3s	remaining: 20.7s
# 353:	learn: 3737.0674337	total: 11.3s	remaining: 20.7s
# 354:	learn: 3735.3159178	total: 11.4s	remaining: 20.6s
# 355:	learn: 3734.3617692	total: 11.4s	remaining: 20.6s
# 356:	learn: 3731.7519935	total: 11.4s	remaining: 20.6s
# 357:	learn: 3729.6684022	total: 11.5s	remaining: 20.5s
# 358:	learn: 3727.5080222	total: 11.5s	remaining: 20.5s
# 359:	learn: 3726.1010655	total: 11.5s	remaining: 20.5s
# 360:	learn: 3722.6334545	total: 11.6s	remaining: 20.4s
# 361:	learn: 3721.1769948	total: 11.6s	remaining: 20.4s
# 362:	learn: 3718.4975422	total: 11.6s	remaining: 20.4s
# 363:	learn: 3717.6894587	total: 11.6s	remaining: 20.3s
# 364:	learn: 3716.5293749	total: 11.7s	remaining: 20.3s
# 365:	learn: 3714.7703978	total: 11.7s	remaining: 20.3s
# 366:	learn: 3714.0498671	total: 11.7s	remaining: 20.2s
# 367:	learn: 3713.1177075	total: 11.8s	remaining: 20.2s
# 368:	learn: 3712.3459874	total: 11.8s	remaining: 20.2s
# 369:	learn: 3710.9705129	total: 11.8s	remaining: 20.1s
# 370:	learn: 3709.4609597	total: 11.9s	remaining: 20.1s
# 371:	learn: 3709.0642770	total: 11.9s	remaining: 20.1s
# 372:	learn: 3707.1947866	total: 11.9s	remaining: 20s
# 373:	learn: 3705.9106902	total: 12s	remaining: 20s
# 374:	learn: 3702.7333936	total: 12s	remaining: 20s
# 375:	learn: 3700.0138102	total: 12s	remaining: 19.9s
# 376:	learn: 3696.3241367	total: 12s	remaining: 19.9s
# 377:	learn: 3695.5707743	total: 12.1s	remaining: 19.9s
# 378:	learn: 3693.3504501	total: 12.1s	remaining: 19.8s
# 379:	learn: 3692.6631104	total: 12.1s	remaining: 19.8s
# 380:	learn: 3691.1014304	total: 12.2s	remaining: 19.8s
# 381:	learn: 3689.6127955	total: 12.2s	remaining: 19.7s
# 382:	learn: 3688.6137478	total: 12.2s	remaining: 19.7s
# 383:	learn: 3687.8365095	total: 12.3s	remaining: 19.7s
# 384:	learn: 3684.9233637	total: 12.3s	remaining: 19.6s
# 385:	learn: 3682.7165896	total: 12.3s	remaining: 19.6s
# 386:	learn: 3682.3081140	total: 12.4s	remaining: 19.6s
# 387:	learn: 3679.6768908	total: 12.4s	remaining: 19.6s
# 388:	learn: 3677.6074338	total: 12.4s	remaining: 19.5s
# 389:	learn: 3676.0579128	total: 12.5s	remaining: 19.5s
# 390:	learn: 3674.5134635	total: 12.5s	remaining: 19.5s
# 391:	learn: 3674.1237328	total: 12.5s	remaining: 19.4s
# 392:	learn: 3673.2130299	total: 12.5s	remaining: 19.4s
# 393:	learn: 3672.3798027	total: 12.6s	remaining: 19.3s
# 394:	learn: 3671.4806459	total: 12.6s	remaining: 19.3s
# 395:	learn: 3670.0684234	total: 12.6s	remaining: 19.3s
# 396:	learn: 3666.8646189	total: 12.7s	remaining: 19.3s
# 397:	learn: 3666.4165857	total: 12.7s	remaining: 19.2s
# 398:	learn: 3665.3684125	total: 12.7s	remaining: 19.2s
# 399:	learn: 3663.8790488	total: 12.8s	remaining: 19.1s
# 400:	learn: 3661.5931754	total: 12.8s	remaining: 19.1s
# 401:	learn: 3660.5445617	total: 12.8s	remaining: 19.1s
# 402:	learn: 3658.9934052	total: 12.9s	remaining: 19.1s
# 403:	learn: 3657.3163419	total: 12.9s	remaining: 19s
# 404:	learn: 3656.4756649	total: 12.9s	remaining: 19s
# 405:	learn: 3654.9652706	total: 13s	remaining: 19s
# 406:	learn: 3653.9730192	total: 13s	remaining: 18.9s
# 407:	learn: 3652.0274957	total: 13s	remaining: 18.9s
# 408:	learn: 3650.3751650	total: 13s	remaining: 18.9s
# 409:	learn: 3648.8774740	total: 13.1s	remaining: 18.8s
# 410:	learn: 3646.8279543	total: 13.1s	remaining: 18.8s
# 411:	learn: 3645.9358007	total: 13.1s	remaining: 18.8s
# 412:	learn: 3644.3375531	total: 13.2s	remaining: 18.7s
# 413:	learn: 3643.7148203	total: 13.2s	remaining: 18.7s
# 414:	learn: 3642.5699048	total: 13.2s	remaining: 18.7s
# 415:	learn: 3640.3440896	total: 13.3s	remaining: 18.6s
# 416:	learn: 3639.1501497	total: 13.3s	remaining: 18.6s
# 417:	learn: 3638.4246044	total: 13.3s	remaining: 18.6s
# 418:	learn: 3636.9662772	total: 13.4s	remaining: 18.5s
# 419:	learn: 3635.1751734	total: 13.4s	remaining: 18.5s
# 420:	learn: 3633.8558381	total: 13.4s	remaining: 18.5s
# 421:	learn: 3633.0046596	total: 13.4s	remaining: 18.4s
# 422:	learn: 3630.4414535	total: 13.5s	remaining: 18.4s
# 423:	learn: 3629.4039772	total: 13.5s	remaining: 18.4s
# 424:	learn: 3628.5999264	total: 13.5s	remaining: 18.3s
# 425:	learn: 3627.5782132	total: 13.6s	remaining: 18.3s
# 426:	learn: 3625.3714221	total: 13.6s	remaining: 18.3s
# 427:	learn: 3623.4110009	total: 13.6s	remaining: 18.2s
# 428:	learn: 3621.6913102	total: 13.7s	remaining: 18.2s
# 429:	learn: 3620.4063446	total: 13.7s	remaining: 18.2s
# 430:	learn: 3617.9015002	total: 13.7s	remaining: 18.1s
# 431:	learn: 3617.0481175	total: 13.8s	remaining: 18.1s
# 432:	learn: 3616.1547928	total: 13.8s	remaining: 18.1s
# 433:	learn: 3614.5698474	total: 13.8s	remaining: 18s
# 434:	learn: 3614.0908494	total: 13.9s	remaining: 18s
# 435:	learn: 3611.8034361	total: 13.9s	remaining: 18s
# 436:	learn: 3610.9924692	total: 13.9s	remaining: 17.9s
# 437:	learn: 3606.6878733	total: 14s	remaining: 17.9s
# 438:	learn: 3605.7418884	total: 14s	remaining: 17.9s
# 439:	learn: 3604.0235295	total: 14s	remaining: 17.9s
# 440:	learn: 3602.0223997	total: 14.1s	remaining: 17.8s
# 441:	learn: 3601.0172332	total: 14.1s	remaining: 17.8s
# 442:	learn: 3600.7027961	total: 14.1s	remaining: 17.8s
# 443:	learn: 3598.4655293	total: 14.2s	remaining: 17.7s
# 444:	learn: 3597.7221127	total: 14.2s	remaining: 17.7s
# 445:	learn: 3596.0898226	total: 14.2s	remaining: 17.7s
# 446:	learn: 3595.2159984	total: 14.2s	remaining: 17.6s
# 447:	learn: 3594.6132712	total: 14.3s	remaining: 17.6s
# 448:	learn: 3591.2668504	total: 14.3s	remaining: 17.6s
# 449:	learn: 3590.2508023	total: 14.3s	remaining: 17.5s
# 450:	learn: 3588.8454031	total: 14.4s	remaining: 17.5s
# 451:	learn: 3588.1972854	total: 14.4s	remaining: 17.5s
# 452:	learn: 3587.3905090	total: 14.4s	remaining: 17.4s
# 453:	learn: 3586.6816985	total: 14.5s	remaining: 17.4s
# 454:	learn: 3586.1929722	total: 14.5s	remaining: 17.4s
# 455:	learn: 3584.8043057	total: 14.5s	remaining: 17.3s
# 456:	learn: 3583.8778596	total: 14.6s	remaining: 17.3s
# 457:	learn: 3583.7029335	total: 14.6s	remaining: 17.3s
# 458:	learn: 3582.5147326	total: 14.6s	remaining: 17.2s
# 459:	learn: 3580.5736301	total: 14.7s	remaining: 17.2s
# 460:	learn: 3579.2015526	total: 14.7s	remaining: 17.2s
# 461:	learn: 3578.3743619	total: 14.7s	remaining: 17.1s
# 462:	learn: 3576.7161233	total: 14.8s	remaining: 17.1s
# 463:	learn: 3575.2284079	total: 14.8s	remaining: 17.1s
# 464:	learn: 3573.5582356	total: 14.8s	remaining: 17s
# 465:	learn: 3572.8556534	total: 14.8s	remaining: 17s
# 466:	learn: 3572.3095619	total: 14.9s	remaining: 17s
# 467:	learn: 3571.6261155	total: 14.9s	remaining: 16.9s
# 468:	learn: 3570.6494063	total: 14.9s	remaining: 16.9s
# 469:	learn: 3569.5464931	total: 15s	remaining: 16.9s
# 470:	learn: 3568.6897432	total: 15s	remaining: 16.9s
# 471:	learn: 3567.3041832	total: 15s	remaining: 16.8s
# 472:	learn: 3566.8197625	total: 15.1s	remaining: 16.8s
# 473:	learn: 3565.8642273	total: 15.1s	remaining: 16.8s
# 474:	learn: 3564.6251858	total: 15.1s	remaining: 16.7s
# 475:	learn: 3562.7759815	total: 15.2s	remaining: 16.7s
# 476:	learn: 3560.9011863	total: 15.2s	remaining: 16.7s
# 477:	learn: 3559.1935018	total: 15.2s	remaining: 16.6s
# 478:	learn: 3558.5100166	total: 15.2s	remaining: 16.6s
# 479:	learn: 3556.2763031	total: 15.3s	remaining: 16.6s
# 480:	learn: 3553.2773303	total: 15.3s	remaining: 16.5s
# 481:	learn: 3552.8047724	total: 15.3s	remaining: 16.5s
# 482:	learn: 3552.3504638	total: 15.4s	remaining: 16.5s
# 483:	learn: 3551.4324015	total: 15.4s	remaining: 16.4s
# 484:	learn: 3550.4303133	total: 15.4s	remaining: 16.4s
# 485:	learn: 3545.1329372	total: 15.5s	remaining: 16.4s
# 486:	learn: 3544.0513277	total: 15.5s	remaining: 16.3s
# 487:	learn: 3543.1939175	total: 15.5s	remaining: 16.3s
# 488:	learn: 3541.8414178	total: 15.6s	remaining: 16.3s
# 489:	learn: 3540.2244353	total: 15.6s	remaining: 16.2s
# 490:	learn: 3538.9420645	total: 15.6s	remaining: 16.2s
# 491:	learn: 3536.9324580	total: 15.7s	remaining: 16.2s
# 492:	learn: 3535.1620948	total: 15.7s	remaining: 16.1s
# 493:	learn: 3534.0555941	total: 15.7s	remaining: 16.1s
# 494:	learn: 3533.0280437	total: 15.7s	remaining: 16.1s
# 495:	learn: 3532.2996323	total: 15.8s	remaining: 16s
# 496:	learn: 3531.4346616	total: 15.8s	remaining: 16s
# 497:	learn: 3530.3857609	total: 15.8s	remaining: 16s
# 498:	learn: 3529.3547529	total: 15.9s	remaining: 15.9s
# 499:	learn: 3529.0379353	total: 15.9s	remaining: 15.9s
# 500:	learn: 3528.0683864	total: 15.9s	remaining: 15.9s
# 501:	learn: 3527.7330571	total: 16s	remaining: 15.8s
# 502:	learn: 3527.1553029	total: 16s	remaining: 15.8s
# 503:	learn: 3526.8344280	total: 16s	remaining: 15.8s
# 504:	learn: 3525.3346669	total: 16s	remaining: 15.7s
# 505:	learn: 3524.4973045	total: 16.1s	remaining: 15.7s
# 506:	learn: 3523.2887233	total: 16.1s	remaining: 15.7s
# 507:	learn: 3522.1535706	total: 16.1s	remaining: 15.6s
# 508:	learn: 3521.3698536	total: 16.2s	remaining: 15.6s
# 509:	learn: 3519.5353303	total: 16.2s	remaining: 15.6s
# 510:	learn: 3518.1694822	total: 16.2s	remaining: 15.5s
# 511:	learn: 3516.6842230	total: 16.3s	remaining: 15.5s
# 512:	learn: 3515.8619705	total: 16.3s	remaining: 15.5s
# 513:	learn: 3515.2593341	total: 16.3s	remaining: 15.4s
# 514:	learn: 3513.4959932	total: 16.3s	remaining: 15.4s
# 515:	learn: 3510.3935651	total: 16.4s	remaining: 15.4s
# 516:	learn: 3509.1686792	total: 16.4s	remaining: 15.3s
# 517:	learn: 3508.4476215	total: 16.4s	remaining: 15.3s
# 518:	learn: 3507.3638099	total: 16.5s	remaining: 15.3s
# 519:	learn: 3506.6913625	total: 16.5s	remaining: 15.2s
# 520:	learn: 3505.5066805	total: 16.5s	remaining: 15.2s
# 521:	learn: 3504.9139060	total: 16.6s	remaining: 15.2s
# 522:	learn: 3503.5522304	total: 16.6s	remaining: 15.1s
# 523:	learn: 3502.0609957	total: 16.6s	remaining: 15.1s
# 524:	learn: 3501.4587900	total: 16.7s	remaining: 15.1s
# 525:	learn: 3499.2773466	total: 16.7s	remaining: 15s
# 526:	learn: 3497.7803158	total: 16.7s	remaining: 15s
# 527:	learn: 3497.0650874	total: 16.7s	remaining: 15s
# 528:	learn: 3495.7675163	total: 16.8s	remaining: 14.9s
# 529:	learn: 3494.5956756	total: 16.8s	remaining: 14.9s
# 530:	learn: 3493.6928992	total: 16.8s	remaining: 14.9s
# 531:	learn: 3492.9756263	total: 16.9s	remaining: 14.8s
# 532:	learn: 3490.4935491	total: 16.9s	remaining: 14.8s
# 533:	learn: 3489.7930816	total: 16.9s	remaining: 14.8s
# 534:	learn: 3488.8669529	total: 17s	remaining: 14.7s
# 535:	learn: 3487.5548202	total: 17s	remaining: 14.7s
# 536:	learn: 3486.3335683	total: 17s	remaining: 14.7s
# 537:	learn: 3485.7536350	total: 17.1s	remaining: 14.6s
# 538:	learn: 3484.7935463	total: 17.1s	remaining: 14.6s
# 539:	learn: 3483.1023270	total: 17.1s	remaining: 14.6s
# 540:	learn: 3482.5050140	total: 17.1s	remaining: 14.5s
# 541:	learn: 3482.0273733	total: 17.2s	remaining: 14.5s
# 542:	learn: 3480.2924653	total: 17.2s	remaining: 14.5s
# 543:	learn: 3478.5212953	total: 17.2s	remaining: 14.5s
# 544:	learn: 3477.5157769	total: 17.3s	remaining: 14.4s
# 545:	learn: 3475.0164278	total: 17.3s	remaining: 14.4s
# 546:	learn: 3473.6081060	total: 17.3s	remaining: 14.4s
# 547:	learn: 3472.8297677	total: 17.4s	remaining: 14.3s
# 548:	learn: 3470.5385983	total: 17.4s	remaining: 14.3s
# 549:	learn: 3469.2399345	total: 17.4s	remaining: 14.3s
# 550:	learn: 3467.5011113	total: 17.5s	remaining: 14.2s
# 551:	learn: 3466.3008970	total: 17.5s	remaining: 14.2s
# 552:	learn: 3465.9923903	total: 17.5s	remaining: 14.2s
# 553:	learn: 3465.0004117	total: 17.6s	remaining: 14.1s
# 554:	learn: 3463.6639993	total: 17.6s	remaining: 14.1s
# 555:	learn: 3462.2292521	total: 17.6s	remaining: 14.1s
# 556:	learn: 3461.1380526	total: 17.6s	remaining: 14s
# 557:	learn: 3460.3004902	total: 17.7s	remaining: 14s
# 558:	learn: 3458.3516424	total: 17.7s	remaining: 14s
# 559:	learn: 3457.3815505	total: 17.7s	remaining: 13.9s
# 560:	learn: 3456.9909683	total: 17.8s	remaining: 13.9s
# 561:	learn: 3454.8749071	total: 17.8s	remaining: 13.9s
# 562:	learn: 3453.8715256	total: 17.8s	remaining: 13.8s
# 563:	learn: 3453.1442022	total: 17.9s	remaining: 13.8s
# 564:	learn: 3451.9126177	total: 17.9s	remaining: 13.8s
# 565:	learn: 3451.0246357	total: 17.9s	remaining: 13.7s
# 566:	learn: 3449.9636816	total: 18s	remaining: 13.7s
# 567:	learn: 3449.4970990	total: 18s	remaining: 13.7s
# 568:	learn: 3448.1299674	total: 18s	remaining: 13.7s
# 569:	learn: 3447.2107863	total: 18.1s	remaining: 13.6s
# 570:	learn: 3445.7235329	total: 18.1s	remaining: 13.6s
# 571:	learn: 3445.5484741	total: 18.1s	remaining: 13.6s
# 572:	learn: 3444.9173927	total: 18.1s	remaining: 13.5s
# 573:	learn: 3444.1476524	total: 18.2s	remaining: 13.5s
# 574:	learn: 3443.1688256	total: 18.2s	remaining: 13.5s
# 575:	learn: 3442.1511134	total: 18.2s	remaining: 13.4s
# 576:	learn: 3441.5743723	total: 18.3s	remaining: 13.4s
# 577:	learn: 3440.4393080	total: 18.3s	remaining: 13.4s
# 578:	learn: 3439.1275918	total: 18.3s	remaining: 13.3s
# 579:	learn: 3437.5346286	total: 18.4s	remaining: 13.3s
# 580:	learn: 3436.9167194	total: 18.4s	remaining: 13.3s
# 581:	learn: 3436.5349663	total: 18.4s	remaining: 13.2s
# 582:	learn: 3435.6568221	total: 18.5s	remaining: 13.2s
# 583:	learn: 3434.4895452	total: 18.5s	remaining: 13.2s
# 584:	learn: 3433.5298115	total: 18.5s	remaining: 13.1s
# 585:	learn: 3432.7899090	total: 18.5s	remaining: 13.1s
# 586:	learn: 3431.9101619	total: 18.6s	remaining: 13.1s
# 587:	learn: 3431.2374223	total: 18.6s	remaining: 13s
# 588:	learn: 3430.3919168	total: 18.6s	remaining: 13s
# 589:	learn: 3429.3660319	total: 18.7s	remaining: 13s
# 590:	learn: 3428.7071856	total: 18.7s	remaining: 12.9s
# 591:	learn: 3427.0613908	total: 18.7s	remaining: 12.9s
# 592:	learn: 3426.6191139	total: 18.8s	remaining: 12.9s
# 593:	learn: 3425.8868209	total: 18.8s	remaining: 12.8s
# 594:	learn: 3425.2366457	total: 18.8s	remaining: 12.8s
# 595:	learn: 3423.6545810	total: 18.8s	remaining: 12.8s
# 596:	learn: 3422.6740826	total: 18.9s	remaining: 12.7s
# 597:	learn: 3421.1117557	total: 18.9s	remaining: 12.7s
# 598:	learn: 3420.7746267	total: 18.9s	remaining: 12.7s
# 599:	learn: 3419.9324232	total: 19s	remaining: 12.6s
# 600:	learn: 3419.5500655	total: 19s	remaining: 12.6s
# 601:	learn: 3418.7682072	total: 19s	remaining: 12.6s
# 602:	learn: 3417.5337043	total: 19.1s	remaining: 12.5s
# 603:	learn: 3416.5541195	total: 19.1s	remaining: 12.5s
# 604:	learn: 3415.5026929	total: 19.1s	remaining: 12.5s
# 605:	learn: 3414.5976978	total: 19.1s	remaining: 12.4s
# 606:	learn: 3413.2882363	total: 19.2s	remaining: 12.4s
# 607:	learn: 3411.9626108	total: 19.2s	remaining: 12.4s
# 608:	learn: 3411.3335960	total: 19.2s	remaining: 12.4s
# 609:	learn: 3410.3502254	total: 19.3s	remaining: 12.3s
# 610:	learn: 3410.0485991	total: 19.3s	remaining: 12.3s
# 611:	learn: 3408.5388061	total: 19.3s	remaining: 12.3s
# 612:	learn: 3407.5846281	total: 19.4s	remaining: 12.2s
# 613:	learn: 3407.1857161	total: 19.4s	remaining: 12.2s
# 614:	learn: 3406.2984987	total: 19.4s	remaining: 12.2s
# 615:	learn: 3405.3267348	total: 19.5s	remaining: 12.1s
# 616:	learn: 3404.2262450	total: 19.5s	remaining: 12.1s
# 617:	learn: 3402.8976428	total: 19.5s	remaining: 12.1s
# 618:	learn: 3401.7148937	total: 19.6s	remaining: 12s
# 619:	learn: 3400.4758570	total: 19.6s	remaining: 12s
# 620:	learn: 3400.0017740	total: 19.6s	remaining: 12s
# 621:	learn: 3398.6935504	total: 19.6s	remaining: 11.9s
# 622:	learn: 3397.0797073	total: 19.7s	remaining: 11.9s
# 623:	learn: 3396.3720959	total: 19.7s	remaining: 11.9s
# 624:	learn: 3395.4699357	total: 19.7s	remaining: 11.8s
# 625:	learn: 3394.2948353	total: 19.8s	remaining: 11.8s
# 626:	learn: 3393.3992580	total: 19.8s	remaining: 11.8s
# 627:	learn: 3392.1934665	total: 19.8s	remaining: 11.7s
# 628:	learn: 3392.0245264	total: 19.9s	remaining: 11.7s
# 629:	learn: 3391.6764690	total: 19.9s	remaining: 11.7s
# 630:	learn: 3390.6322837	total: 19.9s	remaining: 11.7s
# 631:	learn: 3389.4529792	total: 20s	remaining: 11.6s
# 632:	learn: 3389.1883445	total: 20s	remaining: 11.6s
# 633:	learn: 3387.9890720	total: 20s	remaining: 11.6s
# 634:	learn: 3386.7690408	total: 20s	remaining: 11.5s
# 635:	learn: 3386.2326383	total: 20.1s	remaining: 11.5s
# 636:	learn: 3385.6647522	total: 20.1s	remaining: 11.5s
# 637:	learn: 3385.1612129	total: 20.1s	remaining: 11.4s
# 638:	learn: 3384.1299096	total: 20.2s	remaining: 11.4s
# 639:	learn: 3382.8163747	total: 20.2s	remaining: 11.4s
# 640:	learn: 3381.8922907	total: 20.2s	remaining: 11.3s
# 641:	learn: 3381.4100399	total: 20.3s	remaining: 11.3s
# 642:	learn: 3379.3322865	total: 20.3s	remaining: 11.3s
# 643:	learn: 3378.9813200	total: 20.3s	remaining: 11.2s
# 644:	learn: 3377.2845127	total: 20.4s	remaining: 11.2s
# 645:	learn: 3376.3625359	total: 20.4s	remaining: 11.2s
# 646:	learn: 3374.7064479	total: 20.4s	remaining: 11.1s
# 647:	learn: 3372.6862720	total: 20.5s	remaining: 11.1s
# 648:	learn: 3371.8458558	total: 20.5s	remaining: 11.1s
# 649:	learn: 3370.9104103	total: 20.5s	remaining: 11s
# 650:	learn: 3370.2238131	total: 20.5s	remaining: 11s
# 651:	learn: 3368.7581967	total: 20.6s	remaining: 11s
# 652:	learn: 3367.4656628	total: 20.6s	remaining: 10.9s
# 653:	learn: 3366.9406473	total: 20.6s	remaining: 10.9s
# 654:	learn: 3365.7469116	total: 20.7s	remaining: 10.9s
# 655:	learn: 3365.2271232	total: 20.7s	remaining: 10.9s
# 656:	learn: 3364.7046868	total: 20.7s	remaining: 10.8s
# 657:	learn: 3364.2493527	total: 20.8s	remaining: 10.8s
# 658:	learn: 3363.8059414	total: 20.8s	remaining: 10.8s
# 659:	learn: 3363.2919286	total: 20.8s	remaining: 10.7s
# 660:	learn: 3362.8580383	total: 20.8s	remaining: 10.7s
# 661:	learn: 3362.1693858	total: 20.9s	remaining: 10.7s
# 662:	learn: 3360.5690206	total: 20.9s	remaining: 10.6s
# 663:	learn: 3360.1551040	total: 20.9s	remaining: 10.6s
# 664:	learn: 3359.6835085	total: 21s	remaining: 10.6s
# 665:	learn: 3359.1188750	total: 21s	remaining: 10.5s
# 666:	learn: 3358.0370072	total: 21s	remaining: 10.5s
# 667:	learn: 3357.1366093	total: 21.1s	remaining: 10.5s
# 668:	learn: 3355.9071828	total: 21.1s	remaining: 10.4s
# 669:	learn: 3355.4549663	total: 21.1s	remaining: 10.4s
# 670:	learn: 3354.2323925	total: 21.2s	remaining: 10.4s
# 671:	learn: 3353.0823836	total: 21.2s	remaining: 10.3s
# 672:	learn: 3351.9512013	total: 21.2s	remaining: 10.3s
# 673:	learn: 3350.3533010	total: 21.3s	remaining: 10.3s
# 674:	learn: 3349.6966550	total: 21.3s	remaining: 10.3s
# 675:	learn: 3348.6890932	total: 21.3s	remaining: 10.2s
# 676:	learn: 3347.6721861	total: 21.4s	remaining: 10.2s
# 677:	learn: 3347.1216762	total: 21.4s	remaining: 10.2s
# 678:	learn: 3345.8041334	total: 21.4s	remaining: 10.1s
# 679:	learn: 3344.1399059	total: 21.4s	remaining: 10.1s
# 680:	learn: 3342.9207375	total: 21.5s	remaining: 10.1s
# 681:	learn: 3342.1270693	total: 21.5s	remaining: 10s
# 682:	learn: 3341.4668737	total: 21.5s	remaining: 9.99s
# 683:	learn: 3340.8520119	total: 21.6s	remaining: 9.96s
# 684:	learn: 3340.6302912	total: 21.6s	remaining: 9.93s
# 685:	learn: 3339.4321868	total: 21.6s	remaining: 9.9s
# 686:	learn: 3339.1206715	total: 21.7s	remaining: 9.87s
# 687:	learn: 3336.6666723	total: 21.7s	remaining: 9.84s
# 688:	learn: 3335.7521569	total: 21.8s	remaining: 9.82s
# 689:	learn: 3335.3145870	total: 21.8s	remaining: 9.79s
# 690:	learn: 3331.8307718	total: 21.8s	remaining: 9.77s
# 691:	learn: 3330.6076994	total: 21.9s	remaining: 9.74s
# 692:	learn: 3329.6501816	total: 21.9s	remaining: 9.72s
# 693:	learn: 3328.9919348	total: 22s	remaining: 9.69s
# 694:	learn: 3327.8112627	total: 22s	remaining: 9.66s
# 695:	learn: 3327.0528041	total: 22.1s	remaining: 9.64s
# 696:	learn: 3326.7402943	total: 22.1s	remaining: 9.61s
# 697:	learn: 3326.1181756	total: 22.1s	remaining: 9.57s
# 698:	learn: 3324.8215631	total: 22.2s	remaining: 9.54s
# 699:	learn: 3323.8899227	total: 22.2s	remaining: 9.51s
# 700:	learn: 3323.7400965	total: 22.2s	remaining: 9.49s
# 701:	learn: 3322.8523056	total: 22.3s	remaining: 9.46s
# 702:	learn: 3321.8630924	total: 22.3s	remaining: 9.43s
# 703:	learn: 3320.7356599	total: 22.3s	remaining: 9.39s
# 704:	learn: 3320.0114480	total: 22.4s	remaining: 9.36s
# 705:	learn: 3319.5969523	total: 22.4s	remaining: 9.33s
# 706:	learn: 3318.7990848	total: 22.5s	remaining: 9.3s
# 707:	learn: 3318.2177351	total: 22.5s	remaining: 9.27s
# 708:	learn: 3316.8999818	total: 22.5s	remaining: 9.24s
# 709:	learn: 3314.1487221	total: 22.5s	remaining: 9.21s
# 710:	learn: 3312.9259627	total: 22.6s	remaining: 9.18s
# 711:	learn: 3312.2997632	total: 22.6s	remaining: 9.15s
# 712:	learn: 3311.0035541	total: 22.6s	remaining: 9.12s
# 713:	learn: 3310.3115977	total: 22.7s	remaining: 9.08s
# 714:	learn: 3308.3793801	total: 22.7s	remaining: 9.05s
# 715:	learn: 3307.0143243	total: 22.7s	remaining: 9.02s
# 716:	learn: 3306.4467873	total: 22.8s	remaining: 8.99s
# 717:	learn: 3304.6953423	total: 22.8s	remaining: 8.96s
# 718:	learn: 3304.1773747	total: 22.8s	remaining: 8.93s
# 719:	learn: 3303.2701537	total: 22.9s	remaining: 8.89s
# 720:	learn: 3302.6328619	total: 22.9s	remaining: 8.86s
# 721:	learn: 3299.4766690	total: 22.9s	remaining: 8.83s
# 722:	learn: 3298.7534400	total: 23s	remaining: 8.8s
# 723:	learn: 3297.8140560	total: 23s	remaining: 8.77s
# 724:	learn: 3296.0334989	total: 23s	remaining: 8.73s
# 725:	learn: 3295.2771803	total: 23.1s	remaining: 8.7s
# 726:	learn: 3294.6370254	total: 23.1s	remaining: 8.67s
# 727:	learn: 3293.2964254	total: 23.1s	remaining: 8.64s
# 728:	learn: 3292.8625305	total: 23.2s	remaining: 8.61s
# 729:	learn: 3292.1871436	total: 23.2s	remaining: 8.58s
# 730:	learn: 3291.3446927	total: 23.2s	remaining: 8.54s
# 731:	learn: 3290.9138499	total: 23.2s	remaining: 8.51s
# 732:	learn: 3288.0586884	total: 23.3s	remaining: 8.48s
# 733:	learn: 3287.5616697	total: 23.3s	remaining: 8.45s
# 734:	learn: 3286.8441263	total: 23.3s	remaining: 8.42s
# 735:	learn: 3285.5752068	total: 23.4s	remaining: 8.38s
# 736:	learn: 3284.8612101	total: 23.4s	remaining: 8.35s
# 737:	learn: 3283.6346554	total: 23.4s	remaining: 8.32s
# 738:	learn: 3281.8995322	total: 23.5s	remaining: 8.29s
# 739:	learn: 3281.1588657	total: 23.5s	remaining: 8.26s
# 740:	learn: 3280.4206397	total: 23.5s	remaining: 8.22s
# 741:	learn: 3279.2580794	total: 23.6s	remaining: 8.19s
# 742:	learn: 3278.8098193	total: 23.6s	remaining: 8.16s
# 743:	learn: 3277.8353655	total: 23.6s	remaining: 8.13s
# 744:	learn: 3276.8430394	total: 23.7s	remaining: 8.1s
# 745:	learn: 3276.5481391	total: 23.7s	remaining: 8.07s
# 746:	learn: 3275.5898317	total: 23.7s	remaining: 8.04s
# 747:	learn: 3273.7772441	total: 23.8s	remaining: 8.01s
# 748:	learn: 3272.8124410	total: 23.8s	remaining: 7.97s
# 749:	learn: 3272.0633787	total: 23.8s	remaining: 7.94s
# 750:	learn: 3269.5888670	total: 23.9s	remaining: 7.91s
# 751:	learn: 3269.1691159	total: 23.9s	remaining: 7.88s
# 752:	learn: 3268.5467989	total: 23.9s	remaining: 7.85s
# 753:	learn: 3268.0869249	total: 24s	remaining: 7.82s
# 754:	learn: 3267.5998310	total: 24s	remaining: 7.78s
# 755:	learn: 3267.2394100	total: 24s	remaining: 7.75s
# 756:	learn: 3266.4828796	total: 24s	remaining: 7.72s
# 757:	learn: 3266.1570708	total: 24.1s	remaining: 7.69s
# 758:	learn: 3265.3637476	total: 24.1s	remaining: 7.66s
# 759:	learn: 3264.5598310	total: 24.1s	remaining: 7.62s
# 760:	learn: 3262.9112112	total: 24.2s	remaining: 7.59s
# 761:	learn: 3262.1216063	total: 24.2s	remaining: 7.56s
# 762:	learn: 3261.4208473	total: 24.2s	remaining: 7.53s
# 763:	learn: 3260.0368998	total: 24.3s	remaining: 7.5s
# 764:	learn: 3259.5183178	total: 24.3s	remaining: 7.46s
# 765:	learn: 3258.7551200	total: 24.3s	remaining: 7.43s
# 766:	learn: 3258.4254276	total: 24.4s	remaining: 7.4s
# 767:	learn: 3257.2347916	total: 24.4s	remaining: 7.37s
# 768:	learn: 3256.7751624	total: 24.4s	remaining: 7.34s
# 769:	learn: 3256.4347593	total: 24.5s	remaining: 7.3s
# 770:	learn: 3255.8158697	total: 24.5s	remaining: 7.27s
# 771:	learn: 3255.5244282	total: 24.5s	remaining: 7.24s
# 772:	learn: 3255.2785579	total: 24.5s	remaining: 7.21s
# 773:	learn: 3254.7471474	total: 24.6s	remaining: 7.18s
# 774:	learn: 3254.0707676	total: 24.6s	remaining: 7.14s
# 775:	learn: 3253.1338614	total: 24.6s	remaining: 7.11s
# 776:	learn: 3252.2537158	total: 24.7s	remaining: 7.08s
# 777:	learn: 3251.8370713	total: 24.7s	remaining: 7.05s
# 778:	learn: 3250.4662969	total: 24.7s	remaining: 7.02s
# 779:	learn: 3249.5043117	total: 24.8s	remaining: 6.98s
# 780:	learn: 3248.4970745	total: 24.8s	remaining: 6.95s
# 781:	learn: 3248.1009465	total: 24.8s	remaining: 6.92s
# 782:	learn: 3247.7021841	total: 24.8s	remaining: 6.89s
# 783:	learn: 3247.0661442	total: 24.9s	remaining: 6.86s
# 784:	learn: 3246.7838876	total: 24.9s	remaining: 6.83s
# 785:	learn: 3246.3376067	total: 25s	remaining: 6.8s
# 786:	learn: 3245.5265696	total: 25s	remaining: 6.76s
# 787:	learn: 3244.8579655	total: 25s	remaining: 6.73s
# 788:	learn: 3244.2060927	total: 25.1s	remaining: 6.7s
# 789:	learn: 3243.5143647	total: 25.1s	remaining: 6.67s
# 790:	learn: 3241.8930928	total: 25.1s	remaining: 6.64s
# 791:	learn: 3241.3647238	total: 25.2s	remaining: 6.61s
# 792:	learn: 3240.5758293	total: 25.2s	remaining: 6.57s
# 793:	learn: 3240.3880640	total: 25.2s	remaining: 6.54s
# 794:	learn: 3240.0218345	total: 25.2s	remaining: 6.51s
# 795:	learn: 3238.9999973	total: 25.3s	remaining: 6.48s
# 796:	learn: 3238.4951082	total: 25.3s	remaining: 6.45s
# 797:	learn: 3237.3765836	total: 25.3s	remaining: 6.41s
# 798:	learn: 3236.1918221	total: 25.4s	remaining: 6.38s
# 799:	learn: 3235.5773377	total: 25.4s	remaining: 6.35s
# 800:	learn: 3234.5406587	total: 25.4s	remaining: 6.32s
# 801:	learn: 3233.8410668	total: 25.5s	remaining: 6.29s
# 802:	learn: 3233.0825724	total: 25.5s	remaining: 6.25s
# 803:	learn: 3232.6673414	total: 25.5s	remaining: 6.22s
# 804:	learn: 3231.9004790	total: 25.6s	remaining: 6.19s
# 805:	learn: 3231.3681453	total: 25.6s	remaining: 6.16s
# 806:	learn: 3230.6803067	total: 25.6s	remaining: 6.13s
# 807:	learn: 3230.0729780	total: 25.6s	remaining: 6.09s
# 808:	learn: 3228.8312039	total: 25.7s	remaining: 6.06s
# 809:	learn: 3227.4088816	total: 25.7s	remaining: 6.03s
# 810:	learn: 3226.6843957	total: 25.7s	remaining: 6s
# 811:	learn: 3224.9129262	total: 25.8s	remaining: 5.97s
# 812:	learn: 3224.3821250	total: 25.8s	remaining: 5.93s
# 813:	learn: 3223.8924331	total: 25.8s	remaining: 5.9s
# 814:	learn: 3222.3929099	total: 25.9s	remaining: 5.87s
# 815:	learn: 3222.0614079	total: 25.9s	remaining: 5.84s
# 816:	learn: 3219.9163901	total: 25.9s	remaining: 5.81s
# 817:	learn: 3219.6114254	total: 26s	remaining: 5.78s
# 818:	learn: 3219.3545499	total: 26s	remaining: 5.74s
# 819:	learn: 3218.1558862	total: 26s	remaining: 5.71s
# 820:	learn: 3217.6619407	total: 26s	remaining: 5.68s
# 821:	learn: 3217.0306083	total: 26.1s	remaining: 5.65s
# 822:	learn: 3216.5701674	total: 26.1s	remaining: 5.62s
# 823:	learn: 3215.1042298	total: 26.1s	remaining: 5.58s
# 824:	learn: 3214.4603990	total: 26.2s	remaining: 5.55s
# 825:	learn: 3213.7542670	total: 26.2s	remaining: 5.52s
# 826:	learn: 3211.4919759	total: 26.2s	remaining: 5.49s
# 827:	learn: 3210.8694505	total: 26.3s	remaining: 5.46s
# 828:	learn: 3210.1242204	total: 26.3s	remaining: 5.42s
# 829:	learn: 3209.0834732	total: 26.3s	remaining: 5.39s
# 830:	learn: 3208.9167048	total: 26.4s	remaining: 5.36s
# 831:	learn: 3208.0691949	total: 26.4s	remaining: 5.33s
# 832:	learn: 3207.6702315	total: 26.4s	remaining: 5.3s
# 833:	learn: 3206.9499379	total: 26.4s	remaining: 5.26s
# 834:	learn: 3206.3750686	total: 26.5s	remaining: 5.23s
# 835:	learn: 3205.0476723	total: 26.5s	remaining: 5.2s
# 836:	learn: 3203.7537450	total: 26.5s	remaining: 5.17s
# 837:	learn: 3203.3361400	total: 26.6s	remaining: 5.14s
# 838:	learn: 3202.2466095	total: 26.6s	remaining: 5.11s
# 839:	learn: 3201.2845165	total: 26.6s	remaining: 5.07s
# 840:	learn: 3200.6575889	total: 26.7s	remaining: 5.04s
# 841:	learn: 3199.9398926	total: 26.7s	remaining: 5.01s
# 842:	learn: 3199.1182042	total: 26.7s	remaining: 4.98s
# 843:	learn: 3198.1488213	total: 26.8s	remaining: 4.95s
# 844:	learn: 3197.8469104	total: 26.8s	remaining: 4.91s
# 845:	learn: 3197.3807541	total: 26.8s	remaining: 4.88s
# 846:	learn: 3196.7001786	total: 26.9s	remaining: 4.85s
# 847:	learn: 3195.4896786	total: 26.9s	remaining: 4.82s
# 848:	learn: 3194.2727292	total: 26.9s	remaining: 4.79s
# 849:	learn: 3193.5648538	total: 26.9s	remaining: 4.75s
# 850:	learn: 3192.2817820	total: 27s	remaining: 4.72s
# 851:	learn: 3191.3524704	total: 27s	remaining: 4.69s
# 852:	learn: 3190.7224346	total: 27s	remaining: 4.66s
# 853:	learn: 3190.1674286	total: 27.1s	remaining: 4.63s
# 854:	learn: 3189.8842674	total: 27.1s	remaining: 4.59s
# 855:	learn: 3189.4253526	total: 27.1s	remaining: 4.56s
# 856:	learn: 3189.2279510	total: 27.2s	remaining: 4.53s
# 857:	learn: 3188.7093841	total: 27.2s	remaining: 4.5s
# 858:	learn: 3187.9336237	total: 27.2s	remaining: 4.47s
# 859:	learn: 3186.9842887	total: 27.2s	remaining: 4.43s
# 860:	learn: 3186.2759926	total: 27.3s	remaining: 4.4s
# 861:	learn: 3185.6902401	total: 27.3s	remaining: 4.37s
# 862:	learn: 3185.2750973	total: 27.3s	remaining: 4.34s
# 863:	learn: 3183.4514249	total: 27.4s	remaining: 4.31s
# 864:	learn: 3182.5206485	total: 27.4s	remaining: 4.28s
# 865:	learn: 3181.5328754	total: 27.4s	remaining: 4.24s
# 866:	learn: 3181.2402463	total: 27.5s	remaining: 4.21s
# 867:	learn: 3179.4939278	total: 27.5s	remaining: 4.18s
# 868:	learn: 3178.4040814	total: 27.5s	remaining: 4.15s
# 869:	learn: 3178.1399760	total: 27.6s	remaining: 4.12s
# 870:	learn: 3177.6650277	total: 27.6s	remaining: 4.08s
# 871:	learn: 3176.6461645	total: 27.6s	remaining: 4.05s
# 872:	learn: 3176.0953219	total: 27.6s	remaining: 4.02s
# 873:	learn: 3175.5533271	total: 27.7s	remaining: 3.99s
# 874:	learn: 3174.1739156	total: 27.7s	remaining: 3.96s
# 875:	learn: 3173.5051013	total: 27.7s	remaining: 3.93s
# 876:	learn: 3172.1988239	total: 27.8s	remaining: 3.89s
# 877:	learn: 3171.8179620	total: 27.8s	remaining: 3.86s
# 878:	learn: 3170.8787704	total: 27.8s	remaining: 3.83s
# 879:	learn: 3170.3548426	total: 27.9s	remaining: 3.8s
# 880:	learn: 3169.7236628	total: 27.9s	remaining: 3.77s
# 881:	learn: 3169.0662022	total: 27.9s	remaining: 3.73s
# 882:	learn: 3168.6193451	total: 28s	remaining: 3.7s
# 883:	learn: 3167.6665610	total: 28s	remaining: 3.67s
# 884:	learn: 3167.1422205	total: 28s	remaining: 3.64s
# 885:	learn: 3166.5425234	total: 28s	remaining: 3.61s
# 886:	learn: 3164.9964746	total: 28.1s	remaining: 3.58s
# 887:	learn: 3164.3859172	total: 28.1s	remaining: 3.54s
# 888:	learn: 3163.2452906	total: 28.1s	remaining: 3.51s
# 889:	learn: 3162.9136655	total: 28.2s	remaining: 3.48s
# 890:	learn: 3162.5389405	total: 28.2s	remaining: 3.45s
# 891:	learn: 3161.3941416	total: 28.2s	remaining: 3.42s
# 892:	learn: 3159.9391687	total: 28.3s	remaining: 3.39s
# 893:	learn: 3159.1717116	total: 28.3s	remaining: 3.35s
# 894:	learn: 3158.8657308	total: 28.3s	remaining: 3.32s
# 895:	learn: 3158.4194855	total: 28.4s	remaining: 3.29s
# 896:	learn: 3157.8723348	total: 28.4s	remaining: 3.26s
# 897:	learn: 3157.5719299	total: 28.4s	remaining: 3.23s
# 898:	learn: 3157.2441680	total: 28.4s	remaining: 3.2s
# 899:	learn: 3156.4502215	total: 28.5s	remaining: 3.16s
# 900:	learn: 3156.1077905	total: 28.5s	remaining: 3.13s
# 901:	learn: 3155.5241972	total: 28.5s	remaining: 3.1s
# 902:	learn: 3155.1905529	total: 28.6s	remaining: 3.07s
# 903:	learn: 3154.4150431	total: 28.6s	remaining: 3.04s
# 904:	learn: 3154.0000262	total: 28.6s	remaining: 3s
# 905:	learn: 3153.6002825	total: 28.7s	remaining: 2.97s
# 906:	learn: 3153.1076360	total: 28.7s	remaining: 2.94s
# 907:	learn: 3152.7495654	total: 28.7s	remaining: 2.91s
# 908:	learn: 3151.6961796	total: 28.8s	remaining: 2.88s
# 909:	learn: 3151.4569867	total: 28.8s	remaining: 2.85s
# 910:	learn: 3150.4793163	total: 28.8s	remaining: 2.81s
# 911:	learn: 3149.8932644	total: 28.9s	remaining: 2.78s
# 912:	learn: 3149.4160206	total: 28.9s	remaining: 2.75s
# 913:	learn: 3148.6515939	total: 28.9s	remaining: 2.72s
# 914:	learn: 3146.9398698	total: 28.9s	remaining: 2.69s
# 915:	learn: 3146.5001120	total: 29s	remaining: 2.66s
# 916:	learn: 3146.3145835	total: 29s	remaining: 2.63s
# 917:	learn: 3145.7771503	total: 29s	remaining: 2.59s
# 918:	learn: 3145.2134071	total: 29.1s	remaining: 2.56s
# 919:	learn: 3144.2724950	total: 29.1s	remaining: 2.53s
# 920:	learn: 3143.9551629	total: 29.1s	remaining: 2.5s
# 921:	learn: 3143.4917744	total: 29.2s	remaining: 2.47s
# 922:	learn: 3142.6381175	total: 29.2s	remaining: 2.44s
# 923:	learn: 3142.2264575	total: 29.2s	remaining: 2.4s
# 924:	learn: 3141.5120385	total: 29.3s	remaining: 2.37s
# 925:	learn: 3141.1892872	total: 29.3s	remaining: 2.34s
# 926:	learn: 3140.3946012	total: 29.3s	remaining: 2.31s
# 927:	learn: 3139.4117001	total: 29.4s	remaining: 2.28s
# 928:	learn: 3138.8055948	total: 29.4s	remaining: 2.25s
# 929:	learn: 3138.1360059	total: 29.4s	remaining: 2.21s
# 930:	learn: 3137.7461156	total: 29.4s	remaining: 2.18s
# 931:	learn: 3136.7063715	total: 29.5s	remaining: 2.15s
# 932:	learn: 3135.7516431	total: 29.5s	remaining: 2.12s
# 933:	learn: 3135.2772339	total: 29.5s	remaining: 2.09s
# 934:	learn: 3134.2922803	total: 29.6s	remaining: 2.06s
# 935:	learn: 3133.8445651	total: 29.6s	remaining: 2.02s
# 936:	learn: 3132.8808460	total: 29.6s	remaining: 1.99s
# 937:	learn: 3131.8434708	total: 29.7s	remaining: 1.96s
# 938:	learn: 3130.9857709	total: 29.7s	remaining: 1.93s
# 939:	learn: 3130.4207420	total: 29.7s	remaining: 1.9s
# 940:	learn: 3129.8496269	total: 29.8s	remaining: 1.86s
# 941:	learn: 3129.5192307	total: 29.8s	remaining: 1.83s
# 942:	learn: 3128.4514727	total: 29.8s	remaining: 1.8s
# 943:	learn: 3127.6256449	total: 29.8s	remaining: 1.77s
# 944:	learn: 3127.2186899	total: 29.9s	remaining: 1.74s
# 945:	learn: 3126.5390819	total: 29.9s	remaining: 1.71s
# 946:	learn: 3125.8239053	total: 29.9s	remaining: 1.68s
# 947:	learn: 3125.3724376	total: 30s	remaining: 1.64s
# 948:	learn: 3124.7283120	total: 30s	remaining: 1.61s
# 949:	learn: 3124.1181509	total: 30s	remaining: 1.58s
# 950:	learn: 3123.4997099	total: 30.1s	remaining: 1.55s
# 951:	learn: 3123.0846997	total: 30.1s	remaining: 1.52s
# 952:	learn: 3122.7403035	total: 30.1s	remaining: 1.49s
# 953:	learn: 3121.8599433	total: 30.2s	remaining: 1.45s
# 954:	learn: 3121.2887004	total: 30.2s	remaining: 1.42s
# 955:	learn: 3120.5065785	total: 30.2s	remaining: 1.39s
# 956:	learn: 3119.9007527	total: 30.3s	remaining: 1.36s
# 957:	learn: 3119.1412639	total: 30.3s	remaining: 1.33s
# 958:	learn: 3118.5963337	total: 30.3s	remaining: 1.3s
# 959:	learn: 3118.0584245	total: 30.3s	remaining: 1.26s
# 960:	learn: 3117.5715444	total: 30.4s	remaining: 1.23s
# 961:	learn: 3116.7500275	total: 30.4s	remaining: 1.2s
# 962:	learn: 3115.7694171	total: 30.4s	remaining: 1.17s
# 963:	learn: 3114.7060684	total: 30.5s	remaining: 1.14s
# 964:	learn: 3114.3682272	total: 30.5s	remaining: 1.11s
# 965:	learn: 3113.9799973	total: 30.5s	remaining: 1.07s
# 966:	learn: 3113.6615535	total: 30.6s	remaining: 1.04s
# 967:	learn: 3113.3105665	total: 30.6s	remaining: 1.01s
# 968:	learn: 3112.4894022	total: 30.6s	remaining: 980ms
# 969:	learn: 3111.7206059	total: 30.6s	remaining: 948ms
# 970:	learn: 3110.8397558	total: 30.7s	remaining: 916ms
# 971:	learn: 3110.4982939	total: 30.7s	remaining: 885ms
# 972:	learn: 3110.2789608	total: 30.7s	remaining: 853ms
# 973:	learn: 3109.6962580	total: 30.8s	remaining: 821ms
# 974:	learn: 3108.9610484	total: 30.8s	remaining: 790ms
# 975:	learn: 3108.6460836	total: 30.8s	remaining: 758ms
# 976:	learn: 3108.2295896	total: 30.9s	remaining: 727ms
# 977:	learn: 3107.5836057	total: 30.9s	remaining: 695ms
# 978:	learn: 3106.9363246	total: 30.9s	remaining: 663ms
# 979:	learn: 3105.9938824	total: 31s	remaining: 632ms
# 980:	learn: 3105.2738872	total: 31s	remaining: 600ms
# 981:	learn: 3104.3931816	total: 31s	remaining: 569ms
# 982:	learn: 3104.1293003	total: 31.1s	remaining: 537ms
# 983:	learn: 3103.1239454	total: 31.1s	remaining: 505ms
# 984:	learn: 3102.6388186	total: 31.1s	remaining: 474ms
# 985:	learn: 3102.0283284	total: 31.1s	remaining: 442ms
# 986:	learn: 3101.4393623	total: 31.2s	remaining: 411ms
# 987:	learn: 3100.9159918	total: 31.2s	remaining: 379ms
# 988:	learn: 3099.6705222	total: 31.2s	remaining: 347ms
# 989:	learn: 3099.4768059	total: 31.3s	remaining: 316ms
# 990:	learn: 3099.0678077	total: 31.3s	remaining: 284ms
# 991:	learn: 3098.6507951	total: 31.3s	remaining: 253ms
# 992:	learn: 3098.0507822	total: 31.4s	remaining: 221ms
# 993:	learn: 3097.3834474	total: 31.4s	remaining: 189ms
# 994:	learn: 3096.9941356	total: 31.4s	remaining: 158ms
# 995:	learn: 3096.6228943	total: 31.4s	remaining: 126ms
# 996:	learn: 3096.3177802	total: 31.5s	remaining: 94.7ms
# 997:	learn: 3095.9204465	total: 31.5s	remaining: 63.1ms
# 998:	learn: 3095.3363434	total: 31.5s	remaining: 31.6ms
# 999:	learn: 3094.6685228	total: 31.6s	remaining: 0us
#         Real Values  Predicted Values
# 187265         3361       2834.771540
# 25128          3754       4994.753110
# 131095         5334       5011.905205
# 81729          4249       5024.243693
# 12702         16210       7667.709444
# ...             ...               ...
# 114253         5322       5243.389117
# 23730         79024      68223.294128
# 20324         53152      55647.956865
# 118268         4687       4492.260122
# 134337         5102       5447.241675
#
# [72062 rows x 2 columns]
# Training score:  0.981418863903529
# r2 score is:  0.9797087542105776
# MAE:  1825.9720947655394
# MSE:  10432557.530501371
# RMSE:  3229.9469857106587
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# # XGBoostRegressor

# %%
predict(XGBRegressor(objective = 'reg:squarederror', learning_rate = 0.3, max_depth = 5, n_estimators = 50))
# Out:
#         Real Values  Predicted Values
# 187265         3361       3119.813232
# 25128          3754       5106.612793
# 131095         5334       5078.744629
# 81729          4249       5545.652344
# 12702         16210       7108.139648
# ...             ...               ...
# 114253         5322       4979.270020
# 23730         79024      64856.996094
# 20324         53152      55234.296875
# 118268         4687       4256.328125
# 134337         5102       4516.751953
#
# [72062 rows x 2 columns]
# Training score:  0.9650689738655666
# r2 score is:  0.9639540516186529
# MAE:  2490.9177632003775
# MSE:  18532693.070324793
# RMSE:  4304.961448181017
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
X.columns
# Out:
# Index(['airline', 'stop', 'classs', 'departure_time', 'arrival_time',
#        'days_left', 'duration', 'Travelling_Cities'],
#       dtype='object')

# %% [markdown]
# # we choose Random Forest Regressor because it performed well

# %%
rf =RandomForestRegressor(n_estimators=20,max_depth=20)

# %%
model = rf.fit(X_train,y_train)

# %%
row =[[1,0,1,3,4,2,150,0]] #[vistara,stop, economy, flight,evening,night, daysleft, duration in min , delhi to mumbai]

# %%
import pickle

# %%
with open('model_pkl', 'wb') as files:
    pickle.dump(rf, files)

# %%
rf.predict(X_test)
# Out:
# array([ 3062.53172913,  4890.35213055,  4698.70724714, ...,
#        53241.21732527,  4687.32      ,  5334.02471535])

# %%
le_name_mapping=dict(zip(encoder.classes_,encoder.transform(encoder.classes_)))
print(le_name_mapping)
# Out:
# {'Bangalore-Chennai': 0, 'Bangalore-Delhi': 1, 'Bangalore-Hyderabad': 2, 'Bangalore-Kolkata': 3, 'Bangalore-Mumbai': 4, 'Chennai-Bangalore': 5, 'Chennai-Delhi': 6, 'Chennai-Hyderabad': 7, 'Chennai-Kolkata': 8, 'Chennai-Mumbai': 9, 'Delhi-Bangalore': 10, 'Delhi-Chennai': 11, 'Delhi-Hyderabad': 12, 'Delhi-Kolkata': 13, 'Delhi-Mumbai': 14, 'Hyderabad-Bangalore': 15, 'Hyderabad-Chennai': 16, 'Hyderabad-Delhi': 17, 'Hyderabad-Kolkata': 18, 'Hyderabad-Mumbai': 19, 'Kolkata-Bangalore': 20, 'Kolkata-Chennai': 21, 'Kolkata-Delhi': 22, 'Kolkata-Hyderabad': 23, 'Kolkata-Mumbai': 24, 'Mumbai-Bangalore': 25, 'Mumbai-Chennai': 26, 'Mumbai-Delhi': 27, 'Mumbai-Hyderabad': 28, 'Mumbai-Kolkata': 29}
